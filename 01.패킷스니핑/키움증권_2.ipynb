# %%
import pyautogui
import time
import requests
import pandas as pd
import bs4
import re
from selenium.webdriver.support.select import Select
import json
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time

import requests
import pandas as pd
import bs4
import re
from selenium.webdriver.support.select import Select

# %%
import requests

url = "https://bbn.kiwoom.com/bbs/SBbsBoardBCOSZListAjax"
headers = {
    "accept": "*/*, application/evfwByfDS;q=0.1",
    "accept-encoding": "gzip, deflate, br, zstd",
    "accept-language": "ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7",
    "connection": "keep-alive",
    "content-length": "142",
    "content-type": "application/x-www-form-urlencoded; charset=UTF-8",
    "cookie": "JSESSIONID=FYHw3kRIuUjprawAsacsogWte6a1yoy2O1YChHlT0dJD1amVvalteBO6cngvjs9D.a3dzX2RvbWFpbi9iYnMwMTAx; WMONID=GQFc9QrphMT; evfw_Bo7vwu1=08afea1b2069a017c3e6d8ccb231fcd85702d9ces",
    "host": "bbn.kiwoom.com",
    "origin": "https://bbn.kiwoom.com",
    "referer": "https://bbn.kiwoom.com/bbs/VBbsBoardBCOSZView",
    "sec-ch-ua": '"Chromium";v="134", "Not:A-Brand";v="24", "Google Chrome";v="134"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": '"Windows"',
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-origin",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36",
    "x-reply-with": "ajax",
    "x-requested-with": "XMLHttpRequest"
}

# 데이터 페이로드
payload = {
    "pageNo": "1",
    "custId": "",
    "f_keyField": "",
    "f_key": "",
    "searchTp": "1",
    "pagePerBlock": "10",
    "maxGrpStep": "00000691259998",
    "minGrpStep": "00000689559997",
    "prevPageNo": "1",
    "_reqAgent": "ajax"
}

# POST 요청 보내기
response = requests.post(url, headers=headers, data=payload)

# %%
data = response.json()
data
# Out:
# {'topCnt': 4,
#  'boardList': [{'pageNo': None,
#    'pageSize': 15,
#    'totalCount': None,
#    'startRow': None,
#    'endRow': None,
#    'f_key': None,
#    'f_keyField': None,
#    'rnum': 1,
#    'seqid': 9,
#    'scrnTp': 'NCOSZ',
#    'realno': 0,
#    'pareSeqid': 0,
#    'grp': 0,
#    'artcDep': 0,
#    'step': 0,
#    'ttl': '[공지] 대체거래소 관련 조건검색 및 성과검증 서비스 안내',
#    'custId': '',
#    'custPsdn': '키움증권',
#    'mngrYn': None,
#    'ip': None,
#    'readCnt': 251,
#    'dtlCntn': None,
#    'makeTime': '2025.03.04',
#    'email': None,
#    'emailRecvTp': None,
#    'smsRecvTp': None,
#    'emailSendTime': None,
#    'telNo': None,
#    'smsSendtp': None,
#    'smsSendTime': None,
#    'docTp': None,
#    'dltTp': None,
#    'dltNm': None,
#    'dltId': None,
#    'dltRsn': None,
#    'dltTime': None,
#    'mdiaTp': None,
#    'divTp1': None,
#    'divTp2': None,
#    'rgstNm': None,
#    'recmCnt': 0,
#    'htsScrnNo': None,
#    'scrnTpNm': None,
#    'divTp1Nm': None,
# ...

# %%
data['boardList'][0].keys()
# Out:
# dict_keys(['pageNo', 'pageSize', 'totalCount', 'startRow', 'endRow', 'f_key', 'f_keyField', 'rnum', 'seqid', 'scrnTp', 'realno', 'pareSeqid', 'grp', 'artcDep', 'step', 'ttl', 'custId', 'custPsdn', 'mngrYn', 'ip', 'readCnt', 'dtlCntn', 'makeTime', 'email', 'emailRecvTp', 'smsRecvTp', 'emailSendTime', 'telNo', 'smsSendtp', 'smsSendTime', 'docTp', 'dltTp', 'dltNm', 'dltId', 'dltRsn', 'dltTime', 'mdiaTp', 'divTp1', 'divTp2', 'rgstNm', 'recmCnt', 'htsScrnNo', 'scrnTpNm', 'divTp1Nm', 'divTp2Nm', 'isNew', 'rk', 'topCnt', 'topMaxCnt', 'nextScrnTp', 'prevScrnTp', 'nextTtl', 'prevTtl', 'nextSeqid', 'prevSeqid', 'imprLevl', 'attcFile', 'fileseq', 'filenm', 'apndnm', 'wid', 'wname', 'searchTp', 'pareDtlCntn', 'pareTtl', 'viewTp', 'f_scrnTp', 'checkId', 'pagePerBlock', 'maxGrpStep', 'minGrpStep', 'prevPageNo', 'shiftTp', 'blockNo', 'cnt', 'deviceInfo', 'totalTp', 'note'])

# %%
e = 1

for i in range(5) :
    url = "https://bbn.kiwoom.com/bbs/SBbsBoardBCOSZListAjax"
    headers = {
        "accept": "*/*, application/evfwByfDS;q=0.1",
        "accept-encoding": "gzip, deflate, br, zstd",
        "accept-language": "ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7",
        "connection": "keep-alive",
        "content-length": "142",
        "content-type": "application/x-www-form-urlencoded; charset=UTF-8",
        "cookie": "JSESSIONID=FYHw3kRIuUjprawAsacsogWte6a1yoy2O1YChHlT0dJD1amVvalteBO6cngvjs9D.a3dzX2RvbWFpbi9iYnMwMTAx; WMONID=GQFc9QrphMT; evfw_Bo7vwu1=08afea1b2069a017c3e6d8ccb231fcd85702d9ces",
        "host": "bbn.kiwoom.com",
        "origin": "https://bbn.kiwoom.com",
        "referer": "https://bbn.kiwoom.com/bbs/VBbsBoardBCOSZView",
        "sec-ch-ua": '"Chromium";v="134", "Not:A-Brand";v="24", "Google Chrome";v="134"',
        "sec-ch-ua-mobile": "?0",
        "sec-ch-ua-platform": '"Windows"',
        "sec-fetch-dest": "empty",
        "sec-fetch-mode": "cors",
        "sec-fetch-site": "same-origin",
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36",
        "x-reply-with": "ajax",
        "x-requested-with": "XMLHttpRequest"
    }
    
    # 데이터 페이로드
    payload = {
        "pageNo": i,
        "custId": "",
        "f_keyField": "",
        "f_key": "",
        "searchTp": "1",
        "pagePerBlock": "10",
        "maxGrpStep": "00000691259998",
        "minGrpStep": "00000689559997",
        "prevPageNo": "1",
        "_reqAgent": "ajax"
    }
    
    # POST 요청 보내기
    response = requests.post(url, headers=headers, data=payload)
    data = response.json()
    for data_component in data['boardList'] :
        if data_component['step'] == 1 :
            print(e,"번째 글 내용")
            print(data_component['dtlCntn'])
            print(" ")
        e = e +1
# Out:
# 2 번째 글 내용
# 기술적지표에서 일목균형표식으로 수식을 넣었는데
# 화면상단 좌측에 상한가선(0.00)구름(0.00) 하늘(0.00)원래 숫자가 표긷되야하는데
# 이유를 모르겠네요 방법이있을까요
#
# 3 번째 글 내용
# valuewhen(1, time&lt;분봉시간, 기준*(100+퍼센트)/100)
#
#
#
# 조건검색식 만들어 주세요
#
# 4 번째 글 내용
# 금월 월봉이 갭상승으로 시작되는 종목
#
# 6 번째 글 내용
# 3~4개월 음봉으로 지속되다가 금월 양봉으로 전환된 종목
#
# 8 번째 글 내용
# 조건검색후 나온 종목을 관심종목으로 통채로 옮길수 있는 방법 있나요?
# 하나하나 관심종목에 써서 넣어야 하나요?
# 편한 방법 알려주세요
#
# 10 번째 글 내용
# (predayhigh()+predaylow()+predayclose())/3 +predayhigh()-predaylow()
#
# 이 수식을 돌파 할때 조건검색식이 궁금 합니다 ~
#
# 12 번째 글 내용
# 조건검색식에서 볼린저벤드 상한선 이하 조건을 넣고 싶은데 상한선 이상만 있더라구요 방법 없을까요?
#
# 14 번째 글 내용
# 오늘 주가 17% 이상 오른 종목중에  고가대비 7% 이상 빠진 종목 검색식 부탁 드려요
#
# 16 번째 글 내용
# (고가 - 현재가)  &gt;=  (고가 - 전일종가)*0.3    또는
# (고가-현재가) / (고가 - 전일종가 )   &gt;=  0.3
# 검색식이 가능한가요
#
# 18 번째 글 내용
# 3개월 or 6개월  대비
#
# 거래량이 6배 이상 터진 종목을 검색을 할려면 어떤 검색식을 사용해야할까요?
#
# 그리고 3개월 이전 전고점을 돌파하는 검색식 있다면 좀 알려주세요.
#
# 20 번째 글 내용
# 안녕하세요? 귀하의 노고에 감사드립니다.
#
# 전일 동시간대 거래량 대비 거래량이 2배 이상인 종목
#
# 을 검색하고 싶습니다. 이상입니다.
#
# 감사합니다.
#
# 22 번째 글 내용
# 주봉 차트에서
# ...

# %% [markdown]
# ### 두번째 풀코드(셀레니움)

# %%
url = "https://bbn.kiwoom.com/bbs/VBbsBoardBCOSZView"

# %%
from selenium.webdriver.chrome.options import Options

chrome_options = Options()
chrome_options.add_argument("--disable-blink-features=AutomationControlled")

driver = webdriver.Chrome(options=chrome_options)

# %%
driver.get(url)

# %%
trs = driver.find_elements(By.CSS_SELECTOR, "tbody > tr")

# %%
# 새창에서 열기
driver_sub = webdriver.Chrome()
driver_sub.get("https://finance.naver.com/news/mainnews.naver")

# %%
# 방법 1. CTRL + ENTER
company = driver_sub.find_element(By.CSS_SELECTOR, ".company")
company.send_keys(Keys.CONTROL + '\n')

# %%
# 방법 2. 자바스크립트
company = driver_sub.find_element(By.CSS_SELECTOR, ".company")
href = company.get_attribute('href')
driver_sub.execute_script("window.open(arguments[0], '_blank');", href)

# %%
for tr in trs:
    post_id = tr.find_element(By.CSS_SELECTOR, "td:nth-of-type(1)").text

    #글 번호가 있다면
    if post_id != '':
        title = tr.find_element(By.CSS_SELECTOR, ".notice-title").text

        # 새글 이라면 마지막 N삭제
        new_icon = tr.find_elements(By.CSS_SELECTOR,".icon-new")
        if new_icon:
            title = title[:-1]

        date = tr.find_element(By.CSS_SELECTOR, "td:nth-of-type(5)").text
        content = tr.find_element(By.CSS_SELECTOR, ".notice-title")
        content.send_keys(Keys.CONTROL +'\n')
        time.sleep(1)
        content = driver.find_element(By.CSS_SELECTOR,"#dtlCntn").text
        driver.back()
        print(title, date, content,sep='\n')
        print('=' * 20)
# Out:
# [공지] 대체거래소 관련 조건검색 및 성과검증 서비스 안내
# 2025.03.04
# 안녕하세요. 키움증권입니다.
# 키움증권을 이용해주시는 고객님께 감사드립니다.
#  대체거래소 관련 조건검색을 포함한 아래의 서비스는 KRX 시세를 기준으로만 제공됩니다.
#  - 조건검색
#  - 조건검색 실시간
#  - 캐치서비스
#  - 영웅검색, 성과검증
#  추후 통합시세 및 NXT 시세를 활용한 기능을 확대할 예정이오니, 이용에 참고해 주시기 바랍니다.
#  감사합니다.
# ...
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# Cell In[14], line 2
#       1 for tr in trs:
# ----> 2     post_id = tr.find_element(By.CSS_SELECTOR, "td:nth-of-type(1)").text
#       4     #글 번호가 있다면
#       5     if post_id != '':
#
# File ~\anaconda3\envs\crawling\Lib\site-packages\selenium\webdriver\remote\webelement.py:601, in WebElement.find_element(self, by, value)
#     575 """Find an element given a By strategy and locator.
#     576
#     577 Parameters:
#    (...)    598     The first matching `WebElement` found on the page.
#     599 """
# ...

# %%
num_row = len(driver.find_elements(By.CSS_SELECTOR, "tbody > tr"))

for i in range(num_row) :
    trs = driver.find_elements(By.CSS_SELECTOR, "tbody > tr")
    tr = trs[i]
    post_id = tr.find_element(By.CSS_SELECTOR, "td:nth-of-type(1)").text

    #글 번호가 있다면
    if post_id != '':
        title = tr.find_element(By.CSS_SELECTOR, ".notice-title").text

        # 새글 이라면 마지막 N삭제
        new_icon = tr.find_elements(By.CSS_SELECTOR,".icon-new")
        if new_icon:
            title = title[:-1]

        date = tr.find_element(By.CSS_SELECTOR, "td:nth-of-type(5)").text
        content = tr.find_element(By.CSS_SELECTOR, ".notice-title").click()
        time.sleep(1)
        content = driver.find_element(By.CSS_SELECTOR,"#dtlCntn").text
        driver.back()
        time.sleep(1)
        print(title, date, content,sep='\n')
        print('=' * 20)
# Out:
# [공지] 대체거래소 관련 조건검색 및 성과검증 서비스 안내
# 2025.03.04
# 안녕하세요. 키움증권입니다.
# 키움증권을 이용해주시는 고객님께 감사드립니다.
#  대체거래소 관련 조건검색을 포함한 아래의 서비스는 KRX 시세를 기준으로만 제공됩니다.
#  - 조건검색
#  - 조건검색 실시간
#  - 캐치서비스
#  - 영웅검색, 성과검증
#  추후 통합시세 및 NXT 시세를 활용한 기능을 확대할 예정이오니, 이용에 참고해 주시기 바랍니다.
#  감사합니다.
# ...
# 조건검색식 문의드려요
# 2025.03.18 09:57
# 3분봉차트에서 현재가가 120분이동평균선 대비 5% 이상 하락한 종목검색식 부탁드립니다.
# ...
# 검색식 문의
# 2025.03.18 09:11
# CrossUp(wavg(C, 1), wavg(C, 100))
#
# 위 수식을 검색식으로 바꿔주세요~
# ...
# 문의
# 2025.03.18 08:54
# 전일 거래량 급증(20일 평균 거래량 대비 300% 이상)
# 전일 양봉 마감 (종가 >시가)
# 전일 종가 5일 이동평균선 돌파
# 전일 종가 20일 이동평균선 돌파
# 금일 시가가 전일 종가 대비 2~5% 갭상승
# 시초 거래량 급증 (전일 평균 거래량 대비 10배 이상)
# 시초 3분봉 또는 5분봉 기준 거래량 +강한 양봉 형성
#
# 검색식으로 부탁합니다
# ...
# 5분봉에서 저점을 올려가는 종목을 찾는 방법
# 2025.03.18 08:52
# 안녕하세요..
# 저점을 올려주는 종목을 찾는 조건식을 부탁합니다
# ...
# 다음 내용과 지표조건을 조건식으로 부탁드립니다.
# 2025.03.18 07:48
# 수식
# MACD(short,long)-eavg(MACD(short,long),signal)
#
# 지표조건설정
# short     5
# long      12
# signal    2
# 두 선이 서로 교차하는 조건식을 만들고싶습니다. 부탁드려요.
# ...
# 검색식 부탁드립니다.
# 2025.03.18 04:15
# 혼자 만들다 힘들어서 문의 드립니다.
# ...
