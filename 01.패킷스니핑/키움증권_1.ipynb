# %%
import pyautogui
import time
import requests
import pandas as pd
import bs4
import re
from selenium.webdriver.support.select import Select
import json
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time

import requests
import pandas as pd
import bs4
import re
from selenium.webdriver.support.select import Select

# %%
url = "https://bbn.kiwoom.com/bbs/VBbsBoardBCOSZView"

# %%
driver = webdriver.Chrome()
driver.get(url)

# %%
elements = driver.find_elements(By.CSS_SELECTOR,'#kwGridTable > div.table-container > table > tbody > tr')

# %%
elements[5].find_elements(By.CSS_SELECTOR,"span.notice-reply > em")
# Out:
# []

# %%
elements[5].find_element(By.CSS_SELECTOR, "td:nth-child(5)").text
# Out:
# '2025.03.16 18:08'

# %%
if elements[5].find_elements(By.CSS_SELECTOR,"span.notice-reply > em") :
    continue
else :

# %%
for element in elements :
    if element.find_elements(By.CSS_SELECTOR,"span.notice-reply > em") :
        continue
    else :
        title = element.find_element(By.CSS_SELECTOR, "a").text
        wdate = element.find_element(By.CSS_SELECTOR, "td:nth-child(5)").text
        print(title, wdate)
# Out:
# [공지] 대체거래소 관련 조건검색 및 성과검증 서비스 안내 2025.03.04
# 전날 고점 돌파 조건식N 2025.03.16 21:21
# 조건검색식 만들어주세요N 2025.03.16 20:43
# 검색식 부탁합니다N 2025.03.16 20:37
# 검색식N 2025.03.16 18:59
# 총잔량N 2025.03.16 18:08
# 검색식 부탁드려요N 2025.03.16 13:17
# 조건검색식 질문드립니다.N 2025.03.16 12:32
# 하락률에 대한 조건식N 2025.03.16 11:00
# 문의 드립니다.N 2025.03.16 10:12
# 문의N 2025.03.16 09:15
# 검색식 문의 드립니다.N 2025.03.16 04:03

# %% [markdown]
# ### 풀 코드

# %%
import pyautogui
import time
import requests
import pandas as pd
import bs4
import re
from selenium.webdriver.support.select import Select
import json
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time

import requests
import pandas as pd
import bs4
import re
from selenium.webdriver.support.select import Select

url = "https://bbn.kiwoom.com/bbs/VBbsBoardBCOSZView"
driver = webdriver.Chrome()
driver.get(url)
time.sleep(1)
elements = driver.find_elements(By.CSS_SELECTOR,'#kwGridTable > div.table-container > table > tbody > tr')


for element in elements :
    if element.find_elements(By.CSS_SELECTOR,"span.notice-reply > em") :
        continue
    else :
        title = element.find_element(By.CSS_SELECTOR, "a").text
        wdate = element.find_element(By.CSS_SELECTOR, "td:nth-child(5)").text
        print(title, wdate)
# Out:
# [공지] 대체거래소 관련 조건검색 및 성과검증 서비스 안내 2025.03.04
# 검색식부탁드립니다N 2025.03.16 22:13
# 검색식N 2025.03.16 21:57
# 전날 고점 돌파 조건식N 2025.03.16 21:21
# 조건검색식 만들어주세요N 2025.03.16 20:43
# 검색식 부탁합니다N 2025.03.16 20:37
# 검색식N 2025.03.16 18:59
# 총잔량N 2025.03.16 18:08
# 검색식 부탁드려요N 2025.03.16 13:17
# 조건검색식 질문드립니다.N 2025.03.16 12:32
# 하락률에 대한 조건식N 2025.03.16 11:00
# 문의 드립니다.N 2025.03.16 10:12

# %%
headers = {
    "accept": "*/*, application/evfwByfDS;q=0.1",
    "accept-encoding": "gzip, deflate, br, zstd",
    "accept-language": "ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7",
    "connection": "keep-alive",
    "content-length": "142",
    "content-type": "application/x-www-form-urlencoded; charset=UTF-8",
    "cookie": "JSESSIONID=FYHw3kRIuUjprawAsacsogWte6a1yoy2O1YChHlT0dJD1amVvalteBO6cngvjs9D.a3dzX2RvbWFpbi9iYnMwMTAx; WMONID=GQFc9QrphMT; evfw_Bo7vwu1=08afea1b2069a017c3e6d8ccb231fcd85702d9ces",
    "host": "bbn.kiwoom.com",
    "origin": "https://bbn.kiwoom.com",
    "referer": "https://bbn.kiwoom.com/bbs/VBbsBoardBCOSZView",
    "sec-ch-ua": '"Chromium";v="134", "Not:A-Brand";v="24", "Google Chrome";v="134"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": '"Windows"',
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-origin",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36",
    "x-reply-with": "ajax",
    "x-requested-with": "XMLHttpRequest"
}

# %%
from selenium.webdriver.chrome.options import Options

chrome_options = Options()
chrome_options.add_argument("--disable-blink-features=AutomationControlled")

driver = webdriver.Chrome(options=chrome_options)

# %%
url = "https://bbn.kiwoom.com/bbs/VBbsBoardBCOSZView"
url
# Out:
# 'https://bbn.kiwoom.com/bbs/VBbsBoardBCOSZView'

# %%
driver.get(url)

# %%
url = "https://bbn.kiwoom.com/bbs/SBbsBoardBCOSZListAjax"

# %%
import requests

url = "https://bbn.kiwoom.com/bbs/SBbsBoardBCOSZListAjax"
headers = {
    "accept": "*/*, application/evfwByfDS;q=0.1",
    "accept-encoding": "gzip, deflate, br, zstd",
    "accept-language": "ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7",
    "connection": "keep-alive",
    "content-length": "142",
    "content-type": "application/x-www-form-urlencoded; charset=UTF-8",
    "cookie": "JSESSIONID=FYHw3kRIuUjprawAsacsogWte6a1yoy2O1YChHlT0dJD1amVvalteBO6cngvjs9D.a3dzX2RvbWFpbi9iYnMwMTAx; WMONID=GQFc9QrphMT; evfw_Bo7vwu1=08afea1b2069a017c3e6d8ccb231fcd85702d9ces",
    "host": "bbn.kiwoom.com",
    "origin": "https://bbn.kiwoom.com",
    "referer": "https://bbn.kiwoom.com/bbs/VBbsBoardBCOSZView",
    "sec-ch-ua": '"Chromium";v="134", "Not:A-Brand";v="24", "Google Chrome";v="134"',
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": '"Windows"',
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-origin",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36",
    "x-reply-with": "ajax",
    "x-requested-with": "XMLHttpRequest"
}

# 데이터 페이로드
payload = {
    "pageNo": "3",
    "custId": "",
    "f_keyField": "",
    "f_key": "",
    "searchTp": "1",
    "pagePerBlock": "10",
    "maxGrpStep": "00000691259998",
    "minGrpStep": "00000689559997",
    "prevPageNo": "1",
    "_reqAgent": "ajax"
}

# POST 요청 보내기
response = requests.post(url, headers=headers, data=payload)

# 응답 출력
print(response.status_code)
print(response.text)
# Out:
# 200
# {"topCnt":4,"boardList":[{"pageNo":null,"pageSize":15,"totalCount":null,"startRow":null,"endRow":null,"f_key":null,"f_keyField":null,"rnum":0,"seqid":69099,"scrnTp":"BCOSZ","realno":4,"pareSeqid":0,"grp":69099,"artcDep":1,"step":1,"ttl":"렌코차트에 다른 보조지표를 추가할 수 있나요?","custId":"","custPsdn":"pds8***","mngrYn":"N","ip":"221.145.73.187","readCnt":1,"dtlCntn":"지표를 추가해도 보여지지 않습니다...메모리 문제인지?","makeTime":"2025.03.15 11:09","email":null,"emailRecvTp":null,"smsRecvTp":null,"emailSendTime":null,"telNo":null,"smsSendtp":null,"smsSendTime":null,"docTp":"0","dltTp":"1","dltNm":null,"dltId":null,"dltRsn":null,"dltTime":null,"mdiaTp":null,"divTp1":null,"divTp2":null,"rgstNm":null,"recmCnt":0,"htsScrnNo":null,"scrnTpNm":"조건검색 게시판","divTp1Nm":null,"divTp2Nm":null,"isNew":"Y","rk":0,"topCnt":null,"topMaxCnt":null,"nextScrnTp":0,"prevScrnTp":0,"nextTtl":0,"prevTtl":0,"nextSeqid":0,"prevSeqid":0,"imprLevl":null,"attcFile":null,"fileseq":0,"filenm":null,"apndnm":null,"wid":null,"wname":null,"searchTp":0,"pareDtlCntn":null,"pareTtl":null,"viewTp":null,"f_scrnTp":null,"checkId":null,"pagePerBlock":null,"maxGrpStep":"00000691259998","minGrpStep":"00000689559997","prevPageNo":null,"shiftTp":null,"blockNo":0,"cnt":"151","deviceInfo":null,"totalTp":false,"note":null},{"pageNo":null,"pageSize":15,"totalCount":null,"startRow":null,"endRow":null,"f_key":null,"f_keyField":null,"rnum":0,"seqid":69098,"scrnTp":"BCOSZ","realno":3,"pareSeqid":0,"grp":69098,"artcDep":1,"step":1,"ttl":"평균거래대금 조건검색","custId":"","custPsdn":"동방","mngrYn":"N","ip":"122.43.132.92","readCnt":10,"dtlCntn":"직전20봉 평균보다 현재봉이 1000%상승한조건식","makeTime":"2025.03.15 07:54","email":null,"emailRecvTp":null,"smsRecvTp":null,"emailSendTime":null,"telNo":null,"smsSendtp":null,"smsSendTime":null,"docTp":"0","dltTp":"1","dltNm":null,"dltId":null,"dltRsn":null,"dltTime":null,"mdiaTp":null,"divTp1":null,"divTp2":null,"rgstNm":null,"recmCnt":0,"htsScrnNo":null,"scrnTpNm":"조건검색 게시판","divTp1Nm":null,"divTp2Nm":null,"isNew":"Y","rk":0,"topCnt":null,"topMaxCnt":null,"nextScrnTp":0,"prevScrnTp":0,"nextTtl":0,"prevTtl":0,"nextSeqid":0,"prevSeqid":0,"imprLevl":null,"attcFile":null,"fileseq":0,"filenm":null,"apndnm":null,"wid":null,"wname":null,"searchTp":0,"pareDtlCntn":null,"pareTtl":null,"viewTp":null,"f_scrnTp":null,"checkId":null,"pagePerBlock":null,"maxGrpStep":"00000691259998","minGrpStep":"00000689559997","prevPageNo":null,"shiftTp":null,"blockNo":0,"cnt":"151","deviceInfo":null,"totalTp":false,"note":null},{"pageNo":null,"pageSize":15,"totalCount":null,"startRow":null,"endRow":null,"f_key":null,"f_keyField":null,"rnum":0,"seqid":69097,"scrnTp":"BCOSZ","realno":2,"pareSeqid":0,"grp":69097,"artcDep":1,"step":1,"ttl":"조건검색식 부탁드립니다.","custId":"","custPsdn":"ath***","mngrYn":"N","ip":"1.248.117.8","readCnt":17,"dtlCntn":"안녕하세요?\r\n\r\n조건검색식 작성시 패턴분석-패턴정의에서\r\n아래의 조건에 맞는 조건식을 구현하고 싶습니다.\r\n\r\n1. 양봉이며, 종가[현재가]와 고가가 같은 조건식 구현방법\r\n2. 양봉이며, 현재가가 고가의 95% 이상인 조건식 구현방법\r\n   [즉 꼬리가 작은 캔들 모양을 패턴정의로 검색하고 싶습니다.]\r\n\r\n아래와 같은 조건식에서 고가등락률 5% 이상은 어떤의미[어떤 모양의 캔들] 인가요?\r\n\r\nA:시세분석 &gt; 가격조건 &gt; 주가비교:[일]0봉전 시가 &lt; 0봉전 종가\r\nB:시세분석 &gt; 가격조건 &gt; 주가등락률:[일]0봉전(중) 종가대비 0봉전 고가등락률 5%이상\r\n(A and B)\r\n\r\n감사합니다.","makeTime":"2025.03.15 00:39","email":null,"emailRecvTp":"3","smsRecvTp":"3","emailSendTime":null,"telNo":null,"smsSendtp":null,"smsSendTime":null,"docTp":"0","dltTp":"1","dltNm":null,"dltId":null,"dltRsn":null,"dltTime":null,"mdiaTp":null,"divTp1":null,"divTp2":null,"rgstNm":null,"recmCnt":0,"htsScrnNo":null,"scrnTpNm":"조건검색 게시판","divTp1Nm":null,"divTp2Nm":null,"isNew":"Y","rk":0,"topCnt":null,"topMaxCnt":null,"nextScrnTp":0,"prevScrnTp":0,"nextTtl":0,"prevTtl":0,"nextSeqid":0,"prevSeqid":0,"imprLevl":null,"attcFile":null,"fileseq":0,"filenm":null,"apndnm":null,"wid":null,"wname":null,"searchTp":0,"pareDtlCntn":null,"pareTtl":null,"viewTp":null,"f_scrnTp":null,"checkId":null,"pagePerBlock":null,"maxGrpStep":"00000691259998","minGrpStep":"00000689559997","prevPageNo":null,"shiftTp":null,"blockNo":0,"cnt":"151","devic ...

# %%
data = response.json()

# %%
data
# Out:
# {'topCnt': 4,
#  'boardList': [{'pageNo': None,
#    'pageSize': 15,
#    'totalCount': None,
#    'startRow': None,
#    'endRow': None,
#    'f_key': None,
#    'f_keyField': None,
#    'rnum': 0,
#    'seqid': 69099,
#    'scrnTp': 'BCOSZ',
#    'realno': 4,
#    'pareSeqid': 0,
#    'grp': 69099,
#    'artcDep': 1,
#    'step': 1,
#    'ttl': '렌코차트에 다른 보조지표를 추가할 수 있나요?',
#    'custId': '',
#    'custPsdn': 'pds8***',
#    'mngrYn': 'N',
#    'ip': '221.145.73.187',
#    'readCnt': 1,
#    'dtlCntn': '지표를 추가해도 보여지지 않습니다...메모리 문제인지?',
#    'makeTime': '2025.03.15 11:09',
#    'email': None,
#    'emailRecvTp': None,
#    'smsRecvTp': None,
#    'emailSendTime': None,
#    'telNo': None,
#    'smsSendtp': None,
#    'smsSendTime': None,
#    'docTp': '0',
#    'dltTp': '1',
#    'dltNm': None,
#    'dltId': None,
#    'dltRsn': None,
#    'dltTime': None,
#    'mdiaTp': None,
#    'divTp1': None,
#    'divTp2': None,
#    'rgstNm': None,
#    'recmCnt': 0,
#    'htsScrnNo': None,
#    'scrnTpNm': '조건검색 게시판',
#    'divTp1Nm': None,
#    'divTp2Nm': None,
#    'isNew': 'Y',
#    'rk': 0,
#    'topCnt': None,
#    'topMaxCnt': None,
#    'nextScrnTp': 0,
#    'prevScrnTp': 0,
#    'nextTtl': 0,
#    'prevTtl': 0,
#    'nextSeqid': 0,
#    'prevSeqid': 0,
#    'imprLevl': None,
#    'attcFile': None,
#    'fileseq': 0,
#    'filenm': None,
#    'apndnm': None,
#    'wid': None,
#    'wname': None,
#    'searchTp': 0,
#    'pareDtlCntn': None,
#    'pareTtl': None,
#    'viewTp': None,
#    'f_scrnTp': None,
#    'checkId': None,
#    'pagePerBlock': None,
#    'maxGrpStep': '00000691259998',
#    'minGrpStep': '00000689559997',
#    'prevPageNo': None,
#    'shiftTp': None,
#    'blockNo': 0,
#    'cnt': '151',
#    'deviceInfo': None,
#    'totalTp': False,
#    'note': None},
#   {'pageNo': None,
#    'pageSize': 15,
#    'totalCount': None,
#    'startRow': None,
#    'endRow': None,
#    'f_key': None,
#    'f_keyField': None,
#    'rnum': 0,
#    'seqid': 69098,
#    'scrnTp': 'BCOSZ',
#    'realno': 3,
#    'pareSeqid': 0,
#    'grp': 69098,
#    'artcDep': 1,
#    'step': 1,
#    'ttl': '평균거래대금 조건검색',
#    'custId': '',
#    'custPsdn': '동방',
#    'mngrYn': 'N',
#    'ip': '122.43.132.92',
#    'readCnt': 10,
#    'dtlCntn': '직전20봉 평균보다 현재봉이 1000%상승한조건식',
#    'makeTime': '2025.03.15 07:54',
#    'email': None,
#    'emailRecvTp': None,
#    'smsRecvTp': None,
#    'emailSendTime': None,
#    'telNo': None,
#    'smsSendtp': None,
#    'smsSendTime': None,
#    'docTp': '0',
#    'dltTp': '1',
#    'dltNm': None,
#    'dltId': None,
#    'dltRsn': None,
#    'dltTime': None,
#    'mdiaTp': None,
#    'divTp1': None,
#    'divTp2': None,
#    'rgstNm': None,
#    'recmCnt': 0,
#    'htsScrnNo': None,
#    'scrnTpNm': '조건검색 게시판',
#    'divTp1Nm': None,
#    'divTp2Nm': None,
#    'isNew': 'Y',
#    'rk': 0,
#    'topCnt': None,
#    'topMaxCnt': None,
#    'nextScrnTp': 0,
#    'prevScrnTp': 0,
#    'nextTtl': 0,
#    'prevTtl': 0,
#    'nextSeqid': 0,
#    'prevSeqid': 0,
#    'imprLevl': None,
#    'attcFile': None,
#    'fileseq': 0,
#    'filenm': None,
#    'apndnm': None,
#    'wid': None,
#    'wname': None,
#    'searchTp': 0,
#    'pareDtlCntn': None,
#    'pareTtl': None,
#    'viewTp': None,
#    'f_scrnTp': None,
#    'checkId': None,
#    'pagePerBlock': None,
#    'maxGrpStep': '00000691259998',
#    'minGrpStep': '00000689559997',
#    'prevPageNo': None,
#    'shiftTp': None,
#    'blockNo': 0,
#    'cnt': '151',
#    'deviceInfo': None,
#    'totalTp': False,
#    'note': None},
#   {'pageNo': None,
#    'pageSize': 15,
#    'totalCount': None,
#    'startRow': None,
#    'endRow': None,
#    'f_key': None,
#    'f_keyField': None,
#    'rnum': 0,
#    'seqid': 69097,
#    'scrnTp': 'BCOSZ',
#    'realno': 2,
#    'pareSeqid': 0,
#    'grp': 69097,
#    'artcDep': 1,
#    'step': 1,
#    'ttl': '조건검색식 부탁드립니다.',
#    'custId': '',
#    'custPsdn': 'ath***',
#    'mngrYn': 'N',
#    'ip': '1.248.117.8',
#    'readCnt': 17,
#    'dtlCntn': '안녕하세요?\r\n\r\n조건검색식 작성시 패턴분석-패턴정의에서\r\n아래의 조건에 맞는 조건식을 구현하고 싶습니다.\r\n\r\n1. 양봉이며, 종가[현재가]와 고가가 같은 조건식 구현방법\r\n2. 양봉이며, 현재가가 고가의 95% 이상인 조건식 구현방법\r\n   [즉 꼬리가 작은 캔들 모양을 패턴정의로 검색하고 싶습니다.]\r\n\r\n아래와 같은 조건식에서 고가등락률 5% 이상은 어떤의미[어떤 모양의 캔들] 인가요?\r\n\r\nA:시세분석 &gt; 가격조건 &gt; 주가비교:[일]0봉전 시가 &lt; 0봉전 종가\r\nB:시세분석 &gt; 가격조건 &gt; 주가등락률:[일]0봉전(중) 종가대비 0봉전 고가등락률 5%이상\r\n(A and B)\r\n\r\n감사합니다.',
#    'makeTime': '2025.03.15 00:39',
#    'email': None,
#    'emailRecvTp': '3',
#    'smsRecvTp': '3',
#    'emailSendTime': None,
#    'telNo': None,
#    'smsSendtp': None,
#    'smsSendTime': None,
#    'docTp': '0',
#    'dltTp': '1',
#    'dltNm': None,
#    'dltId': None,
#    'dltRsn': None,
#    'dltTime': None,
#    'mdiaTp': None,
#    'divTp1': None,
#    'divTp2': None,
#    'rgstNm': None,
#    'recmCnt': 0,
#    'htsScrnNo': None,
#    'scrnTpNm': '조건검색 게시판',
#    'divTp1Nm': None,
#    'divTp2Nm': None,
#    'isNew': 'Y',
#    'rk': 0,
#    'topCnt': None,
#    'topMaxCnt': None,
#    'nextScrnTp': 0,
#    'prevScrnTp': 0,
#    'nextTtl': 0,
#    'prevTtl': 0,
#    'nextSeqid': 0,
#    'prevSeqid': 0,
#    'imprLevl': None,
#    'attcFile': None,
#    'fileseq': 0,
#    'filenm': None,
#    'apndnm': None,
#    'wid': None,
#    'wname': None,
#    'searchTp': 0,
#    'pareDtlCntn': None,
#    'pareTtl': None,
#    'viewTp': None,
#    'f_scrnTp': None,
#    'checkId': None,
#    'pagePerBlock': None,
#    'maxGrpStep': '00000691259998',
#    'minGrpStep': '00000689559997',
#    'prevPageNo': None,
#    'shiftTp': None,
#    'blockNo': 0,
#    'cnt': '151',
#    'deviceInfo': None,
#    'totalTp': False,
#    'note': None},
#   {'pageNo': None,
#    'pageSize': 15,
#    'totalCount': None,
#    'startRow': None,
#    'endRow': None,
#    'f_key': None,
#    'f_keyField': None,
#    'rnum': 0,
#    'seqid': 69096,
#    'scrnTp': 'BCOSZ',
#    'realno': 1,
#    'pareSeqid': 0,
#    'grp': 69096,
#    'artcDep': 1,
#    'step': 1,
#    'ttl': '안녕하세요.',
#    'custId': '',
#    'custPsdn': 'mdmu***',
#    'mngrYn': 'N',
#    'ip': '182.221.199.240',
#    'readCnt': 9,
#    'dtlCntn': '스토캐스틱 매수 신호:CrossUp(StochasticsSlow(Period1,Period2),buyLevel)\r\n기간1:20 기간2:5 이구요. 제가 묻고저 하는것은 여기서 buylevel이 무슨 뜻이지요? \r\n\r\nstochastic(slow) 를 선택 "기준값 돌파" %K  20으로 설정  하여도 신호가 검색되지 않습니다.\r\n\r\n신호를 검색할 수 있는 조건검색식 부탁드립니다.',
#    'makeTime': '2025.03.14 23:35',
#    'email': None,
#    'emailRecvTp': None,
#    'smsRecvTp': None,
#    'emailSendTime': None,
#    'telNo': None,
#    'smsSendtp': None,
#    'smsSendTime': None,
#    'docTp': '0',
#    'dltTp': '1',
#    'dltNm': None,
#    'dltId': None,
#    'dltRsn': None,
#    'dltTime': None,
#    'mdiaTp': None,
#    'divTp1': None,
#    'divTp2': None,
#    'rgstNm': None,
#    'recmCnt': 0,
#    'htsScrnNo': None,
#    'scrnTpNm': '조건검색 게시판',
#    'divTp1Nm': None,
#    'divTp2Nm': None,
#    'isNew': 'N',
#    'rk': 0,
#    'topCnt': None,
#    'topMaxCnt': None,
#    'nextScrnTp': 0,
#    'prevScrnTp': 0,
#    'nextTtl': 0,
#    'prevTtl': 0,
#    'nextSeqid': 0,
#    'prevSeqid': 0,
#    'imprLevl': None,
#    'attcFile': None,
#    'fileseq': 0,
#    'filenm': None,
#    'apndnm': None,
#    'wid': None,
#    'wname': None,
#    'searchTp': 0,
#    'pareDtlCntn': None,
#    'pareTtl': None,
#    'viewTp': None,
#    'f_scrnTp': None,
#    'checkId': None,
#    'pagePerBlock': None,
#    'maxGrpStep': '00000691259998',
#    'minGrpStep': '00000689559997',
#    'prevPageNo': None,
#    'shiftTp': None,
#    'blockNo': 0,
#    'cnt': '151',
#    'deviceInfo': None,
#    'totalTp': False,
#    'note': None},
#   {'pageNo': None,
#    'pageSize': 15,
#    'totalCount': None,
#    'startRow': None,
#    'endRow': None,
#    'f_key': None,
#    'f_keyField': None,
#    'rnum': 0,
#    'seqid': 69094,
#    'scrnTp': 'BCOSZ',
#    'realno': 10,
#    'pareSeqid': 0,
#    'grp': 69094,
#    'artcDep': 1,
#    'step': 1,
#    'ttl': '조건검색식의 차이점',
#    'custId': '',
#    'custPsdn': 'land***',
#    'mngrYn': 'N',
#    'ip': '211.202.137.238',
#    'readCnt': 11,
#    'dtlCntn': '안녕하세요,\r\n시세분석-기술적분석-주가이동평균에서 \r\n주가이동평균등락률이 있는데 무슨 검색식인지 잘 몰라서 여쭙습니다. \r\nex) 10봉전(중) 종가 20이평대비 \r\n          5봉전 종가 5이평등락률 10~20% 라고 가정했을때로 설명 한번 부탁드립니다.',
#    'makeTime': '2025.03.14 20:44',
#    'email': None,
#    'emailRecvTp': None,
#    'smsRecvTp': None,
#    'emailSendTime': None,
#    'telNo': None,
#    'smsSendtp': None,
#    'smsSendTime': None,
#    'docTp': '0',
#    'dltTp': '1',
#    'dltNm': None,
#    'dltId': None,
#    'dltRsn': None,
#    'dltTime': None,
#    'mdiaTp': None,
#    'divTp1': None,
#    'divTp2': None,
#    'rgstNm': None,
#    'recmCnt': 0,
#    'htsScrnNo': None,
#    'scrnTpNm': '조건검색 게시판',
#    'divTp1Nm': None,
#    'divTp2Nm': None,
#    'isNew': 'N',
#    'rk': 0,
#    'topCnt': None,
#    'topMaxCnt': None,
#    'nextScrnTp': 0,
#    'prevScrnTp': 0,
#    'nextTtl': 0,
#    'prevTtl': 0,
#    'nextSeqid': 0,
#    'prevSeqid': 0,
#    'imprLevl': None,
#    'attcFile': None,
#    'fileseq': 0,
#    'filenm': None,
#    'apndnm': None,
#    'wid': None,
#    'wname': None,
#    'searchTp': 0,
#    'pareDtlCntn': None,
#    'pareTtl': None,
#    'viewTp': None,
#    'f_scrnTp': None,
#    'checkId': None,
#    'pagePerBlock': None,
#    'maxGrpStep': '00000691259998',
#    'minGrpStep': '00000689559997',
#    'prevPageNo': None,
#    'shiftTp': None,
#    'blockNo': 0,
#    'cnt': '151',
#    'deviceInfo': None,
#    'totalTp': False,
#    'note': None},
#   {'pageNo': None,
#    'pageSize': 15,
#    'totalCount': None,
#    'startRow': None,
#    'endRow': None,
#    'f_key': None,
#    'f_keyField': None,
#    'rnum': 0,
#    'seqid': 69093,
#    'scrnTp': 'BCOSZ',
#    'realno': 9,
#    'pareSeqid': 0,
#    'grp': 69093,
#    'artcDep': 1,
#    'step': 1,
#    'ttl': '조건 검색 문의드립니다.',
#    'custId': '',
#    'custPsdn': 'joonk***',
#    'mngrYn': 'N',
#    'ip': '125.131.16.48',
#    'readCnt': 14,
#    'dtlCntn': '안녕하세요\r\n\r\n분봉에서 " dayhigh() " 를 돌파하는 검색식을 구현하고 싶습니다. \r\n\r\n가능할까요?\r\n\r\n감사합니다.',
#    'makeTime': '2025.03.14 17:51',
#    'email': None,
#    'emailRecvTp': '3',
#    'smsRecvTp': '3',
#    'emailSendTime': None,
#    'telNo': None,
#    'smsSendtp': None,
#    'smsSendTime': None,
#    'docTp': '0',
#    'dltTp': '1',
#    'dltNm': None,
#    'dltId': None,
#    'dltRsn': None,
#    'dltTime': None,
#    'mdiaTp': None,
#    'divTp1': None,
#    'divTp2': None,
#    'rgstNm': None,
#    'recmCnt': 0,
#    'htsScrnNo': None,
#    'scrnTpNm': '조건검색 게시판',
#    'divTp1Nm': None,
#    'divTp2Nm': None,
#    'isNew': 'N',
#    'rk': 0,
#    'topCnt': None,
#    'topMaxCnt': None,
#    'nextScrnTp': 0,
#    'prevScrnTp': 0,
#    'nextTtl': 0,
#    'prevTtl': 0,
#    'nextSeqid': 0,
#    'prevSeqid': 0,
#    'imprLevl': None,
#    'attcFile': None,
#    'fileseq': 0,
#    'filenm': None,
#    'apndnm': None,
#    'wid': None,
#    'wname': None,
#    'searchTp': 0,
#    'pareDtlCntn': None,
#    'pareTtl': None,
#    'viewTp': None,
#    'f_scrnTp': None,
#    'checkId': None,
#    'pagePerBlock': None,
#    'maxGrpStep': '00000691259998',
#    'minGrpStep': '00000689559997',
#    'prevPageNo': None,
#    'shiftTp': None,
#    'blockNo': 0,
#    'cnt': '151',
#    'deviceInfo': None,
#    'totalTp': False,
#    'note': None},
#   {'pageNo': None,
#    'pageSize': 15,
#    'totalCount': None,
#    'startRow': None,
#    'endRow': None,
#    'f_key': None,
#    'f_keyField': None,
#    'rnum': 0,
#    'seqid': 69091,
#    'scrnTp': 'BCOSZ',
#    'realno': 7,
#    'pareSeqid': 0,
#    'grp': 69091,
#    'artcDep': 1,
#    'step': 1,
#    'ttl': '답변요망이요',
#    'custId': '',
#    'custPsdn': 'yeee9***',
#    'mngrYn': 'N',
#    'ip': '175.123.44.208',
#    'readCnt': 8,
#    'dtlCntn': 'A=(15이평-종가)/종가*100\r\nB=(33이평-종가)/종가*100\r\n저는 이게 아니라 단순히 그냥 15이평과 33이평 가격차이가 1프로이내인 종목을 검색하고 싶은것입니다.\r\n\r\n그래서 원글에 예시를 ex) 15일선 1600원-33일선 1616원   /   15일선 1616원-33일선 1600원 이렇게 들었는데\r\n1600 숫자에 대한 1프로가 16이라 1616이라고 예시를 든거에요.\r\n이 내용에 대한것도 검색식이 없는걸까요?',
#    'makeTime': '2025.03.14 16:55',
#    'email': None,
#    'emailRecvTp': None,
#    'smsRecvTp': None,
#    'emailSendTime': None,
#    'telNo': None,
#    'smsSendtp': None,
#    'smsSendTime': None,
#    'docTp': '0',
#    'dltTp': '1',
#    'dltNm': None,
#    'dltId': None,
#    'dltRsn': None,
#    'dltTime': None,
#    'mdiaTp': None,
#    'divTp1': None,
#    'divTp2': None,
#    'rgstNm': None,
#    'recmCnt': 0,
#    'htsScrnNo': None,
#    'scrnTpNm': '조건검색 게시판',
#    'divTp1Nm': None,
#    'divTp2Nm': None,
#    'isNew': 'N',
#    'rk': 0,
#    'topCnt': None,
#    'topMaxCnt': None,
#    'nextScrnTp': 0,
#    'prevScrnTp': 0,
#    'nextTtl': 0,
#    'prevTtl': 0,
#    'nextSeqid': 0,
#    'prevSeqid': 0,
#    'imprLevl': None,
#    'attcFile': None,
#    'fileseq': 0,
#    'filenm': None,
#    'apndnm': None,
#    'wid': None,
#    'wname': None,
#    'searchTp': 0,
#    'pareDtlCntn': None,
#    'pareTtl': None,
#    'viewTp': None,
#    'f_scrnTp': None,
#    'checkId': None,
#    'pagePerBlock': None,
#    'maxGrpStep': '00000691259998',
#    'minGrpStep': '00000689559997',
#    'prevPageNo': None,
#    'shiftTp': None,
#    'blockNo': 0,
#    'cnt': '151',
#    'deviceInfo': None,
#    'totalTp': False,
#    'note': None},
#   {'pageNo': None,
#    'pageSize': 15,
#    'totalCount': None,
#    'startRow': None,
#    'endRow': None,
#    'f_key': None,
#    'f_keyField': None,
#    'rnum': 0,
#    'seqid': 69089,
#    'scrnTp': 'BCOSZ',
#    'realno': 5,
#    'pareSeqid': 0,
#    'grp': 69089,
#    'artcDep': 1,
#    'step': 1,
#    'ttl': '등락률 조건검색 문의',
#    'custId': '',
#    'custPsdn': 'vytnd***',
#    'mngrYn': 'N',
#    'ip': '211.193.13.120',
#    'readCnt': 23,
#    'dtlCntn': '안녕하세요,\r\n7일 이내 전일 종가 대비 20~30% 이상 주가가 올랐던 종목 검색식 부탁드립니다.',
#    'makeTime': '2025.03.14 16:46',
#    'email': None,
#    'emailRecvTp': None,
#    'smsRecvTp': None,
#    'emailSendTime': None,
#    'telNo': None,
#    'smsSendtp': None,
#    'smsSendTime': None,
#    'docTp': '0',
#    'dltTp': '1',
#    'dltNm': None,
#    'dltId': None,
#    'dltRsn': None,
#    'dltTime': None,
#    'mdiaTp': None,
#    'divTp1': None,
#    'divTp2': None,
#    'rgstNm': None,
#    'recmCnt': 0,
#    'htsScrnNo': None,
#    'scrnTpNm': '조건검색 게시판',
#    'divTp1Nm': None,
#    'divTp2Nm': None,
#    'isNew': 'N',
#    'rk': 0,
#    'topCnt': None,
#    'topMaxCnt': None,
#    'nextScrnTp': 0,
#    'prevScrnTp': 0,
#    'nextTtl': 0,
#    'prevTtl': 0,
#    'nextSeqid': 0,
#    'prevSeqid': 0,
#    'imprLevl': None,
#    'attcFile': None,
#    'fileseq': 0,
#    'filenm': None,
#    'apndnm': None,
#    'wid': None,
#    'wname': None,
#    'searchTp': 0,
#    'pareDtlCntn': None,
#    'pareTtl': None,
#    'viewTp': None,
#    'f_scrnTp': None,
#    'checkId': None,
#    'pagePerBlock': None,
#    'maxGrpStep': '00000691259998',
#    'minGrpStep': '00000689559997',
#    'prevPageNo': None,
#    'shiftTp': None,
#    'blockNo': 0,
#    'cnt': '151',
#    'deviceInfo': None,
#    'totalTp': False,
#    'note': None},
#   {'pageNo': None,
#    'pageSize': 15,
#    'totalCount': None,
#    'startRow': None,
#    'endRow': None,
#    'f_key': None,
#    'f_keyField': None,
#    'rnum': 0,
#    'seqid': 69090,
#    'scrnTp': 'BCOSZ',
#    'realno': 6,
#    'pareSeqid': 69089,
#    'grp': 69089,
#    'artcDep': 2,
#    'step': 2,
#    'ttl': '문의에 대한 답변입니다.',
#    'custId': '',
#    'custPsdn': '운영자6',
#    'mngrYn': 'Y',
#    'ip': '172.51.59.31',
#    'readCnt': 32,
#    'dtlCntn': '안녕하십니까. 키움증권 운영자입니다.\r\n먼저 키움증권에 관심을 가져주시고 이용해주시는 고객님께 감사 인사드립니다.\r\n\r\n아래의 조건식을 참고하여 주시기 바랍니다.\r\n\r\n시세분석 > 가격조건 > 기간내 등락률: [일]0봉전 7봉이내에서 전일종가대비종가 20%이상 \r\n\r\n감사합니다.\r\n\r\n<p align=center>- 서비스플랫폼팀 - </p>',
#    'makeTime': '2025.03.14 16:51',
#    'email': None,
#    'emailRecvTp': '1',
#    'smsRecvTp': '3',
#    'emailSendTime': '2025.03.14 16:51',
#    'telNo': None,
#    'smsSendtp': None,
#    'smsSendTime': None,
#    'docTp': '0',
#    'dltTp': '1',
#    'dltNm': None,
#    'dltId': None,
#    'dltRsn': None,
#    'dltTime': None,
#    'mdiaTp': None,
#    'divTp1': None,
#    'divTp2': None,
#    'rgstNm': None,
#    'recmCnt': 0,
#    'htsScrnNo': None,
#    'scrnTpNm': '조건검색 게시판',
#    'divTp1Nm': None,
#    'divTp2Nm': None,
#    'isNew': 'N',
#    'rk': 0,
#    'topCnt': None,
#    'topMaxCnt': None,
#    'nextScrnTp': 0,
#    'prevScrnTp': 0,
#    'nextTtl': 0,
#    'prevTtl': 0,
#    'nextSeqid': 0,
#    'prevSeqid': 0,
#    'imprLevl': None,
#    'attcFile': [],
#    'fileseq': 0,
#    'filenm': None,
#    'apndnm': None,
#    'wid': None,
#    'wname': None,
#    'searchTp': 0,
#    'pareDtlCntn': None,
#    'pareTtl': None,
#    'viewTp': None,
#    'f_scrnTp': None,
#    'checkId': None,
#    'pagePerBlock': None,
#    'maxGrpStep': '00000691259998',
#    'minGrpStep': '00000689559997',
#    'prevPageNo': None,
#    'shiftTp': None,
#    'blockNo': 0,
#    'cnt': '151',
#    'deviceInfo': None,
#    'totalTp': False,
#    'note': None},
#   {'pageNo': None,
#    'pageSize': 15,
#    'totalCount': None,
#    'startRow': None,
#    'endRow': None,
#    'f_key': None,
#    'f_keyField': None,
#    'rnum': 0,
#    'seqid': 69087,
#    'scrnTp': 'BCOSZ',
#    'realno': 3,
#    'pareSeqid': 0,
#    'grp': 69087,
#    'artcDep': 1,
#    'step': 1,
#    'ttl': '조건식 문의 드립니다.',
#    'custId': '',
#    'custPsdn': 'love8***',
#    'mngrYn': 'N',
#    'ip': '119.66.120.51',
#    'readCnt': 17,
#    'dtlCntn': '안녕하세요.\r\n\r\n조건식 문의 드립니다.\r\n\r\n\r\nㅁ 기본조건 \r\n     -  역배열 : 20 &lt; 60 &lt; 120 &lt; 240 이평선 \r\n     -  신저가 : 최근 20일 이내에 신저가 존재\r\n\r\n조건 문의 1) 20일 이평선을 돌파 할때 검색\r\n\r\n조건문의 2) 20일 이평선을 돌파 할때 검색\r\n     and 30분봉 기준 130봉이내 최고 거래량으로 갱신\r\n\r\n조건문의 3) 20일 이평선을 돌파 할때 검색\r\n     and 30분봉 기준 130봉이내 최고 거래량으로 갱신\r\n     and 최근 10봉 이내에 15일 이평선을 돌파 이력이 있음.\r\n\r\n혹시, 조건문의 3번이 안될까봐, 분할하여 문의 하였습니다.\r\n조건식 3번이 되면,  3번만 알려 주시면 됩니다.\r\n\r\n감사합니다.',
#    'makeTime': '2025.03.14 16:39',
#    'email': None,
#    'emailRecvTp': None,
#    'smsRecvTp': None,
#    'emailSendTime': None,
#    'telNo': None,
#    'smsSendtp': None,
#    'smsSendTime': None,
#    'docTp': '0',
#    'dltTp': '1',
#    'dltNm': None,
#    'dltId': None,
#    'dltRsn': None,
#    'dltTime': None,
#    'mdiaTp': None,
#    'divTp1': None,
#    'divTp2': None,
#    'rgstNm': None,
#    'recmCnt': 0,
#    'htsScrnNo': None,
#    'scrnTpNm': '조건검색 게시판',
#    'divTp1Nm': None,
#    'divTp2Nm': None,
#    'isNew': 'N',
#    'rk': 0,
#    'topCnt': None,
#    'topMaxCnt': None,
#    'nextScrnTp': 0,
#    'prevScrnTp': 0,
#    'nextTtl': 0,
#    'prevTtl': 0,
#    'nextSeqid': 0,
#    'prevSeqid': 0,
#    'imprLevl': None,
#    'attcFile': None,
#    'fileseq': 0,
#    'filenm': None,
#    'apndnm': None,
#    'wid': None,
#    'wname': None,
#    'searchTp': 0,
#    'pareDtlCntn': None,
#    'pareTtl': None,
#    'viewTp': None,
#    'f_scrnTp': None,
#    'checkId': None,
#    'pagePerBlock': None,
#    'maxGrpStep': '00000691259998',
#    'minGrpStep': '00000689559997',
#    'prevPageNo': None,
#    'shiftTp': None,
#    'blockNo': 0,
#    'cnt': '151',
#    'deviceInfo': None,
#    'totalTp': False,
#    'note': None},
#   {'pageNo': None,
#    'pageSize': 15,
#    'totalCount': None,
#    'startRow': None,
#    'endRow': None,
#    'f_key': None,
#    'f_keyField': None,
#    'rnum': 0,
#    'seqid': 69088,
#    'scrnTp': 'BCOSZ',
#    'realno': 4,
#    'pareSeqid': 69087,
#    'grp': 69087,
#    'artcDep': 2,
#    'step': 2,
#    'ttl': '문의에 대한 답변입니다.',
#    'custId': '',
#    'custPsdn': '운영자6',
#    'mngrYn': 'Y',
#    'ip': '172.51.59.31',
#    'readCnt': 18,
#    'dtlCntn': '안녕하십니까. 키움증권 운영자입니다.\r\n먼저 키움증권에 관심을 가져주시고 이용해주시는 고객님께 감사 인사드립니다.\r\n\r\n1.  신저가 : 최근 20일 이내에 신저가 존재\r\n=> 신저가를 계산하기 위해서는 기간수치가 특정되어야 합니다. \r\n(예: 최근 20일 이내에 100봉중 신저가)\r\n\r\n2. 각 조건을 주기가 [30분]주기 조건이 동일한 조건을 의미하는\r\n조건에 따라 주기가 다를 경우 각[주기]를 표기하여 주시기면  가능여부 확읺 안내하여 드리겠습니다. \r\n\r\n\r\n\r\n감사합니다.\r\n\r\n<p align=center>- 서비스플랫폼팀 - </p>',
#    'makeTime': '2025.03.14 16:45',
#    'email': None,
#    'emailRecvTp': '3',
#    'smsRecvTp': '3',
#    'emailSendTime': None,
#    'telNo': None,
#    'smsSendtp': None,
#    'smsSendTime': None,
#    'docTp': '0',
#    'dltTp': '1',
#    'dltNm': None,
#    'dltId': None,
#    'dltRsn': None,
#    'dltTime': None,
#    'mdiaTp': None,
#    'divTp1': None,
#    'divTp2': None,
#    'rgstNm': None,
#    'recmCnt': 0,
#    'htsScrnNo': None,
#    'scrnTpNm': '조건검색 게시판',
#    'divTp1Nm': None,
#    'divTp2Nm': None,
#    'isNew': 'N',
#    'rk': 0,
#    'topCnt': None,
#    'topMaxCnt': None,
#    'nextScrnTp': 0,
#    'prevScrnTp': 0,
#    'nextTtl': 0,
#    'prevTtl': 0,
#    'nextSeqid': 0,
#    'prevSeqid': 0,
#    'imprLevl': None,
#    'attcFile': [],
#    'fileseq': 0,
#    'filenm': None,
#    'apndnm': None,
#    'wid': None,
#    'wname': None,
#    'searchTp': 0,
#    'pareDtlCntn': None,
#    'pareTtl': None,
#    'viewTp': None,
#    'f_scrnTp': None,
#    'checkId': None,
#    'pagePerBlock': None,
#    'maxGrpStep': '00000691259998',
#    'minGrpStep': '00000689559997',
#    'prevPageNo': None,
#    'shiftTp': None,
#    'blockNo': 0,
#    'cnt': '151',
#    'deviceInfo': None,
#    'totalTp': False,
#    'note': None},
#   {'pageNo': None,
#    'pageSize': 15,
#    'totalCount': None,
#    'startRow': None,
#    'endRow': None,
#    'f_key': None,
#    'f_keyField': None,
#    'rnum': 0,
#    'seqid': 69095,
#    'scrnTp': 'BCOSZ',
#    'realno': 0,
#    'pareSeqid': 69088,
#    'grp': 69087,
#    'artcDep': 3,
#    'step': 3,
#    'ttl': '문의에 대한 답변입니다.',
#    'custId': '',
#    'custPsdn': 'love8***',
#    'mngrYn': 'N',
#    'ip': '122.43.255.117',
#    'readCnt': 11,
#    'dtlCntn': '안녕하세요?\r\n답변 감사드립니다.\r\n\r\n\r\n1.  신저가 : 최근 20일 이내에 신저가 존재\r\n==&gt; 최근 20일 이내에 100봉중 신저가\r\n\r\n2. 각 조건을 주기가 [30분]주기 조건이 동일한 조건을 의미하는\r\n조건에 따라 주기가 다를 경우 각[주기]를 표기하여 주시기면  가능여부 확읺 안내하여 드리겠습니다. \r\n==&gt; 30분 주기로 안내 부탁드립니다.',
#    'makeTime': '2025.03.14 22:07',
#    'email': None,
#    'emailRecvTp': None,
#    'smsRecvTp': None,
#    'emailSendTime': None,
#    'telNo': None,
#    'smsSendtp': None,
#    'smsSendTime': None,
#    'docTp': '0',
#    'dltTp': '1',
#    'dltNm': None,
#    'dltId': None,
#    'dltRsn': None,
#    'dltTime': None,
#    'mdiaTp': None,
#    'divTp1': None,
#    'divTp2': None,
#    'rgstNm': None,
#    'recmCnt': 0,
#    'htsScrnNo': None,
#    'scrnTpNm': '조건검색 게시판',
#    'divTp1Nm': None,
#    'divTp2Nm': None,
#    'isNew': 'N',
#    'rk': 0,
#    'topCnt': None,
#    'topMaxCnt': None,
#    'nextScrnTp': 0,
#    'prevScrnTp': 0,
#    'nextTtl': 0,
#    'prevTtl': 0,
#    'nextSeqid': 0,
#    'prevSeqid': 0,
#    'imprLevl': None,
#    'attcFile': None,
#    'fileseq': 0,
#    'filenm': None,
#    'apndnm': None,
#    'wid': None,
#    'wname': None,
#    'searchTp': 0,
#    'pareDtlCntn': None,
#    'pareTtl': None,
#    'viewTp': None,
#    'f_scrnTp': None,
#    'checkId': None,
#    'pagePerBlock': None,
#    'maxGrpStep': '00000691259998',
#    'minGrpStep': '00000689559997',
#    'prevPageNo': None,
#    'shiftTp': None,
#    'blockNo': 0,
#    'cnt': '151',
#    'deviceInfo': None,
#    'totalTp': False,
#    'note': None},
#   {'pageNo': None,
#    'pageSize': 15,
#    'totalCount': None,
#    'startRow': None,
#    'endRow': None,
#    'f_key': None,
#    'f_keyField': None,
#    'rnum': 0,
#    'seqid': 69085,
#    'scrnTp': 'BCOSZ',
#    'realno': 1,
#    'pareSeqid': 0,
#    'grp': 69085,
#    'artcDep': 1,
#    'step': 1,
#    'ttl': '일봉 이평선 조건검색',
#    'custId': '',
#    'custPsdn': 'sugar***',
#    'mngrYn': 'N',
#    'ip': '116.32.27.60',
#    'readCnt': 20,
#    'dtlCntn': '안녕하세요\r\n일봉기준 15일 이평선이 닿는 종목을 검색하려고 하는데\r\n아래 조건으로 조건검색식과 신호수식도 확인부탁드립니다.\r\n\r\n1. 일봉 이평선 20일선 &lt; 60일선 &lt; 120일선 (정배열)\r\n2. 이 종목들중에 15일선에 닿은 종목',
#    'makeTime': '2025.03.14 15:46',
#    'email': None,
#    'emailRecvTp': '3',
#    'smsRecvTp': '3',
#    'emailSendTime': None,
#    'telNo': None,
#    'smsSendtp': None,
#    'smsSendTime': None,
#    'docTp': '0',
#    'dltTp': '1',
#    'dltNm': None,
#    'dltId': None,
#    'dltRsn': None,
#    'dltTime': None,
#    'mdiaTp': None,
#    'divTp1': None,
#    'divTp2': None,
#    'rgstNm': None,
#    'recmCnt': 0,
#    'htsScrnNo': None,
#    'scrnTpNm': '조건검색 게시판',
#    'divTp1Nm': None,
#    'divTp2Nm': None,
#    'isNew': 'N',
#    'rk': 0,
#    'topCnt': None,
#    'topMaxCnt': None,
#    'nextScrnTp': 0,
#    'prevScrnTp': 0,
#    'nextTtl': 0,
#    'prevTtl': 0,
#    'nextSeqid': 0,
#    'prevSeqid': 0,
#    'imprLevl': None,
#    'attcFile': None,
#    'fileseq': 0,
#    'filenm': None,
#    'apndnm': None,
#    'wid': None,
#    'wname': None,
#    'searchTp': 0,
#    'pareDtlCntn': None,
#    'pareTtl': None,
#    'viewTp': None,
#    'f_scrnTp': None,
#    'checkId': None,
#    'pagePerBlock': None,
#    'maxGrpStep': '00000691259998',
#    'minGrpStep': '00000689559997',
#    'prevPageNo': None,
#    'shiftTp': None,
#    'blockNo': 0,
#    'cnt': '151',
#    'deviceInfo': None,
#    'totalTp': False,
#    'note': None},
#   {'pageNo': None,
#    'pageSize': 15,
#    'totalCount': None,
#    'startRow': None,
#    'endRow': None,
#    'f_key': None,
#    'f_keyField': None,
#    'rnum': 0,
#    'seqid': 69086,
#    'scrnTp': 'BCOSZ',
#    'realno': 2,
#    'pareSeqid': 69085,
#    'grp': 69085,
#    'artcDep': 2,
#    'step': 2,
#    'ttl': '문의에 대한 답변입니다.',
#    'custId': '',
#    'custPsdn': '운영자6',
#    'mngrYn': 'Y',
#    'ip': '172.51.59.31',
#    'readCnt': 32,
#    'dtlCntn': '안녕하십니까. 키움증권 운영자입니다.\r\n먼저 키움증권에 관심을 가져주시고 이용해주시는 고객님께 감사 인사드립니다.\r\n\r\n아래의 수식을 참고하여 주시기 바랍니다\r\n\r\nA:기술적분석 > 주가이동평균 > 주가이동평균배열(3개):[일]0봉전 20이평 < 60이평 < 120이평 \r\nB:기술적분석 > 주가이동평균> 주가이동평균돌파:[일]0봉전 (종가 1)이평 (종가 15)이평 골든크로스 \r\n\r\nA and B\r\n\r\n수식및 차트관련 문의는 고객게시판 또는 영웅문4 게시판을 이용 부탁드립니다. \r\n\r\n감사합니다.\r\n\r\n<p align=center>- 서비스플랫폼팀 - </p>',
#    'makeTime': '2025.03.14 15:51',
#    'email': None,
#    'emailRecvTp': '3',
#    'smsRecvTp': '3',
#    'emailSendTime': None,
#    'telNo': None,
#    'smsSendtp': None,
#    'smsSendTime': None,
#    'docTp': '0',
#    'dltTp': '1',
#    'dltNm': None,
#    'dltId': None,
#    'dltRsn': None,
#    'dltTime': None,
#    'mdiaTp': None,
#    'divTp1': None,
#    'divTp2': None,
#    'rgstNm': None,
#    'recmCnt': 0,
#    'htsScrnNo': None,
#    'scrnTpNm': '조건검색 게시판',
#    'divTp1Nm': None,
#    'divTp2Nm': None,
#    'isNew': 'N',
#    'rk': 0,
#    'topCnt': None,
#    'topMaxCnt': None,
#    'nextScrnTp': 0,
#    'prevScrnTp': 0,
#    'nextTtl': 0,
#    'prevTtl': 0,
#    'nextSeqid': 0,
#    'prevSeqid': 0,
#    'imprLevl': None,
#    'attcFile': [],
#    'fileseq': 0,
#    'filenm': None,
#    'apndnm': None,
#    'wid': None,
#    'wname': None,
#    'searchTp': 0,
#    'pareDtlCntn': None,
#    'pareTtl': None,
#    'viewTp': None,
#    'f_scrnTp': None,
#    'checkId': None,
#    'pagePerBlock': None,
#    'maxGrpStep': '00000691259998',
#    'minGrpStep': '00000689559997',
#    'prevPageNo': None,
#    'shiftTp': None,
#    'blockNo': 0,
#    'cnt': '151',
#    'deviceInfo': None,
#    'totalTp': False,
#    'note': None},
#   {'pageNo': None,
#    'pageSize': 15,
#    'totalCount': None,
#    'startRow': None,
#    'endRow': None,
#    'f_key': None,
#    'f_keyField': None,
#    'rnum': 0,
#    'seqid': 69079,
#    'scrnTp': 'BCOSZ',
#    'realno': 27,
#    'pareSeqid': 0,
#    'grp': 69079,
#    'artcDep': 1,
#    'step': 1,
#    'ttl': '프로그램 순매수량 + 분봉 차트',
#    'custId': '',
#    'custPsdn': 'eunga***',
#    'mngrYn': 'N',
#    'ip': '211.104.158.146',
#    'readCnt': 15,
#    'dtlCntn': '안녕하세요,\r\n\r\n분봉차트에\r\n\r\n프로그램 순매수량이나 금액을 보조지표로 추가할 수 있는 조건식 있을까요?',
#    'makeTime': '2025.03.14 14:55',
#    'email': None,
#    'emailRecvTp': None,
#    'smsRecvTp': None,
#    'emailSendTime': None,
#    'telNo': None,
#    'smsSendtp': None,
#    'smsSendTime': None,
#    'docTp': '0',
#    'dltTp': '1',
#    'dltNm': None,
#    'dltId': None,
#    'dltRsn': None,
#    'dltTime': None,
#    'mdiaTp': None,
#    'divTp1': None,
#    'divTp2': None,
#    'rgstNm': None,
#    'recmCnt': 0,
#    'htsScrnNo': None,
#    'scrnTpNm': '조건검색 게시판',
#    'divTp1Nm': None,
#    'divTp2Nm': None,
#    'isNew': 'N',
#    'rk': 0,
#    'topCnt': None,
#    'topMaxCnt': None,
#    'nextScrnTp': 0,
#    'prevScrnTp': 0,
#    'nextTtl': 0,
#    'prevTtl': 0,
#    'nextSeqid': 0,
#    'prevSeqid': 0,
#    'imprLevl': None,
#    'attcFile': None,
#    'fileseq': 0,
#    'filenm': None,
#    'apndnm': None,
#    'wid': None,
#    'wname': None,
#    'searchTp': 0,
#    'pareDtlCntn': None,
#    'pareTtl': None,
#    'viewTp': None,
#    'f_scrnTp': None,
#    'checkId': None,
#    'pagePerBlock': None,
#    'maxGrpStep': '00000691259998',
#    'minGrpStep': '00000689559997',
#    'prevPageNo': None,
#    'shiftTp': None,
#    'blockNo': 0,
#    'cnt': '151',
#    'deviceInfo': None,
#    'totalTp': False,
#    'note': None}],
#  'totalCount': 0}

# %%
data['boardList']
# Out:
# [{'pageNo': None,
#   'pageSize': 15,
#   'totalCount': None,
#   'startRow': None,
#   'endRow': None,
#   'f_key': None,
#   'f_keyField': None,
#   'rnum': 0,
#   'seqid': 69099,
#   'scrnTp': 'BCOSZ',
#   'realno': 4,
#   'pareSeqid': 0,
#   'grp': 69099,
#   'artcDep': 1,
#   'step': 1,
#   'ttl': '렌코차트에 다른 보조지표를 추가할 수 있나요?',
#   'custId': '',
#   'custPsdn': 'pds8***',
#   'mngrYn': 'N',
#   'ip': '221.145.73.187',
#   'readCnt': 1,
#   'dtlCntn': '지표를 추가해도 보여지지 않습니다...메모리 문제인지?',
#   'makeTime': '2025.03.15 11:09',
#   'email': None,
#   'emailRecvTp': None,
#   'smsRecvTp': None,
#   'emailSendTime': None,
#   'telNo': None,
#   'smsSendtp': None,
#   'smsSendTime': None,
#   'docTp': '0',
#   'dltTp': '1',
#   'dltNm': None,
#   'dltId': None,
#   'dltRsn': None,
#   'dltTime': None,
#   'mdiaTp': None,
#   'divTp1': None,
#   'divTp2': None,
#   'rgstNm': None,
#   'recmCnt': 0,
#   'htsScrnNo': None,
#   'scrnTpNm': '조건검색 게시판',
#   'divTp1Nm': None,
#   'divTp2Nm': None,
#   'isNew': 'Y',
#   'rk': 0,
#   'topCnt': None,
#   'topMaxCnt': None,
#   'nextScrnTp': 0,
#   'prevScrnTp': 0,
#   'nextTtl': 0,
#   'prevTtl': 0,
#   'nextSeqid': 0,
#   'prevSeqid': 0,
#   'imprLevl': None,
#   'attcFile': None,
#   'fileseq': 0,
#   'filenm': None,
#   'apndnm': None,
#   'wid': None,
#   'wname': None,
#   'searchTp': 0,
#   'pareDtlCntn': None,
#   'pareTtl': None,
#   'viewTp': None,
#   'f_scrnTp': None,
#   'checkId': None,
#   'pagePerBlock': None,
#   'maxGrpStep': '00000691259998',
#   'minGrpStep': '00000689559997',
#   'prevPageNo': None,
#   'shiftTp': None,
#   'blockNo': 0,
#   'cnt': '151',
#   'deviceInfo': None,
#   'totalTp': False,
#   'note': None},
#  {'pageNo': None,
#   'pageSize': 15,
#   'totalCount': None,
#   'startRow': None,
#   'endRow': None,
#   'f_key': None,
#   'f_keyField': None,
#   'rnum': 0,
#   'seqid': 69098,
#   'scrnTp': 'BCOSZ',
#   'realno': 3,
#   'pareSeqid': 0,
#   'grp': 69098,
#   'artcDep': 1,
#   'step': 1,
#   'ttl': '평균거래대금 조건검색',
#   'custId': '',
#   'custPsdn': '동방',
#   'mngrYn': 'N',
#   'ip': '122.43.132.92',
#   'readCnt': 10,
#   'dtlCntn': '직전20봉 평균보다 현재봉이 1000%상승한조건식',
#   'makeTime': '2025.03.15 07:54',
#   'email': None,
#   'emailRecvTp': None,
#   'smsRecvTp': None,
#   'emailSendTime': None,
#   'telNo': None,
#   'smsSendtp': None,
#   'smsSendTime': None,
#   'docTp': '0',
#   'dltTp': '1',
#   'dltNm': None,
#   'dltId': None,
#   'dltRsn': None,
#   'dltTime': None,
#   'mdiaTp': None,
#   'divTp1': None,
#   'divTp2': None,
#   'rgstNm': None,
#   'recmCnt': 0,
#   'htsScrnNo': None,
#   'scrnTpNm': '조건검색 게시판',
#   'divTp1Nm': None,
#   'divTp2Nm': None,
#   'isNew': 'Y',
#   'rk': 0,
#   'topCnt': None,
#   'topMaxCnt': None,
#   'nextScrnTp': 0,
#   'prevScrnTp': 0,
#   'nextTtl': 0,
#   'prevTtl': 0,
#   'nextSeqid': 0,
#   'prevSeqid': 0,
#   'imprLevl': None,
#   'attcFile': None,
#   'fileseq': 0,
#   'filenm': None,
#   'apndnm': None,
#   'wid': None,
#   'wname': None,
#   'searchTp': 0,
#   'pareDtlCntn': None,
#   'pareTtl': None,
#   'viewTp': None,
#   'f_scrnTp': None,
#   'checkId': None,
#   'pagePerBlock': None,
#   'maxGrpStep': '00000691259998',
#   'minGrpStep': '00000689559997',
#   'prevPageNo': None,
#   'shiftTp': None,
#   'blockNo': 0,
#   'cnt': '151',
#   'deviceInfo': None,
#   'totalTp': False,
#   'note': None},
#  {'pageNo': None,
#   'pageSize': 15,
#   'totalCount': None,
#   'startRow': None,
#   'endRow': None,
#   'f_key': None,
#   'f_keyField': None,
#   'rnum': 0,
#   'seqid': 69097,
#   'scrnTp': 'BCOSZ',
#   'realno': 2,
#   'pareSeqid': 0,
#   'grp': 69097,
#   'artcDep': 1,
#   'step': 1,
#   'ttl': '조건검색식 부탁드립니다.',
#   'custId': '',
#   'custPsdn': 'ath***',
#   'mngrYn': 'N',
#   'ip': '1.248.117.8',
#   'readCnt': 17,
#   'dtlCntn': '안녕하세요?\r\n\r\n조건검색식 작성시 패턴분석-패턴정의에서\r\n아래의 조건에 맞는 조건식을 구현하고 싶습니다.\r\n\r\n1. 양봉이며, 종가[현재가]와 고가가 같은 조건식 구현방법\r\n2. 양봉이며, 현재가가 고가의 95% 이상인 조건식 구현방법\r\n   [즉 꼬리가 작은 캔들 모양을 패턴정의로 검색하고 싶습니다.]\r\n\r\n아래와 같은 조건식에서 고가등락률 5% 이상은 어떤의미[어떤 모양의 캔들] 인가요?\r\n\r\nA:시세분석 &gt; 가격조건 &gt; 주가비교:[일]0봉전 시가 &lt; 0봉전 종가\r\nB:시세분석 &gt; 가격조건 &gt; 주가등락률:[일]0봉전(중) 종가대비 0봉전 고가등락률 5%이상\r\n(A and B)\r\n\r\n감사합니다.',
#   'makeTime': '2025.03.15 00:39',
#   'email': None,
#   'emailRecvTp': '3',
#   'smsRecvTp': '3',
#   'emailSendTime': None,
#   'telNo': None,
#   'smsSendtp': None,
#   'smsSendTime': None,
#   'docTp': '0',
#   'dltTp': '1',
#   'dltNm': None,
#   'dltId': None,
#   'dltRsn': None,
#   'dltTime': None,
#   'mdiaTp': None,
#   'divTp1': None,
#   'divTp2': None,
#   'rgstNm': None,
#   'recmCnt': 0,
#   'htsScrnNo': None,
#   'scrnTpNm': '조건검색 게시판',
#   'divTp1Nm': None,
#   'divTp2Nm': None,
#   'isNew': 'Y',
#   'rk': 0,
#   'topCnt': None,
#   'topMaxCnt': None,
#   'nextScrnTp': 0,
#   'prevScrnTp': 0,
#   'nextTtl': 0,
#   'prevTtl': 0,
#   'nextSeqid': 0,
#   'prevSeqid': 0,
#   'imprLevl': None,
#   'attcFile': None,
#   'fileseq': 0,
#   'filenm': None,
#   'apndnm': None,
#   'wid': None,
#   'wname': None,
#   'searchTp': 0,
#   'pareDtlCntn': None,
#   'pareTtl': None,
#   'viewTp': None,
#   'f_scrnTp': None,
#   'checkId': None,
#   'pagePerBlock': None,
#   'maxGrpStep': '00000691259998',
#   'minGrpStep': '00000689559997',
#   'prevPageNo': None,
#   'shiftTp': None,
#   'blockNo': 0,
#   'cnt': '151',
#   'deviceInfo': None,
#   'totalTp': False,
#   'note': None},
#  {'pageNo': None,
#   'pageSize': 15,
#   'totalCount': None,
#   'startRow': None,
#   'endRow': None,
#   'f_key': None,
#   'f_keyField': None,
#   'rnum': 0,
#   'seqid': 69096,
#   'scrnTp': 'BCOSZ',
#   'realno': 1,
#   'pareSeqid': 0,
#   'grp': 69096,
#   'artcDep': 1,
#   'step': 1,
#   'ttl': '안녕하세요.',
#   'custId': '',
#   'custPsdn': 'mdmu***',
#   'mngrYn': 'N',
#   'ip': '182.221.199.240',
#   'readCnt': 9,
#   'dtlCntn': '스토캐스틱 매수 신호:CrossUp(StochasticsSlow(Period1,Period2),buyLevel)\r\n기간1:20 기간2:5 이구요. 제가 묻고저 하는것은 여기서 buylevel이 무슨 뜻이지요? \r\n\r\nstochastic(slow) 를 선택 "기준값 돌파" %K  20으로 설정  하여도 신호가 검색되지 않습니다.\r\n\r\n신호를 검색할 수 있는 조건검색식 부탁드립니다.',
#   'makeTime': '2025.03.14 23:35',
#   'email': None,
#   'emailRecvTp': None,
#   'smsRecvTp': None,
#   'emailSendTime': None,
#   'telNo': None,
#   'smsSendtp': None,
#   'smsSendTime': None,
#   'docTp': '0',
#   'dltTp': '1',
#   'dltNm': None,
#   'dltId': None,
#   'dltRsn': None,
#   'dltTime': None,
#   'mdiaTp': None,
#   'divTp1': None,
#   'divTp2': None,
#   'rgstNm': None,
#   'recmCnt': 0,
#   'htsScrnNo': None,
#   'scrnTpNm': '조건검색 게시판',
#   'divTp1Nm': None,
#   'divTp2Nm': None,
#   'isNew': 'N',
#   'rk': 0,
#   'topCnt': None,
#   'topMaxCnt': None,
#   'nextScrnTp': 0,
#   'prevScrnTp': 0,
#   'nextTtl': 0,
#   'prevTtl': 0,
#   'nextSeqid': 0,
#   'prevSeqid': 0,
#   'imprLevl': None,
#   'attcFile': None,
#   'fileseq': 0,
#   'filenm': None,
#   'apndnm': None,
#   'wid': None,
#   'wname': None,
#   'searchTp': 0,
#   'pareDtlCntn': None,
#   'pareTtl': None,
#   'viewTp': None,
#   'f_scrnTp': None,
#   'checkId': None,
#   'pagePerBlock': None,
#   'maxGrpStep': '00000691259998',
#   'minGrpStep': '00000689559997',
#   'prevPageNo': None,
#   'shiftTp': None,
#   'blockNo': 0,
#   'cnt': '151',
#   'deviceInfo': None,
#   'totalTp': False,
#   'note': None},
#  {'pageNo': None,
#   'pageSize': 15,
#   'totalCount': None,
#   'startRow': None,
#   'endRow': None,
#   'f_key': None,
#   'f_keyField': None,
#   'rnum': 0,
#   'seqid': 69094,
#   'scrnTp': 'BCOSZ',
#   'realno': 10,
#   'pareSeqid': 0,
#   'grp': 69094,
#   'artcDep': 1,
#   'step': 1,
#   'ttl': '조건검색식의 차이점',
#   'custId': '',
#   'custPsdn': 'land***',
#   'mngrYn': 'N',
#   'ip': '211.202.137.238',
#   'readCnt': 11,
#   'dtlCntn': '안녕하세요,\r\n시세분석-기술적분석-주가이동평균에서 \r\n주가이동평균등락률이 있는데 무슨 검색식인지 잘 몰라서 여쭙습니다. \r\nex) 10봉전(중) 종가 20이평대비 \r\n          5봉전 종가 5이평등락률 10~20% 라고 가정했을때로 설명 한번 부탁드립니다.',
#   'makeTime': '2025.03.14 20:44',
#   'email': None,
#   'emailRecvTp': None,
#   'smsRecvTp': None,
#   'emailSendTime': None,
#   'telNo': None,
#   'smsSendtp': None,
#   'smsSendTime': None,
#   'docTp': '0',
#   'dltTp': '1',
#   'dltNm': None,
#   'dltId': None,
#   'dltRsn': None,
#   'dltTime': None,
#   'mdiaTp': None,
#   'divTp1': None,
#   'divTp2': None,
#   'rgstNm': None,
#   'recmCnt': 0,
#   'htsScrnNo': None,
#   'scrnTpNm': '조건검색 게시판',
#   'divTp1Nm': None,
#   'divTp2Nm': None,
#   'isNew': 'N',
#   'rk': 0,
#   'topCnt': None,
#   'topMaxCnt': None,
#   'nextScrnTp': 0,
#   'prevScrnTp': 0,
#   'nextTtl': 0,
#   'prevTtl': 0,
#   'nextSeqid': 0,
#   'prevSeqid': 0,
#   'imprLevl': None,
#   'attcFile': None,
#   'fileseq': 0,
#   'filenm': None,
#   'apndnm': None,
#   'wid': None,
#   'wname': None,
#   'searchTp': 0,
#   'pareDtlCntn': None,
#   'pareTtl': None,
#   'viewTp': None,
#   'f_scrnTp': None,
#   'checkId': None,
#   'pagePerBlock': None,
#   'maxGrpStep': '00000691259998',
#   'minGrpStep': '00000689559997',
#   'prevPageNo': None,
#   'shiftTp': None,
#   'blockNo': 0,
#   'cnt': '151',
#   'deviceInfo': None,
#   'totalTp': False,
#   'note': None},
#  {'pageNo': None,
#   'pageSize': 15,
#   'totalCount': None,
#   'startRow': None,
#   'endRow': None,
#   'f_key': None,
#   'f_keyField': None,
#   'rnum': 0,
#   'seqid': 69093,
#   'scrnTp': 'BCOSZ',
#   'realno': 9,
#   'pareSeqid': 0,
#   'grp': 69093,
#   'artcDep': 1,
#   'step': 1,
#   'ttl': '조건 검색 문의드립니다.',
#   'custId': '',
#   'custPsdn': 'joonk***',
#   'mngrYn': 'N',
#   'ip': '125.131.16.48',
#   'readCnt': 14,
#   'dtlCntn': '안녕하세요\r\n\r\n분봉에서 " dayhigh() " 를 돌파하는 검색식을 구현하고 싶습니다. \r\n\r\n가능할까요?\r\n\r\n감사합니다.',
#   'makeTime': '2025.03.14 17:51',
#   'email': None,
#   'emailRecvTp': '3',
#   'smsRecvTp': '3',
#   'emailSendTime': None,
#   'telNo': None,
#   'smsSendtp': None,
#   'smsSendTime': None,
#   'docTp': '0',
#   'dltTp': '1',
#   'dltNm': None,
#   'dltId': None,
#   'dltRsn': None,
#   'dltTime': None,
#   'mdiaTp': None,
#   'divTp1': None,
#   'divTp2': None,
#   'rgstNm': None,
#   'recmCnt': 0,
#   'htsScrnNo': None,
#   'scrnTpNm': '조건검색 게시판',
#   'divTp1Nm': None,
#   'divTp2Nm': None,
#   'isNew': 'N',
#   'rk': 0,
#   'topCnt': None,
#   'topMaxCnt': None,
#   'nextScrnTp': 0,
#   'prevScrnTp': 0,
#   'nextTtl': 0,
#   'prevTtl': 0,
#   'nextSeqid': 0,
#   'prevSeqid': 0,
#   'imprLevl': None,
#   'attcFile': None,
#   'fileseq': 0,
#   'filenm': None,
#   'apndnm': None,
#   'wid': None,
#   'wname': None,
#   'searchTp': 0,
#   'pareDtlCntn': None,
#   'pareTtl': None,
#   'viewTp': None,
#   'f_scrnTp': None,
#   'checkId': None,
#   'pagePerBlock': None,
#   'maxGrpStep': '00000691259998',
#   'minGrpStep': '00000689559997',
#   'prevPageNo': None,
#   'shiftTp': None,
#   'blockNo': 0,
#   'cnt': '151',
#   'deviceInfo': None,
#   'totalTp': False,
#   'note': None},
#  {'pageNo': None,
#   'pageSize': 15,
#   'totalCount': None,
#   'startRow': None,
#   'endRow': None,
#   'f_key': None,
#   'f_keyField': None,
#   'rnum': 0,
#   'seqid': 69091,
#   'scrnTp': 'BCOSZ',
#   'realno': 7,
#   'pareSeqid': 0,
#   'grp': 69091,
#   'artcDep': 1,
#   'step': 1,
#   'ttl': '답변요망이요',
#   'custId': '',
#   'custPsdn': 'yeee9***',
#   'mngrYn': 'N',
#   'ip': '175.123.44.208',
#   'readCnt': 8,
#   'dtlCntn': 'A=(15이평-종가)/종가*100\r\nB=(33이평-종가)/종가*100\r\n저는 이게 아니라 단순히 그냥 15이평과 33이평 가격차이가 1프로이내인 종목을 검색하고 싶은것입니다.\r\n\r\n그래서 원글에 예시를 ex) 15일선 1600원-33일선 1616원   /   15일선 1616원-33일선 1600원 이렇게 들었는데\r\n1600 숫자에 대한 1프로가 16이라 1616이라고 예시를 든거에요.\r\n이 내용에 대한것도 검색식이 없는걸까요?',
#   'makeTime': '2025.03.14 16:55',
#   'email': None,
#   'emailRecvTp': None,
#   'smsRecvTp': None,
#   'emailSendTime': None,
#   'telNo': None,
#   'smsSendtp': None,
#   'smsSendTime': None,
#   'docTp': '0',
#   'dltTp': '1',
#   'dltNm': None,
#   'dltId': None,
#   'dltRsn': None,
#   'dltTime': None,
#   'mdiaTp': None,
#   'divTp1': None,
#   'divTp2': None,
#   'rgstNm': None,
#   'recmCnt': 0,
#   'htsScrnNo': None,
#   'scrnTpNm': '조건검색 게시판',
#   'divTp1Nm': None,
#   'divTp2Nm': None,
#   'isNew': 'N',
#   'rk': 0,
#   'topCnt': None,
#   'topMaxCnt': None,
#   'nextScrnTp': 0,
#   'prevScrnTp': 0,
#   'nextTtl': 0,
#   'prevTtl': 0,
#   'nextSeqid': 0,
#   'prevSeqid': 0,
#   'imprLevl': None,
#   'attcFile': None,
#   'fileseq': 0,
#   'filenm': None,
#   'apndnm': None,
#   'wid': None,
#   'wname': None,
#   'searchTp': 0,
#   'pareDtlCntn': None,
#   'pareTtl': None,
#   'viewTp': None,
#   'f_scrnTp': None,
#   'checkId': None,
#   'pagePerBlock': None,
#   'maxGrpStep': '00000691259998',
#   'minGrpStep': '00000689559997',
#   'prevPageNo': None,
#   'shiftTp': None,
#   'blockNo': 0,
#   'cnt': '151',
#   'deviceInfo': None,
#   'totalTp': False,
#   'note': None},
#  {'pageNo': None,
#   'pageSize': 15,
#   'totalCount': None,
#   'startRow': None,
#   'endRow': None,
#   'f_key': None,
#   'f_keyField': None,
#   'rnum': 0,
#   'seqid': 69089,
#   'scrnTp': 'BCOSZ',
#   'realno': 5,
#   'pareSeqid': 0,
#   'grp': 69089,
#   'artcDep': 1,
#   'step': 1,
#   'ttl': '등락률 조건검색 문의',
#   'custId': '',
#   'custPsdn': 'vytnd***',
#   'mngrYn': 'N',
#   'ip': '211.193.13.120',
#   'readCnt': 23,
#   'dtlCntn': '안녕하세요,\r\n7일 이내 전일 종가 대비 20~30% 이상 주가가 올랐던 종목 검색식 부탁드립니다.',
#   'makeTime': '2025.03.14 16:46',
#   'email': None,
#   'emailRecvTp': None,
#   'smsRecvTp': None,
#   'emailSendTime': None,
#   'telNo': None,
#   'smsSendtp': None,
#   'smsSendTime': None,
#   'docTp': '0',
#   'dltTp': '1',
#   'dltNm': None,
#   'dltId': None,
#   'dltRsn': None,
#   'dltTime': None,
#   'mdiaTp': None,
#   'divTp1': None,
#   'divTp2': None,
#   'rgstNm': None,
#   'recmCnt': 0,
#   'htsScrnNo': None,
#   'scrnTpNm': '조건검색 게시판',
#   'divTp1Nm': None,
#   'divTp2Nm': None,
#   'isNew': 'N',
#   'rk': 0,
#   'topCnt': None,
#   'topMaxCnt': None,
#   'nextScrnTp': 0,
#   'prevScrnTp': 0,
#   'nextTtl': 0,
#   'prevTtl': 0,
#   'nextSeqid': 0,
#   'prevSeqid': 0,
#   'imprLevl': None,
#   'attcFile': None,
#   'fileseq': 0,
#   'filenm': None,
#   'apndnm': None,
#   'wid': None,
#   'wname': None,
#   'searchTp': 0,
#   'pareDtlCntn': None,
#   'pareTtl': None,
#   'viewTp': None,
#   'f_scrnTp': None,
#   'checkId': None,
#   'pagePerBlock': None,
#   'maxGrpStep': '00000691259998',
#   'minGrpStep': '00000689559997',
#   'prevPageNo': None,
#   'shiftTp': None,
#   'blockNo': 0,
#   'cnt': '151',
#   'deviceInfo': None,
#   'totalTp': False,
#   'note': None},
#  {'pageNo': None,
#   'pageSize': 15,
#   'totalCount': None,
#   'startRow': None,
#   'endRow': None,
#   'f_key': None,
#   'f_keyField': None,
#   'rnum': 0,
#   'seqid': 69090,
#   'scrnTp': 'BCOSZ',
#   'realno': 6,
#   'pareSeqid': 69089,
#   'grp': 69089,
#   'artcDep': 2,
#   'step': 2,
#   'ttl': '문의에 대한 답변입니다.',
#   'custId': '',
#   'custPsdn': '운영자6',
#   'mngrYn': 'Y',
#   'ip': '172.51.59.31',
#   'readCnt': 32,
#   'dtlCntn': '안녕하십니까. 키움증권 운영자입니다.\r\n먼저 키움증권에 관심을 가져주시고 이용해주시는 고객님께 감사 인사드립니다.\r\n\r\n아래의 조건식을 참고하여 주시기 바랍니다.\r\n\r\n시세분석 > 가격조건 > 기간내 등락률: [일]0봉전 7봉이내에서 전일종가대비종가 20%이상 \r\n\r\n감사합니다.\r\n\r\n<p align=center>- 서비스플랫폼팀 - </p>',
#   'makeTime': '2025.03.14 16:51',
#   'email': None,
#   'emailRecvTp': '1',
#   'smsRecvTp': '3',
#   'emailSendTime': '2025.03.14 16:51',
#   'telNo': None,
#   'smsSendtp': None,
#   'smsSendTime': None,
#   'docTp': '0',
#   'dltTp': '1',
#   'dltNm': None,
#   'dltId': None,
#   'dltRsn': None,
#   'dltTime': None,
#   'mdiaTp': None,
#   'divTp1': None,
#   'divTp2': None,
#   'rgstNm': None,
#   'recmCnt': 0,
#   'htsScrnNo': None,
#   'scrnTpNm': '조건검색 게시판',
#   'divTp1Nm': None,
#   'divTp2Nm': None,
#   'isNew': 'N',
#   'rk': 0,
#   'topCnt': None,
#   'topMaxCnt': None,
#   'nextScrnTp': 0,
#   'prevScrnTp': 0,
#   'nextTtl': 0,
#   'prevTtl': 0,
#   'nextSeqid': 0,
#   'prevSeqid': 0,
#   'imprLevl': None,
#   'attcFile': [],
#   'fileseq': 0,
#   'filenm': None,
#   'apndnm': None,
#   'wid': None,
#   'wname': None,
#   'searchTp': 0,
#   'pareDtlCntn': None,
#   'pareTtl': None,
#   'viewTp': None,
#   'f_scrnTp': None,
#   'checkId': None,
#   'pagePerBlock': None,
#   'maxGrpStep': '00000691259998',
#   'minGrpStep': '00000689559997',
#   'prevPageNo': None,
#   'shiftTp': None,
#   'blockNo': 0,
#   'cnt': '151',
#   'deviceInfo': None,
#   'totalTp': False,
#   'note': None},
#  {'pageNo': None,
#   'pageSize': 15,
#   'totalCount': None,
#   'startRow': None,
#   'endRow': None,
#   'f_key': None,
#   'f_keyField': None,
#   'rnum': 0,
#   'seqid': 69087,
#   'scrnTp': 'BCOSZ',
#   'realno': 3,
#   'pareSeqid': 0,
#   'grp': 69087,
#   'artcDep': 1,
#   'step': 1,
#   'ttl': '조건식 문의 드립니다.',
#   'custId': '',
#   'custPsdn': 'love8***',
#   'mngrYn': 'N',
#   'ip': '119.66.120.51',
#   'readCnt': 17,
#   'dtlCntn': '안녕하세요.\r\n\r\n조건식 문의 드립니다.\r\n\r\n\r\nㅁ 기본조건 \r\n     -  역배열 : 20 &lt; 60 &lt; 120 &lt; 240 이평선 \r\n     -  신저가 : 최근 20일 이내에 신저가 존재\r\n\r\n조건 문의 1) 20일 이평선을 돌파 할때 검색\r\n\r\n조건문의 2) 20일 이평선을 돌파 할때 검색\r\n     and 30분봉 기준 130봉이내 최고 거래량으로 갱신\r\n\r\n조건문의 3) 20일 이평선을 돌파 할때 검색\r\n     and 30분봉 기준 130봉이내 최고 거래량으로 갱신\r\n     and 최근 10봉 이내에 15일 이평선을 돌파 이력이 있음.\r\n\r\n혹시, 조건문의 3번이 안될까봐, 분할하여 문의 하였습니다.\r\n조건식 3번이 되면,  3번만 알려 주시면 됩니다.\r\n\r\n감사합니다.',
#   'makeTime': '2025.03.14 16:39',
#   'email': None,
#   'emailRecvTp': None,
#   'smsRecvTp': None,
#   'emailSendTime': None,
#   'telNo': None,
#   'smsSendtp': None,
#   'smsSendTime': None,
#   'docTp': '0',
#   'dltTp': '1',
#   'dltNm': None,
#   'dltId': None,
#   'dltRsn': None,
#   'dltTime': None,
#   'mdiaTp': None,
#   'divTp1': None,
#   'divTp2': None,
#   'rgstNm': None,
#   'recmCnt': 0,
#   'htsScrnNo': None,
#   'scrnTpNm': '조건검색 게시판',
#   'divTp1Nm': None,
#   'divTp2Nm': None,
#   'isNew': 'N',
#   'rk': 0,
#   'topCnt': None,
#   'topMaxCnt': None,
#   'nextScrnTp': 0,
#   'prevScrnTp': 0,
#   'nextTtl': 0,
#   'prevTtl': 0,
#   'nextSeqid': 0,
#   'prevSeqid': 0,
#   'imprLevl': None,
#   'attcFile': None,
#   'fileseq': 0,
#   'filenm': None,
#   'apndnm': None,
#   'wid': None,
#   'wname': None,
#   'searchTp': 0,
#   'pareDtlCntn': None,
#   'pareTtl': None,
#   'viewTp': None,
#   'f_scrnTp': None,
#   'checkId': None,
#   'pagePerBlock': None,
#   'maxGrpStep': '00000691259998',
#   'minGrpStep': '00000689559997',
#   'prevPageNo': None,
#   'shiftTp': None,
#   'blockNo': 0,
#   'cnt': '151',
#   'deviceInfo': None,
#   'totalTp': False,
#   'note': None},
#  {'pageNo': None,
#   'pageSize': 15,
#   'totalCount': None,
#   'startRow': None,
#   'endRow': None,
#   'f_key': None,
#   'f_keyField': None,
#   'rnum': 0,
#   'seqid': 69088,
#   'scrnTp': 'BCOSZ',
#   'realno': 4,
#   'pareSeqid': 69087,
#   'grp': 69087,
#   'artcDep': 2,
#   'step': 2,
#   'ttl': '문의에 대한 답변입니다.',
#   'custId': '',
#   'custPsdn': '운영자6',
#   'mngrYn': 'Y',
#   'ip': '172.51.59.31',
#   'readCnt': 18,
#   'dtlCntn': '안녕하십니까. 키움증권 운영자입니다.\r\n먼저 키움증권에 관심을 가져주시고 이용해주시는 고객님께 감사 인사드립니다.\r\n\r\n1.  신저가 : 최근 20일 이내에 신저가 존재\r\n=> 신저가를 계산하기 위해서는 기간수치가 특정되어야 합니다. \r\n(예: 최근 20일 이내에 100봉중 신저가)\r\n\r\n2. 각 조건을 주기가 [30분]주기 조건이 동일한 조건을 의미하는\r\n조건에 따라 주기가 다를 경우 각[주기]를 표기하여 주시기면  가능여부 확읺 안내하여 드리겠습니다. \r\n\r\n\r\n\r\n감사합니다.\r\n\r\n<p align=center>- 서비스플랫폼팀 - </p>',
#   'makeTime': '2025.03.14 16:45',
#   'email': None,
#   'emailRecvTp': '3',
#   'smsRecvTp': '3',
#   'emailSendTime': None,
#   'telNo': None,
#   'smsSendtp': None,
#   'smsSendTime': None,
#   'docTp': '0',
#   'dltTp': '1',
#   'dltNm': None,
#   'dltId': None,
#   'dltRsn': None,
#   'dltTime': None,
#   'mdiaTp': None,
#   'divTp1': None,
#   'divTp2': None,
#   'rgstNm': None,
#   'recmCnt': 0,
#   'htsScrnNo': None,
#   'scrnTpNm': '조건검색 게시판',
#   'divTp1Nm': None,
#   'divTp2Nm': None,
#   'isNew': 'N',
#   'rk': 0,
#   'topCnt': None,
#   'topMaxCnt': None,
#   'nextScrnTp': 0,
#   'prevScrnTp': 0,
#   'nextTtl': 0,
#   'prevTtl': 0,
#   'nextSeqid': 0,
#   'prevSeqid': 0,
#   'imprLevl': None,
#   'attcFile': [],
#   'fileseq': 0,
#   'filenm': None,
#   'apndnm': None,
#   'wid': None,
#   'wname': None,
#   'searchTp': 0,
#   'pareDtlCntn': None,
#   'pareTtl': None,
#   'viewTp': None,
#   'f_scrnTp': None,
#   'checkId': None,
#   'pagePerBlock': None,
#   'maxGrpStep': '00000691259998',
#   'minGrpStep': '00000689559997',
#   'prevPageNo': None,
#   'shiftTp': None,
#   'blockNo': 0,
#   'cnt': '151',
#   'deviceInfo': None,
#   'totalTp': False,
#   'note': None},
#  {'pageNo': None,
#   'pageSize': 15,
#   'totalCount': None,
#   'startRow': None,
#   'endRow': None,
#   'f_key': None,
#   'f_keyField': None,
#   'rnum': 0,
#   'seqid': 69095,
#   'scrnTp': 'BCOSZ',
#   'realno': 0,
#   'pareSeqid': 69088,
#   'grp': 69087,
#   'artcDep': 3,
#   'step': 3,
#   'ttl': '문의에 대한 답변입니다.',
#   'custId': '',
#   'custPsdn': 'love8***',
#   'mngrYn': 'N',
#   'ip': '122.43.255.117',
#   'readCnt': 11,
#   'dtlCntn': '안녕하세요?\r\n답변 감사드립니다.\r\n\r\n\r\n1.  신저가 : 최근 20일 이내에 신저가 존재\r\n==&gt; 최근 20일 이내에 100봉중 신저가\r\n\r\n2. 각 조건을 주기가 [30분]주기 조건이 동일한 조건을 의미하는\r\n조건에 따라 주기가 다를 경우 각[주기]를 표기하여 주시기면  가능여부 확읺 안내하여 드리겠습니다. \r\n==&gt; 30분 주기로 안내 부탁드립니다.',
#   'makeTime': '2025.03.14 22:07',
#   'email': None,
#   'emailRecvTp': None,
#   'smsRecvTp': None,
#   'emailSendTime': None,
#   'telNo': None,
#   'smsSendtp': None,
#   'smsSendTime': None,
#   'docTp': '0',
#   'dltTp': '1',
#   'dltNm': None,
#   'dltId': None,
#   'dltRsn': None,
#   'dltTime': None,
#   'mdiaTp': None,
#   'divTp1': None,
#   'divTp2': None,
#   'rgstNm': None,
#   'recmCnt': 0,
#   'htsScrnNo': None,
#   'scrnTpNm': '조건검색 게시판',
#   'divTp1Nm': None,
#   'divTp2Nm': None,
#   'isNew': 'N',
#   'rk': 0,
#   'topCnt': None,
#   'topMaxCnt': None,
#   'nextScrnTp': 0,
#   'prevScrnTp': 0,
#   'nextTtl': 0,
#   'prevTtl': 0,
#   'nextSeqid': 0,
#   'prevSeqid': 0,
#   'imprLevl': None,
#   'attcFile': None,
#   'fileseq': 0,
#   'filenm': None,
#   'apndnm': None,
#   'wid': None,
#   'wname': None,
#   'searchTp': 0,
#   'pareDtlCntn': None,
#   'pareTtl': None,
#   'viewTp': None,
#   'f_scrnTp': None,
#   'checkId': None,
#   'pagePerBlock': None,
#   'maxGrpStep': '00000691259998',
#   'minGrpStep': '00000689559997',
#   'prevPageNo': None,
#   'shiftTp': None,
#   'blockNo': 0,
#   'cnt': '151',
#   'deviceInfo': None,
#   'totalTp': False,
#   'note': None},
#  {'pageNo': None,
#   'pageSize': 15,
#   'totalCount': None,
#   'startRow': None,
#   'endRow': None,
#   'f_key': None,
#   'f_keyField': None,
#   'rnum': 0,
#   'seqid': 69085,
#   'scrnTp': 'BCOSZ',
#   'realno': 1,
#   'pareSeqid': 0,
#   'grp': 69085,
#   'artcDep': 1,
#   'step': 1,
#   'ttl': '일봉 이평선 조건검색',
#   'custId': '',
#   'custPsdn': 'sugar***',
#   'mngrYn': 'N',
#   'ip': '116.32.27.60',
#   'readCnt': 20,
#   'dtlCntn': '안녕하세요\r\n일봉기준 15일 이평선이 닿는 종목을 검색하려고 하는데\r\n아래 조건으로 조건검색식과 신호수식도 확인부탁드립니다.\r\n\r\n1. 일봉 이평선 20일선 &lt; 60일선 &lt; 120일선 (정배열)\r\n2. 이 종목들중에 15일선에 닿은 종목',
#   'makeTime': '2025.03.14 15:46',
#   'email': None,
#   'emailRecvTp': '3',
#   'smsRecvTp': '3',
#   'emailSendTime': None,
#   'telNo': None,
#   'smsSendtp': None,
#   'smsSendTime': None,
#   'docTp': '0',
#   'dltTp': '1',
#   'dltNm': None,
#   'dltId': None,
#   'dltRsn': None,
#   'dltTime': None,
#   'mdiaTp': None,
#   'divTp1': None,
#   'divTp2': None,
#   'rgstNm': None,
#   'recmCnt': 0,
#   'htsScrnNo': None,
#   'scrnTpNm': '조건검색 게시판',
#   'divTp1Nm': None,
#   'divTp2Nm': None,
#   'isNew': 'N',
#   'rk': 0,
#   'topCnt': None,
#   'topMaxCnt': None,
#   'nextScrnTp': 0,
#   'prevScrnTp': 0,
#   'nextTtl': 0,
#   'prevTtl': 0,
#   'nextSeqid': 0,
#   'prevSeqid': 0,
#   'imprLevl': None,
#   'attcFile': None,
#   'fileseq': 0,
#   'filenm': None,
#   'apndnm': None,
#   'wid': None,
#   'wname': None,
#   'searchTp': 0,
#   'pareDtlCntn': None,
#   'pareTtl': None,
#   'viewTp': None,
#   'f_scrnTp': None,
#   'checkId': None,
#   'pagePerBlock': None,
#   'maxGrpStep': '00000691259998',
#   'minGrpStep': '00000689559997',
#   'prevPageNo': None,
#   'shiftTp': None,
#   'blockNo': 0,
#   'cnt': '151',
#   'deviceInfo': None,
#   'totalTp': False,
#   'note': None},
#  {'pageNo': None,
#   'pageSize': 15,
#   'totalCount': None,
#   'startRow': None,
#   'endRow': None,
#   'f_key': None,
#   'f_keyField': None,
#   'rnum': 0,
#   'seqid': 69086,
#   'scrnTp': 'BCOSZ',
#   'realno': 2,
#   'pareSeqid': 69085,
#   'grp': 69085,
#   'artcDep': 2,
#   'step': 2,
#   'ttl': '문의에 대한 답변입니다.',
#   'custId': '',
#   'custPsdn': '운영자6',
#   'mngrYn': 'Y',
#   'ip': '172.51.59.31',
#   'readCnt': 32,
#   'dtlCntn': '안녕하십니까. 키움증권 운영자입니다.\r\n먼저 키움증권에 관심을 가져주시고 이용해주시는 고객님께 감사 인사드립니다.\r\n\r\n아래의 수식을 참고하여 주시기 바랍니다\r\n\r\nA:기술적분석 > 주가이동평균 > 주가이동평균배열(3개):[일]0봉전 20이평 < 60이평 < 120이평 \r\nB:기술적분석 > 주가이동평균> 주가이동평균돌파:[일]0봉전 (종가 1)이평 (종가 15)이평 골든크로스 \r\n\r\nA and B\r\n\r\n수식및 차트관련 문의는 고객게시판 또는 영웅문4 게시판을 이용 부탁드립니다. \r\n\r\n감사합니다.\r\n\r\n<p align=center>- 서비스플랫폼팀 - </p>',
#   'makeTime': '2025.03.14 15:51',
#   'email': None,
#   'emailRecvTp': '3',
#   'smsRecvTp': '3',
#   'emailSendTime': None,
#   'telNo': None,
#   'smsSendtp': None,
#   'smsSendTime': None,
#   'docTp': '0',
#   'dltTp': '1',
#   'dltNm': None,
#   'dltId': None,
#   'dltRsn': None,
#   'dltTime': None,
#   'mdiaTp': None,
#   'divTp1': None,
#   'divTp2': None,
#   'rgstNm': None,
#   'recmCnt': 0,
#   'htsScrnNo': None,
#   'scrnTpNm': '조건검색 게시판',
#   'divTp1Nm': None,
#   'divTp2Nm': None,
#   'isNew': 'N',
#   'rk': 0,
#   'topCnt': None,
#   'topMaxCnt': None,
#   'nextScrnTp': 0,
#   'prevScrnTp': 0,
#   'nextTtl': 0,
#   'prevTtl': 0,
#   'nextSeqid': 0,
#   'prevSeqid': 0,
#   'imprLevl': None,
#   'attcFile': [],
#   'fileseq': 0,
#   'filenm': None,
#   'apndnm': None,
#   'wid': None,
#   'wname': None,
#   'searchTp': 0,
#   'pareDtlCntn': None,
#   'pareTtl': None,
#   'viewTp': None,
#   'f_scrnTp': None,
#   'checkId': None,
#   'pagePerBlock': None,
#   'maxGrpStep': '00000691259998',
#   'minGrpStep': '00000689559997',
#   'prevPageNo': None,
#   'shiftTp': None,
#   'blockNo': 0,
#   'cnt': '151',
#   'deviceInfo': None,
#   'totalTp': False,
#   'note': None},
#  {'pageNo': None,
#   'pageSize': 15,
#   'totalCount': None,
#   'startRow': None,
#   'endRow': None,
#   'f_key': None,
#   'f_keyField': None,
#   'rnum': 0,
#   'seqid': 69079,
#   'scrnTp': 'BCOSZ',
#   'realno': 27,
#   'pareSeqid': 0,
#   'grp': 69079,
#   'artcDep': 1,
#   'step': 1,
#   'ttl': '프로그램 순매수량 + 분봉 차트',
#   'custId': '',
#   'custPsdn': 'eunga***',
#   'mngrYn': 'N',
#   'ip': '211.104.158.146',
#   'readCnt': 15,
#   'dtlCntn': '안녕하세요,\r\n\r\n분봉차트에\r\n\r\n프로그램 순매수량이나 금액을 보조지표로 추가할 수 있는 조건식 있을까요?',
#   'makeTime': '2025.03.14 14:55',
#   'email': None,
#   'emailRecvTp': None,
#   'smsRecvTp': None,
#   'emailSendTime': None,
#   'telNo': None,
#   'smsSendtp': None,
#   'smsSendTime': None,
#   'docTp': '0',
#   'dltTp': '1',
#   'dltNm': None,
#   'dltId': None,
#   'dltRsn': None,
#   'dltTime': None,
#   'mdiaTp': None,
#   'divTp1': None,
#   'divTp2': None,
#   'rgstNm': None,
#   'recmCnt': 0,
#   'htsScrnNo': None,
#   'scrnTpNm': '조건검색 게시판',
#   'divTp1Nm': None,
#   'divTp2Nm': None,
#   'isNew': 'N',
#   'rk': 0,
#   'topCnt': None,
#   'topMaxCnt': None,
#   'nextScrnTp': 0,
#   'prevScrnTp': 0,
#   'nextTtl': 0,
#   'prevTtl': 0,
#   'nextSeqid': 0,
#   'prevSeqid': 0,
#   'imprLevl': None,
#   'attcFile': None,
#   'fileseq': 0,
#   'filenm': None,
#   'apndnm': None,
#   'wid': None,
#   'wname': None,
#   'searchTp': 0,
#   'pareDtlCntn': None,
#   'pareTtl': None,
#   'viewTp': None,
#   'f_scrnTp': None,
#   'checkId': None,
#   'pagePerBlock': None,
#   'maxGrpStep': '00000691259998',
#   'minGrpStep': '00000689559997',
#   'prevPageNo': None,
#   'shiftTp': None,
#   'blockNo': 0,
#   'cnt': '151',
#   'deviceInfo': None,
#   'totalTp': False,
#   'note': None}]

# %%
data['boardList'][0]
# Out:
# {'pageNo': None,
#  'pageSize': 15,
#  'totalCount': None,
#  'startRow': None,
#  'endRow': None,
#  'f_key': None,
#  'f_keyField': None,
#  'rnum': 0,
#  'seqid': 69099,
#  'scrnTp': 'BCOSZ',
#  'realno': 4,
#  'pareSeqid': 0,
#  'grp': 69099,
#  'artcDep': 1,
#  'step': 1,
#  'ttl': '렌코차트에 다른 보조지표를 추가할 수 있나요?',
#  'custId': '',
#  'custPsdn': 'pds8***',
#  'mngrYn': 'N',
#  'ip': '221.145.73.187',
#  'readCnt': 1,
#  'dtlCntn': '지표를 추가해도 보여지지 않습니다...메모리 문제인지?',
#  'makeTime': '2025.03.15 11:09',
#  'email': None,
#  'emailRecvTp': None,
#  'smsRecvTp': None,
#  'emailSendTime': None,
#  'telNo': None,
#  'smsSendtp': None,
#  'smsSendTime': None,
#  'docTp': '0',
#  'dltTp': '1',
#  'dltNm': None,
#  'dltId': None,
#  'dltRsn': None,
#  'dltTime': None,
#  'mdiaTp': None,
#  'divTp1': None,
#  'divTp2': None,
#  'rgstNm': None,
#  'recmCnt': 0,
#  'htsScrnNo': None,
#  'scrnTpNm': '조건검색 게시판',
#  'divTp1Nm': None,
#  'divTp2Nm': None,
#  'isNew': 'Y',
#  'rk': 0,
#  'topCnt': None,
#  'topMaxCnt': None,
#  'nextScrnTp': 0,
#  'prevScrnTp': 0,
#  'nextTtl': 0,
#  'prevTtl': 0,
#  'nextSeqid': 0,
#  'prevSeqid': 0,
#  'imprLevl': None,
#  'attcFile': None,
#  'fileseq': 0,
#  'filenm': None,
#  'apndnm': None,
#  'wid': None,
#  'wname': None,
#  'searchTp': 0,
#  'pareDtlCntn': None,
#  'pareTtl': None,
#  'viewTp': None,
#  'f_scrnTp': None,
#  'checkId': None,
#  'pagePerBlock': None,
#  'maxGrpStep': '00000691259998',
#  'minGrpStep': '00000689559997',
#  'prevPageNo': None,
#  'shiftTp': None,
#  'blockNo': 0,
#  'cnt': '151',
#  'deviceInfo': None,
#  'totalTp': False,
#  'note': None}

# %% [markdown]
# ### 풀코드

# %%
import requests
import pyautogui
import time
import requests
import pandas as pd
import bs4
import re
from selenium.webdriver.support.select import Select
import json
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time

import requests
import pandas as pd
import bs4
import re
from selenium.webdriver.support.select import Select

l = []
for i in range(11):
    url = "https://bbn.kiwoom.com/bbs/SBbsBoardBCOSZListAjax"
    headers = {
        "accept": "*/*, application/evfwByfDS;q=0.1",
        "accept-encoding": "gzip, deflate, br, zstd",
        "accept-language": "ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7",
        "connection": "keep-alive",
        "content-length": "142",
        "content-type": "application/x-www-form-urlencoded; charset=UTF-8",
        "cookie": "JSESSIONID=FYHw3kRIuUjprawAsacsogWte6a1yoy2O1YChHlT0dJD1amVvalteBO6cngvjs9D.a3dzX2RvbWFpbi9iYnMwMTAx; WMONID=GQFc9QrphMT; evfw_Bo7vwu1=08afea1b2069a017c3e6d8ccb231fcd85702d9ces",
        "host": "bbn.kiwoom.com",
        "origin": "https://bbn.kiwoom.com",
        "referer": "https://bbn.kiwoom.com/bbs/VBbsBoardBCOSZView",
        "sec-ch-ua": '"Chromium";v="134", "Not:A-Brand";v="24", "Google Chrome";v="134"',
        "sec-ch-ua-mobile": "?0",
        "sec-ch-ua-platform": '"Windows"',
        "sec-fetch-dest": "empty",
        "sec-fetch-mode": "cors",
        "sec-fetch-site": "same-origin",
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36",
        "x-reply-with": "ajax",
        "x-requested-with": "XMLHttpRequest"
    }
    
    # 데이터 페이로드
    payload = {
        "pageNo": i,
        "custId": "",
        "f_keyField": "",
        "f_key": "",
        "searchTp": "1",
        "pagePerBlock": "10",
        "maxGrpStep": "00000691259998",
        "minGrpStep": "00000689559997",
        "prevPageNo": "1",
        "_reqAgent": "ajax"
    }
    
    # POST 요청 보내기
    response = requests.post(url, headers=headers, data=payload)
    data = response.json().get('boardList',[])
    for element in data :
        if element.get('step') == 1 :
            title = element.get('ttl')
            wdata = element.get('makeTime')
            content = element.get('dtlCntn').replace("\r", "").replace("\n", " ")
            l.append([title, wdata, content])

# %%
df = pd.DataFrame(l, columns = ['제목', '날짜', '내용'])
df
# Out:
#                       제목                날짜  \
# 0          조건검색식 부탁드립니다.  2025.03.18 10:27
# 1           조건을 찾고 있습니다.  2025.03.18 10:25
# 2            조건검색식 문의드려요  2025.03.18 09:57
# 3                 검색식 문의  2025.03.18 09:11
# 4                     문의  2025.03.18 08:54
# ..                   ...               ...
# 68               문의드립니다.  2025.03.13 15:21
# 69          검색식 확인요청(재업)  2025.03.13 13:18
# 70               조건검색 문의  2025.03.13 13:13
# 71  최근에 조정이 30% 이상 나온 종목  2025.03.13 13:09
# 72   VWAP로 조건검색은 안되는건가요?  2025.03.13 12:59
#
#                                                    내용
# 0   1,3분봉상 20일선 안깨고 상승하는 검색식 부탁드립니다.   정확히 안되면 비슷하...
# 1   주가등락률 을 보면요,  ( ) 주기 ( )봉전 (중)(   ) 대비   - (1)...
# 2   3분봉차트에서 현재가가 120분이동평균선 대비 5% 이상 하락한 종목검색식 부탁드립니다.
# 3   CrossUp(wavg(C, 1), wavg(C, 100))  위 수식을 검색식으로...
# 4   전일 거래량 급증(20일 평균 거래량 대비 300% 이상) 전일 양봉 마감 (종가 ...
# ..                                                ...
# 68  조건1) 주가등락률 : [240분] 1봉전(중) 종가대비 0봉전 고가등락률 5%이상...
# 69  안녕하세요. 전환선 1봉 연속상승 검색식에서 파인메딕스가 검색이 안되는데 이유가 멀까요?
# 70  전일 15일 이동평균선보다 금일 15일 이동평균선이 높은 것을 나타내려면 어떻게 해...
# 71  안녕하세요 수고 많으십니다.  최근에 조정이 30% 이상 나온 종목을 검색하고자 합...
# 72  차트상에서는 표시 되는데 조건검색에서는 찾을수가 없어서요.  지원된다면 정말 좋을 ...
#
# [73 rows x 3 columns]

# %%
data = response.json()

# %%
data = data.get('boardList',[])[0]
data
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 data = data.get('boardList',[])[0]
#       2 data
#
# IndexError: list index out of range
