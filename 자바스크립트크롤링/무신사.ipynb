# %%
import requests
import re, json
from bs4 import BeautifulSoup
import pandas as pd

# %%
import requests

cookies = {
    '_gf': 'A',
    'tr[vid]': '67dcc9ed80d478.78189875',
    'tr[vd]': '1742522861',
    '_ga': 'GA1.1.2014950775.1742522862',
    '_gcl_au': '1.1.1173424347.1742522862',
    '_kmpid': 'km|www.musinsa.com|1742522862391|8bed8223-fe1b-4702-a9ff-df8d0ca43824',
    '_kmpid': 'km|musinsa.com|1742522862391|8bed8223-fe1b-4702-a9ff-df8d0ca43824',
    '_fbp': 'fb.1.1742522862889.61970195871643448',
    '_fwb': '1557zuEgyrlkclzlKZTqlUc.1742522862899',
    '_hjSession_1491926': 'eyJpZCI6ImVhYWY4NzM4LTNjZTEtNDMxNS05MmE4LWFlNWQ2NDE5ZTY4NyIsImMiOjE3NDI1MjI4NjI5MTcsInMiOjAsInIiOjAsInNiIjowLCJzciI6MCwic2UiOjAsImZzIjoxLCJzcCI6MH0=',
    '_pin_unauth': 'dWlkPU9UWTRaVFZtWXpJdE5XVmlPQzAwWW1WakxXSXpNVFl0TlRGalkyVXhOekV6T0dJNQ',
    '_hjSessionUser_1491926': 'eyJpZCI6IjM4YmQ2OThkLTMyY2MtNTIxNi1hOWNmLTFmN2MzN2E4ZTI0NiIsImNyZWF0ZWQiOjE3NDI1MjI4NjI5MTcsImV4aXN0aW5nIjp0cnVlfQ==',
    'topBanner': '%7B%22WEBY%22%3A0%2C%22WEBN%22%3A0%2C%22APPY%22%3A0%2C%22APPN%22%3A0%2C%22APPALL%22%3A0%7D',
    'PHPSESSID': '4226e15bfa5fa6a5410130fb16ed5caa',
    'cart_no': 'x4cYG0jKxoPy11Hca%2F4hvNL%2FJlQrtTNAe1nKIT3RZlY%3D',
    '_tt_enable_cookie': '1',
    '_ttp': '01JPV7AKAA8M0D5JH5FH4N16B3_.tt.1',
    'ab.storage.deviceId.1773491f-ef03-4901-baf8-dbf84e1de25b': '%7B%22g%22%3A%229fa9d012-1d4c-a302-ef6e-7adb457cf56e%22%2C%22c%22%3A1742522895703%2C%22l%22%3A1742522895703%7D',
    'tr[vt]': '1742524154',
    'tr[vc]': '2',
    'tr[pv]': '9',
    'wcs_bt': 's_eacb1da8e76:1742525131',
    'cto_bundle': 'KL-',
    'ab.storage.sessionId.1773491f-ef03-4901-baf8-dbf84e1de25b': '%7B%22g%22%3A%22390fb563-51a2-cdd7-957b-63fb03dc938e%22%2C%22e%22%3A1742526933870%2C%22c%22%3A1742522895701%2C%22l%22%3A1742525133870%7D',
    '_ga_8PEGV51YTJ': 'GS1.1.1742522861.1.1.1742525143.49.0.0',
    '_dd_s': 'rum=0&expire=1742526091424',
}

headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
    'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
    'cache-control': 'max-age=0',
    'priority': 'u=0, i',
    'referer': 'https://www.musinsa.com/main/musinsa/release?sectionId=91',
    'sec-ch-ua': '"Chromium";v="134", "Not:A-Brand";v="24", "Google Chrome";v="134"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'document',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-user': '?1',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36',
    # 'cookie': '_gf=A; tr[vid]=67dcc9ed80d478.78189875; tr[vd]=1742522861; _ga=GA1.1.2014950775.1742522862; _gcl_au=1.1.1173424347.1742522862; _kmpid=km|www.musinsa.com|1742522862391|8bed8223-fe1b-4702-a9ff-df8d0ca43824; _kmpid=km|musinsa.com|1742522862391|8bed8223-fe1b-4702-a9ff-df8d0ca43824; _fbp=fb.1.1742522862889.61970195871643448; _fwb=1557zuEgyrlkclzlKZTqlUc.1742522862899; _hjSession_1491926=eyJpZCI6ImVhYWY4NzM4LTNjZTEtNDMxNS05MmE4LWFlNWQ2NDE5ZTY4NyIsImMiOjE3NDI1MjI4NjI5MTcsInMiOjAsInIiOjAsInNiIjowLCJzciI6MCwic2UiOjAsImZzIjoxLCJzcCI6MH0=; _pin_unauth=dWlkPU9UWTRaVFZtWXpJdE5XVmlPQzAwWW1WakxXSXpNVFl0TlRGalkyVXhOekV6T0dJNQ; _hjSessionUser_1491926=eyJpZCI6IjM4YmQ2OThkLTMyY2MtNTIxNi1hOWNmLTFmN2MzN2E4ZTI0NiIsImNyZWF0ZWQiOjE3NDI1MjI4NjI5MTcsImV4aXN0aW5nIjp0cnVlfQ==; topBanner=%7B%22WEBY%22%3A0%2C%22WEBN%22%3A0%2C%22APPY%22%3A0%2C%22APPN%22%3A0%2C%22APPALL%22%3A0%7D; PHPSESSID=4226e15bfa5fa6a5410130fb16ed5caa; cart_no=x4cYG0jKxoPy11Hca%2F4hvNL%2FJlQrtTNAe1nKIT3RZlY%3D; _tt_enable_cookie=1; _ttp=01JPV7AKAA8M0D5JH5FH4N16B3_.tt.1; ab.storage.deviceId.1773491f-ef03-4901-baf8-dbf84e1de25b=%7B%22g%22%3A%229fa9d012-1d4c-a302-ef6e-7adb457cf56e%22%2C%22c%22%3A1742522895703%2C%22l%22%3A1742522895703%7D; tr[vt]=1742524154; tr[vc]=2; tr[pv]=9; wcs_bt=s_eacb1da8e76:1742525131; cto_bundle=KL-; ab.storage.sessionId.1773491f-ef03-4901-baf8-dbf84e1de25b=%7B%22g%22%3A%22390fb563-51a2-cdd7-957b-63fb03dc938e%22%2C%22e%22%3A1742526933870%2C%22c%22%3A1742522895701%2C%22l%22%3A1742525133870%7D; _ga_8PEGV51YTJ=GS1.1.1742522861.1.1.1742525143.49.0.0; _dd_s=rum=0&expire=1742526091424',
}

res = requests.get('https://www.musinsa.com/products/4790520', cookies=cookies, headers=headers)

# %%
js_code = res.text

# %%
pattern = r'window.__MSS__.product.state\s\=\s(\{.+\};)' # window.__MSS__.product.state\s\=\s(\{.*?\});
match = re.search(pattern, res.text, re.DOTALL)
json_text = match.group(1)

# %%
data = json_text.replace('\n\n        window.__MSS_FE__ = window.__MSS_FE__ || {};\n        window.__MSS_FE__.shared = {"loggedIn":false};\n        window.__MSS_FE__.product = window.__MSS_FE__.product || {};', '')

# %%
data = json.loads(data.replace(';',''))

# %%
data['company']
# Out:
# {'name': '(주)무신사',
#  'ceoName': '조만호, 박준모',
#  'businessNumber': '2118879575',
#  'mailOrderReportNumber': '2012-서울강남-01897',
#  'phoneNumber': '1544-7199',
#  'email': 'cs@musinsa.com',
#  'address': '서울 성동구 아차산로13길 11',
#  'detailAddress': '1층 (성수동2가, 무신사캠퍼스 엔1)'}

# %%
data.get('brandInfo','').get('brandName')
# Out:
# '아디다스'

# %%
data.get('company')
# Out:
# {'name': '(주)무신사',
#  'ceoName': '조만호, 박준모',
#  'businessNumber': '2118879575',
#  'mailOrderReportNumber': '2012-서울강남-01897',
#  'phoneNumber': '1544-7199',
#  'email': 'cs@musinsa.com',
#  'address': '서울 성동구 아차산로13길 11',
#  'detailAddress': '1층 (성수동2가, 무신사캠퍼스 엔1)'}

# %%
# 딕셔너리 데이터 보기 쉽게 표시
print(json.dumps(data, indent=4, ensure_ascii=False))
# Out:
# {
#     "goodsNo": 4790520,
#     "goodsNm": "(무신사 단독) 와플 반팔 폴로 셔츠 - 블랙 / JV9266",
#     "goodsNmEng": "WAFFLE SS POLO BLACK",
#     "thumbnailImageUrl": "/images/goods_img/20250214/4790520/4790520_17405506828338_500.jpg",
#     "headDesc": "",
#     "styleNo": "JV9266",
#     "sex": [
#         "남성",
#         "여성"
#     ],
#     "sexCode": 6,
#     "brand": "adidas",
#     "brandInfo": {
#         "brand": "adidas",
#         "brandName": "아디다스",
#         "brandEnglishName": "ADIDAS",
#         "brandNationCode": "germany",
#         "brandNationName": "독일",
#         "brandNationEnglishName": "GERMANY",
#         "brandLogoImage": "//image.musinsa.com/mfile_s01/_brand/free_medium/adidas.png?20240220140057",
#         "brandWhiteLogoImage": "//image.musinsa.com/images/brand/white_logo_img/adidas.svg?20240220141222",
#         "sinceYear": 1949,
# ...

# %% [markdown]
# ### 다른 방식

# %%
res = requests.get('https://www.musinsa.com/products/4790520', cookies=cookies, headers=headers)

# %%
html = res.text
soup = BeautifulSoup(html, 'html.parser')
text = soup.select_one("category-data")

# %%
pattern = r'window.__MSS__.product.state\s\=\s(\{.*?\});'
match = re.search(pattern, res.text, re.DOTALL)
json_text = match.group(1)

# %%
json_text
# Out:
# '{"goodsNo":4790520,"goodsNm":"(무신사 단독) 와플 반팔 폴로 셔츠 - 블랙 / JV9266","goodsNmEng":"WAFFLE SS POLO BLACK","thumbnailImageUrl":"/images/goods_img/20250214/4790520/4790520_17405506828338_500.jpg","headDesc":"","styleNo":"JV9266","sex":["남성","여성"],"sexCode":6,"brand":"adidas","brandInfo":{"brand":"adidas","brandName":"아디다스","brandEnglishName":"ADIDAS","brandNationCode":"germany","brandNationName":"독일","brandNationEnglishName":"GERMANY","brandLogoImage":"//image.musinsa.com/mfile_s01/_brand/free_medium/adidas.png?20240220140057","brandWhiteLogoImage":"//image.musinsa.com/images/brand/white_logo_img/adidas.svg?20240220141222","sinceYear":1949,"memo":"스포츠 라이프스타일은 라커룸 밖에서도 계속됩니다. 1920년부터 독일의 헤르초게나우라흐에서 스포츠 슈즈를 만들던 아디다스(ADIDAS)는 이러한 철학을 토대로 경기장에서부터 거리에 이르기까지 모두가 즐길 수 있는 \'스포츠 라이프스타일\'의 개념을 처음으로 도입한 브랜드입니다. 스포츠 영역의 다양한 요소를 일상의 영역으로 가져오는 아디다스는 이를 통해 전 세계의 트렌드를 주도하고 있으며, 지금도 여전히 자신의 다양한 모습을 보여주고 싶어하는 소비자와 직접 소통하며 함께 혁신적인 트렌드를 만들고 있습니다.","isBrandExclusive":false,"isFlagship":true},"seasonYear":"202
# ...

# %%
data = json.loads(json_text)

# %%
data
# Out:
# {'goodsNo': 4790520,
#  'goodsNm': '(무신사 단독) 와플 반팔 폴로 셔츠 - 블랙 / JV9266',
#  'goodsNmEng': 'WAFFLE SS POLO BLACK',
#  'thumbnailImageUrl': '/images/goods_img/20250214/4790520/4790520_17405506828338_500.jpg',
#  'headDesc': '',
#  'styleNo': 'JV9266',
#  'sex': ['남성', '여성'],
#  'sexCode': 6,
#  'brand': 'adidas',
#  'brandInfo': {'brand': 'adidas',
#   'brandName': '아디다스',
#   'brandEnglishName': 'ADIDAS',
#   'brandNationCode': 'germany',
#   'brandNationName': '독일',
#   'brandNationEnglishName': 'GERMANY',
#   'brandLogoImage': '//image.musinsa.com/mfile_s01/_brand/free_medium/adidas.png?20240220140057',
#   'brandWhiteLogoImage': '//image.musinsa.com/images/brand/white_logo_img/adidas.svg?20240220141222',
#   'sinceYear': 1949,
# ...

# %% [markdown]
# ## 2단계 브랜드별 첫 번째 상품들의 상품 ID 추출

# %%
cookies = {
    '_gf': 'A',
    'tr[vid]': '67dcc9ed80d478.78189875',
    'tr[vd]': '1742522861',
    '_ga': 'GA1.1.2014950775.1742522862',
    '_gcl_au': '1.1.1173424347.1742522862',
    '_kmpid': 'km|musinsa.com|1742522862391|8bed8223-fe1b-4702-a9ff-df8d0ca43824',
    '_fbp': 'fb.1.1742522862889.61970195871643448',
    '_fwb': '1557zuEgyrlkclzlKZTqlUc.1742522862899',
    '_pin_unauth': 'dWlkPU9UWTRaVFZtWXpJdE5XVmlPQzAwWW1WakxXSXpNVFl0TlRGalkyVXhOekV6T0dJNQ',
    '_hjSessionUser_1491926': 'eyJpZCI6IjM4YmQ2OThkLTMyY2MtNTIxNi1hOWNmLTFmN2MzN2E4ZTI0NiIsImNyZWF0ZWQiOjE3NDI1MjI4NjI5MTcsImV4aXN0aW5nIjp0cnVlfQ==',
    'topBanner': '%7B%22WEBY%22%3A0%2C%22WEBN%22%3A0%2C%22APPY%22%3A0%2C%22APPN%22%3A0%2C%22APPALL%22%3A0%7D',
    '_tt_enable_cookie': '1',
    '_ttp': '01JPV7AKAA8M0D5JH5FH4N16B3_.tt.1',
    'ab.storage.deviceId.1773491f-ef03-4901-baf8-dbf84e1de25b': '%7B%22g%22%3A%229fa9d012-1d4c-a302-ef6e-7adb457cf56e%22%2C%22c%22%3A1742522895703%2C%22l%22%3A1742527175784%7D',
    'ab.storage.sessionId.1773491f-ef03-4901-baf8-dbf84e1de25b': '%7B%22g%22%3A%2242f585f1-b896-d369-322f-0990b24d5071%22%2C%22e%22%3A1742529702920%2C%22c%22%3A1742527175783%2C%22l%22%3A1742527902920%7D',
    'tr[vt]': '1742693365',
    'tr[vc]': '1',
    '_hjSession_1491926': 'eyJpZCI6ImQ4YWExNzQ1LTcxYWEtNGQ4OC05ZGUwLWJkYWUzZmEyZjE0MCIsImMiOjE3NDI2OTMzNjcwMDksInMiOjAsInIiOjAsInNiIjowLCJzciI6MCwic2UiOjAsImZzIjowLCJzcCI6MH0=',
    'tr[pv]': '2',
    'cto_bundle': 'lMpSUF9DWXB3OTN4bXRnSmJmOW5GNmozRGRRMHNubGdjcndZWTFQTEdCRG9KaHl2dGtXcHdSbyUyRjl5S0tVN3QwRjNleSUyQlVGZDhDMEl1dlRHbFBxckdiUFZWeHRnaUdNYXJJOXgySDNOWUZYNlg3VjloVVM0JTJCRFBpbHRMV0JXd3dhMXhtZ01sMHBKQkRzeHRndTZwcm5XTFhXeFElM0QlM0Q',
    '_ga_8PEGV51YTJ': 'GS1.1.1742693365.1.1.1742693538.44.0.0',
}

headers = {
    'accept': 'application/json, text/plain, */*',
    'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
    'origin': 'https://www.musinsa.com',
    'priority': 'u=1, i',
    'referer': 'https://www.musinsa.com/',
    'sec-ch-ua': '"Chromium";v="134", "Not:A-Brand";v="24", "Google Chrome";v="134"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-site',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36',
    # 'cookie': '_gf=A; tr[vid]=67dcc9ed80d478.78189875; tr[vd]=1742522861; _ga=GA1.1.2014950775.1742522862; _gcl_au=1.1.1173424347.1742522862; _kmpid=km|musinsa.com|1742522862391|8bed8223-fe1b-4702-a9ff-df8d0ca43824; _fbp=fb.1.1742522862889.61970195871643448; _fwb=1557zuEgyrlkclzlKZTqlUc.1742522862899; _pin_unauth=dWlkPU9UWTRaVFZtWXpJdE5XVmlPQzAwWW1WakxXSXpNVFl0TlRGalkyVXhOekV6T0dJNQ; _hjSessionUser_1491926=eyJpZCI6IjM4YmQ2OThkLTMyY2MtNTIxNi1hOWNmLTFmN2MzN2E4ZTI0NiIsImNyZWF0ZWQiOjE3NDI1MjI4NjI5MTcsImV4aXN0aW5nIjp0cnVlfQ==; topBanner=%7B%22WEBY%22%3A0%2C%22WEBN%22%3A0%2C%22APPY%22%3A0%2C%22APPN%22%3A0%2C%22APPALL%22%3A0%7D; _tt_enable_cookie=1; _ttp=01JPV7AKAA8M0D5JH5FH4N16B3_.tt.1; ab.storage.deviceId.1773491f-ef03-4901-baf8-dbf84e1de25b=%7B%22g%22%3A%229fa9d012-1d4c-a302-ef6e-7adb457cf56e%22%2C%22c%22%3A1742522895703%2C%22l%22%3A1742527175784%7D; ab.storage.sessionId.1773491f-ef03-4901-baf8-dbf84e1de25b=%7B%22g%22%3A%2242f585f1-b896-d369-322f-0990b24d5071%22%2C%22e%22%3A1742529702920%2C%22c%22%3A1742527175783%2C%22l%22%3A1742527902920%7D; tr[vt]=1742693365; tr[vc]=1; _hjSession_1491926=eyJpZCI6ImQ4YWExNzQ1LTcxYWEtNGQ4OC05ZGUwLWJkYWUzZmEyZjE0MCIsImMiOjE3NDI2OTMzNjcwMDksInMiOjAsInIiOjAsInNiIjowLCJzciI6MCwic2UiOjAsImZzIjowLCJzcCI6MH0=; tr[pv]=2; cto_bundle=lMpSUF9DWXB3OTN4bXRnSmJmOW5GNmozRGRRMHNubGdjcndZWTFQTEdCRG9KaHl2dGtXcHdSbyUyRjl5S0tVN3QwRjNleSUyQlVGZDhDMEl1dlRHbFBxckdiUFZWeHRnaUdNYXJJOXgySDNOWUZYNlg3VjloVVM0JTJCRFBpbHRMV0JXd3dhMXhtZ01sMHBKQkRzeHRndTZwcm5XTFhXeFElM0QlM0Q; _ga_8PEGV51YTJ=GS1.1.1742693365.1.1.1742693538.44.0.0',
}

params = {
    'storeCode': 'musinsa',
    'sectionId': '91',
    'gf': 'A',
}

res = requests.get('https://api.musinsa.com/api2/hm/v1/pans/release', params=params, cookies=cookies, headers=headers)
res
# Out:
# <Response [200]>

# %%
res.text
# Out:
# '{"data":{"modules":[{"id":"TAB_OUTLINED-eb749f40-b97d-48c7-8a38-dfe752681dd2","apiUrl":"https://api.musinsa.com/api2/hm/v1/pans/release/sections/{sectionId}?storeCode=musinsa","hasDivider":true,"type":"TAB_OUTLINED","tabs":[{"key":"musinsa_91","params":{"sectionId":"91"},"text":{"text":"NOW"},"impressionEventLog":{"ga4":{"name":"impression_button","payload":{"page_id":"/main/musinsa/release","section_name":"release_tab","section_index":"1","index":"1","applied_tab":"release_now","extra_info":"NOW","button_id":"release_theme","button_name":"NOW"}}},"onClick":{"eventLog":{"ga4":{"name":"click_button","payload":{"page_id":"/main/musinsa/release","section_name":"release_tab","section_index":"1","index":"1","applied_tab":"release_now","extra_info":"NOW","button_id":"release_theme","button_name":"NOW"}},"amplitude":{"name":"click_tab","payload":{"from":"screen_main_musinsa_release","section_name":"release_tab","section_index":"1","index":"1","applied_tab":"release_now","type_2":"NOW","gen
# ...

# %%
js_code = res.text
data = json.loads(js_code)
data
# Out:
# {'data': {'modules': [{'id': 'TAB_OUTLINED-eb749f40-b97d-48c7-8a38-dfe752681dd2',
#     'apiUrl': 'https://api.musinsa.com/api2/hm/v1/pans/release/sections/{sectionId}?storeCode=musinsa',
#     'hasDivider': True,
#     'type': 'TAB_OUTLINED',
#     'tabs': [{'key': 'musinsa_91',
#       'params': {'sectionId': '91'},
#       'text': {'text': 'NOW'},
#       'impressionEventLog': {'ga4': {'name': 'impression_button',
#         'payload': {'page_id': '/main/musinsa/release',
#          'section_name': 'release_tab',
#          'section_index': '1',
#          'index': '1',
#          'applied_tab': 'release_now',
#          'extra_info': 'NOW',
#          'button_id': 'release_theme',
#          'button_name': 'NOW'}}},
#       'onClick': {'eventLog': {'ga4': {'name': 'click_button',
#          'payload': {'page_id': '/main/musinsa/release',
#           'section_name': 'release_tab',
#           'section_index': '1',
#           'index': '1',
#           'applied_tab': 'release_now',
# ...

# %%
len(data['data']['modules'])
# Out:
# 22

# %%
data['data']['modules'][3]
# Out:
# {'id': '4870',
#  'items': [{'type': 'PRODUCT_CAROUSEL',
#    'id': '4757489',
#    'info': {'productName': '디테쳐블 라운드 자켓 (차콜)',
#     'discountRatio': 10,
#     'finalPrice': 122400,
#     'strikethrough': False},
#    'image': {'url': 'https://image.msscdn.net/images/goods_img/20250204/4757489/4757489_17393496371861_500.jpg',
#     'onClickLike': {'productId': '4757489',
#      'eventLog': {'ga4': {'payload': {'page_id': '/main/musinsa/release',
#         'section_name': 'release_list',
#         'section_index': '6',
#         'index': '1',
#         'applied_tab': 'release_now',
#         'extra_info': 'NOW',
#         'brand_id': 'hugyourskin',
#         'content_id': '4870',
#         'content_name': '허그유어스킨 25 S/S 선발매',
#         'content_type': 'title',
#         'liked_item_id': '4757489'}},
#       'amplitude': {'payload': {'from': 'screen_main_musinsa_release',
#         'section_name': 'release_list',
#         'section_index': '6',
#         'section_title': 'NOW',
# ...

# %%
for i in range(len(data['data']['modules'])) :
    pattern = r"^\d+$"
    id_value = data['data']['modules'][i]['id']
    
    if re.fullmatch(pattern, id_value):
        product_id = data['data']['modules'][i]['items'][0]['id']
        print(product_id)
# Out:
# 4790520
# 4757489
# 1163169
# 1178135
# 1763157
# 3392006
# 4460716
# 595040
# 4787743
# 1214169
# 4763291
# 3716351
# 4760076
# 3933001
# 4737880
# 4876171
# 4767271
# 4737608
# 4894804
# 4794878

# %%
pattern = r"^\d+$"
id_value = data['data']['modules'][3]['id']
if re.fullmatch(pattern, id_value):
    print(id_value)  # 숫자형 문자열이면 출력
else:
    print("해당 값은 숫자형 문자열이 아닙니다.")
# Out:
# 4940

# %% [markdown]
# ## 풀코드 3단계

# %%
import requests
import re, json
from bs4 import BeautifulSoup

# %%
cookies = {
    '_gf': 'A',
    'tr[vid]': '67dcc9ed80d478.78189875',
    'tr[vd]': '1742522861',
    '_ga': 'GA1.1.2014950775.1742522862',
    '_gcl_au': '1.1.1173424347.1742522862',
    '_kmpid': 'km|musinsa.com|1742522862391|8bed8223-fe1b-4702-a9ff-df8d0ca43824',
    '_fbp': 'fb.1.1742522862889.61970195871643448',
    '_fwb': '1557zuEgyrlkclzlKZTqlUc.1742522862899',
    '_pin_unauth': 'dWlkPU9UWTRaVFZtWXpJdE5XVmlPQzAwWW1WakxXSXpNVFl0TlRGalkyVXhOekV6T0dJNQ',
    '_hjSessionUser_1491926': 'eyJpZCI6IjM4YmQ2OThkLTMyY2MtNTIxNi1hOWNmLTFmN2MzN2E4ZTI0NiIsImNyZWF0ZWQiOjE3NDI1MjI4NjI5MTcsImV4aXN0aW5nIjp0cnVlfQ==',
    'topBanner': '%7B%22WEBY%22%3A0%2C%22WEBN%22%3A0%2C%22APPY%22%3A0%2C%22APPN%22%3A0%2C%22APPALL%22%3A0%7D',
    '_tt_enable_cookie': '1',
    '_ttp': '01JPV7AKAA8M0D5JH5FH4N16B3_.tt.1',
    'ab.storage.deviceId.1773491f-ef03-4901-baf8-dbf84e1de25b': '%7B%22g%22%3A%229fa9d012-1d4c-a302-ef6e-7adb457cf56e%22%2C%22c%22%3A1742522895703%2C%22l%22%3A1742527175784%7D',
    'ab.storage.sessionId.1773491f-ef03-4901-baf8-dbf84e1de25b': '%7B%22g%22%3A%2242f585f1-b896-d369-322f-0990b24d5071%22%2C%22e%22%3A1742529702920%2C%22c%22%3A1742527175783%2C%22l%22%3A1742527902920%7D',
    'tr[vt]': '1742693365',
    'tr[vc]': '1',
    '_hjSession_1491926': 'eyJpZCI6ImQ4YWExNzQ1LTcxYWEtNGQ4OC05ZGUwLWJkYWUzZmEyZjE0MCIsImMiOjE3NDI2OTMzNjcwMDksInMiOjAsInIiOjAsInNiIjowLCJzciI6MCwic2UiOjAsImZzIjowLCJzcCI6MH0=',
    'tr[pv]': '2',
    'cto_bundle': 'lMpSUF9DWXB3OTN4bXRnSmJmOW5GNmozRGRRMHNubGdjcndZWTFQTEdCRG9KaHl2dGtXcHdSbyUyRjl5S0tVN3QwRjNleSUyQlVGZDhDMEl1dlRHbFBxckdiUFZWeHRnaUdNYXJJOXgySDNOWUZYNlg3VjloVVM0JTJCRFBpbHRMV0JXd3dhMXhtZ01sMHBKQkRzeHRndTZwcm5XTFhXeFElM0QlM0Q',
    '_ga_8PEGV51YTJ': 'GS1.1.1742693365.1.1.1742693538.44.0.0',
}

headers = {
    'accept': 'application/json, text/plain, */*',
    'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
    'origin': 'https://www.musinsa.com',
    'priority': 'u=1, i',
    'referer': 'https://www.musinsa.com/',
    'sec-ch-ua': '"Chromium";v="134", "Not:A-Brand";v="24", "Google Chrome";v="134"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-site',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36',
    # 'cookie': '_gf=A; tr[vid]=67dcc9ed80d478.78189875; tr[vd]=1742522861; _ga=GA1.1.2014950775.1742522862; _gcl_au=1.1.1173424347.1742522862; _kmpid=km|musinsa.com|1742522862391|8bed8223-fe1b-4702-a9ff-df8d0ca43824; _fbp=fb.1.1742522862889.61970195871643448; _fwb=1557zuEgyrlkclzlKZTqlUc.1742522862899; _pin_unauth=dWlkPU9UWTRaVFZtWXpJdE5XVmlPQzAwWW1WakxXSXpNVFl0TlRGalkyVXhOekV6T0dJNQ; _hjSessionUser_1491926=eyJpZCI6IjM4YmQ2OThkLTMyY2MtNTIxNi1hOWNmLTFmN2MzN2E4ZTI0NiIsImNyZWF0ZWQiOjE3NDI1MjI4NjI5MTcsImV4aXN0aW5nIjp0cnVlfQ==; topBanner=%7B%22WEBY%22%3A0%2C%22WEBN%22%3A0%2C%22APPY%22%3A0%2C%22APPN%22%3A0%2C%22APPALL%22%3A0%7D; _tt_enable_cookie=1; _ttp=01JPV7AKAA8M0D5JH5FH4N16B3_.tt.1; ab.storage.deviceId.1773491f-ef03-4901-baf8-dbf84e1de25b=%7B%22g%22%3A%229fa9d012-1d4c-a302-ef6e-7adb457cf56e%22%2C%22c%22%3A1742522895703%2C%22l%22%3A1742527175784%7D; ab.storage.sessionId.1773491f-ef03-4901-baf8-dbf84e1de25b=%7B%22g%22%3A%2242f585f1-b896-d369-322f-0990b24d5071%22%2C%22e%22%3A1742529702920%2C%22c%22%3A1742527175783%2C%22l%22%3A1742527902920%7D; tr[vt]=1742693365; tr[vc]=1; _hjSession_1491926=eyJpZCI6ImQ4YWExNzQ1LTcxYWEtNGQ4OC05ZGUwLWJkYWUzZmEyZjE0MCIsImMiOjE3NDI2OTMzNjcwMDksInMiOjAsInIiOjAsInNiIjowLCJzciI6MCwic2UiOjAsImZzIjowLCJzcCI6MH0=; tr[pv]=2; cto_bundle=lMpSUF9DWXB3OTN4bXRnSmJmOW5GNmozRGRRMHNubGdjcndZWTFQTEdCRG9KaHl2dGtXcHdSbyUyRjl5S0tVN3QwRjNleSUyQlVGZDhDMEl1dlRHbFBxckdiUFZWeHRnaUdNYXJJOXgySDNOWUZYNlg3VjloVVM0JTJCRFBpbHRMV0JXd3dhMXhtZ01sMHBKQkRzeHRndTZwcm5XTFhXeFElM0QlM0Q; _ga_8PEGV51YTJ=GS1.1.1742693365.1.1.1742693538.44.0.0',
}

params = {
    'storeCode': 'musinsa',
    'sectionId': '91',
    'gf': 'A',
}

sub_cookies = {
    '_gf': 'A',
    'tr[vid]': '67dcc9ed80d478.78189875',
    'tr[vd]': '1742522861',
    '_ga': 'GA1.1.2014950775.1742522862',
    '_gcl_au': '1.1.1173424347.1742522862',
    '_kmpid': 'km|www.musinsa.com|1742522862391|8bed8223-fe1b-4702-a9ff-df8d0ca43824',
    '_kmpid': 'km|musinsa.com|1742522862391|8bed8223-fe1b-4702-a9ff-df8d0ca43824',
    '_fbp': 'fb.1.1742522862889.61970195871643448',
    '_fwb': '1557zuEgyrlkclzlKZTqlUc.1742522862899',
    '_hjSession_1491926': 'eyJpZCI6ImVhYWY4NzM4LTNjZTEtNDMxNS05MmE4LWFlNWQ2NDE5ZTY4NyIsImMiOjE3NDI1MjI4NjI5MTcsInMiOjAsInIiOjAsInNiIjowLCJzciI6MCwic2UiOjAsImZzIjoxLCJzcCI6MH0=',
    '_pin_unauth': 'dWlkPU9UWTRaVFZtWXpJdE5XVmlPQzAwWW1WakxXSXpNVFl0TlRGalkyVXhOekV6T0dJNQ',
    '_hjSessionUser_1491926': 'eyJpZCI6IjM4YmQ2OThkLTMyY2MtNTIxNi1hOWNmLTFmN2MzN2E4ZTI0NiIsImNyZWF0ZWQiOjE3NDI1MjI4NjI5MTcsImV4aXN0aW5nIjp0cnVlfQ==',
    'topBanner': '%7B%22WEBY%22%3A0%2C%22WEBN%22%3A0%2C%22APPY%22%3A0%2C%22APPN%22%3A0%2C%22APPALL%22%3A0%7D',
    'PHPSESSID': '4226e15bfa5fa6a5410130fb16ed5caa',
    'cart_no': 'x4cYG0jKxoPy11Hca%2F4hvNL%2FJlQrtTNAe1nKIT3RZlY%3D',
    '_tt_enable_cookie': '1',
    '_ttp': '01JPV7AKAA8M0D5JH5FH4N16B3_.tt.1',
    'ab.storage.deviceId.1773491f-ef03-4901-baf8-dbf84e1de25b': '%7B%22g%22%3A%229fa9d012-1d4c-a302-ef6e-7adb457cf56e%22%2C%22c%22%3A1742522895703%2C%22l%22%3A1742522895703%7D',
    'tr[vt]': '1742524154',
    'tr[vc]': '2',
    'tr[pv]': '9',
    'wcs_bt': 's_eacb1da8e76:1742525131',
    'cto_bundle': 'KL-',
    'ab.storage.sessionId.1773491f-ef03-4901-baf8-dbf84e1de25b': '%7B%22g%22%3A%22390fb563-51a2-cdd7-957b-63fb03dc938e%22%2C%22e%22%3A1742526933870%2C%22c%22%3A1742522895701%2C%22l%22%3A1742525133870%7D',
    '_ga_8PEGV51YTJ': 'GS1.1.1742522861.1.1.1742525143.49.0.0',
    '_dd_s': 'rum=0&expire=1742526091424',
}

sub_headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
    'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
    'cache-control': 'max-age=0',
    'priority': 'u=0, i',
    'referer': 'https://www.musinsa.com/main/musinsa/release?sectionId=91',
    'sec-ch-ua': '"Chromium";v="134", "Not:A-Brand";v="24", "Google Chrome";v="134"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'document',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-user': '?1',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36',
    # 'cookie': '_gf=A; tr[vid]=67dcc9ed80d478.78189875; tr[vd]=1742522861; _ga=GA1.1.2014950775.1742522862; _gcl_au=1.1.1173424347.1742522862; _kmpid=km|www.musinsa.com|1742522862391|8bed8223-fe1b-4702-a9ff-df8d0ca43824; _kmpid=km|musinsa.com|1742522862391|8bed8223-fe1b-4702-a9ff-df8d0ca43824; _fbp=fb.1.1742522862889.61970195871643448; _fwb=1557zuEgyrlkclzlKZTqlUc.1742522862899; _hjSession_1491926=eyJpZCI6ImVhYWY4NzM4LTNjZTEtNDMxNS05MmE4LWFlNWQ2NDE5ZTY4NyIsImMiOjE3NDI1MjI4NjI5MTcsInMiOjAsInIiOjAsInNiIjowLCJzciI6MCwic2UiOjAsImZzIjoxLCJzcCI6MH0=; _pin_unauth=dWlkPU9UWTRaVFZtWXpJdE5XVmlPQzAwWW1WakxXSXpNVFl0TlRGalkyVXhOekV6T0dJNQ; _hjSessionUser_1491926=eyJpZCI6IjM4YmQ2OThkLTMyY2MtNTIxNi1hOWNmLTFmN2MzN2E4ZTI0NiIsImNyZWF0ZWQiOjE3NDI1MjI4NjI5MTcsImV4aXN0aW5nIjp0cnVlfQ==; topBanner=%7B%22WEBY%22%3A0%2C%22WEBN%22%3A0%2C%22APPY%22%3A0%2C%22APPN%22%3A0%2C%22APPALL%22%3A0%7D; PHPSESSID=4226e15bfa5fa6a5410130fb16ed5caa; cart_no=x4cYG0jKxoPy11Hca%2F4hvNL%2FJlQrtTNAe1nKIT3RZlY%3D; _tt_enable_cookie=1; _ttp=01JPV7AKAA8M0D5JH5FH4N16B3_.tt.1; ab.storage.deviceId.1773491f-ef03-4901-baf8-dbf84e1de25b=%7B%22g%22%3A%229fa9d012-1d4c-a302-ef6e-7adb457cf56e%22%2C%22c%22%3A1742522895703%2C%22l%22%3A1742522895703%7D; tr[vt]=1742524154; tr[vc]=2; tr[pv]=9; wcs_bt=s_eacb1da8e76:1742525131; cto_bundle=KL-; ab.storage.sessionId.1773491f-ef03-4901-baf8-dbf84e1de25b=%7B%22g%22%3A%22390fb563-51a2-cdd7-957b-63fb03dc938e%22%2C%22e%22%3A1742526933870%2C%22c%22%3A1742522895701%2C%22l%22%3A1742525133870%7D; _ga_8PEGV51YTJ=GS1.1.1742522861.1.1.1742525143.49.0.0; _dd_s=rum=0&expire=1742526091424',
}

res = requests.get('https://api.musinsa.com/api2/hm/v1/pans/release', params=params, cookies=cookies, headers=headers)

js_code = res.text
data = json.loads(js_code)

brand_set = set()

for i in range(len(data['data']['modules'])) :
    pattern = r"^\d+$"
    id_value = data['data']['modules'][i]['id']
    
    if re.fullmatch(pattern, id_value):
        product_id = data['data']['modules'][i]['items'][0]['id']
        url = 'https://www.musinsa.com/products/{}'.format(product_id)
        sub_res = requests.get(url, cookies=sub_cookies, headers=sub_headers)

        html = res.text
        soup = BeautifulSoup(html, 'html.parser')
        text = soup.select_one("category-data")

        pattern = r'window.__MSS__.product.state\s\=\s(\{.*?\});'
        match = re.search(pattern, sub_res.text, re.DOTALL)
        json_text = match.group(1)

        sub_data = json.loads(json_text)

        brandname = sub_data['brandInfo']['brandName']
        phoneNumber = sub_data['company']['phoneNumber']
        email = sub_data['company']['email']
        address = sub_data['company']['address']

        brand_set.add((brandname,phoneNumber,email,address))

# %%
brand_set
# Out:
# {('닥터마틴', '1544-7199', 'cs@musinsa.com', '서울 성동구 아차산로13길 11'),
#  ('디스이즈네버댓',
#   '070-4015-0014',
#   'service@thisisneverthat.com',
#   '서울 성동구 아차산로 159 (제이케이앤디)'),
#  ('스컬프터', '010-8450-2279', 'jinchoi@rootscorp.co.kr', '서울특별시 마포구 와우산로11길 16'),
#  ('스켈리웩', '02-2256-0308', 'splanet.official@gmail.com', '서울 중구 다산로 159'),
#  ('썸웨어버터', '070-7710-3805', 'somewherebutter_@naver.com', '대구 북구 칠곡중앙대로 373'),
#  ('아디다스', '1544-7199', 'cs@musinsa.com', '서울 성동구 아차산로13길 11'),
#  ('아식스', '1544-7199', 'cs@musinsa.com', '서울 성동구 아차산로13길 11'),
#  ('에이이에이이', '070-4821-4096', 'ae.60835@ae-ae.kr', '대구 중구 달구벌대로414길 6'),
#  ('엠엘비', '080-807-0012', 'mlb@fnfcorp.com', '서울특별시 강남구 언주로 541 에프앤에프사옥 본관'),
#  ('오헤시오', '02-3144-2595', 'cs_help@ba-on.com', '서울 마포구 양화로 100'),
#  ('자빈드서울', '1899-2043', 'hypark@dahaus.co.kr', '서울 용산구 이태원로55길 5'),
#  ('캘빈클라인 진',
#   '02-3447-0555',
#   'younjh0402@ossokorea.com',
#   '서울 강남구 삼성로 622 (대명빌딩)'),
# ...

# %%
df = pd.DataFrame(list(brand_set), columns=['브랜드명', '전화번호', '이메일', '주소'])

# %%
df
# Out:
#         브랜드명           전화번호                          이메일  \
# 0        엠엘비   080-807-0012              mlb@fnfcorp.com
# 1         푸마      1544-7199               cs@musinsa.com
# 2    디스이즈네버댓  070-4015-0014  service@thisisneverthat.com
# 3        아식스      1544-7199               cs@musinsa.com
# 4      썸웨어버터  070-7710-3805   somewherebutter_@naver.com
# 5        프렌다   031-928-5495    prendafromplant@gmail.com
# 6       닥터마틴      1544-7199               cs@musinsa.com
# 7    캘빈클라인 진   02-3447-0555     younjh0402@ossokorea.com
# 8   파르티멘토 우먼  070-4212-2105       partimento.w@gmail.com
# 9       아디다스      1544-7199               cs@musinsa.com
# 10      스컬프터  010-8450-2279      jinchoi@rootscorp.co.kr
# 11     자빈드서울      1899-2043          hypark@dahaus.co.kr
# 12    허그유어스킨  010-3014-3891      hugyourskinkr@gmail.com
# 13    에이이에이이  070-4821-4096            ae.60835@ae-ae.kr
# 14      스켈리웩   02-2256-0308   splanet.official@gmail.com
# ...
