# %%
# !pip install requests

# %%
# %config IPCompleter.greedy=True

# %%
import requests

# %%
res = requests.get("https://search.naver.com/search.naver?ssc=tab.blog.all&sm=tab_jum&query=%EB%A7%9B%EC%A7%91")

# %%
res
# Out:
# <Response [200]>

# %%
type(res)
# Out:
# requests.models.Response

# %%
res.text
# Out:
# '<!doctype html> <html lang="ko"><head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta property="og:title" content="맛집 : 네이버 블로그검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="\'맛집\'의 네이버 블로그검색 결과입니다."> <meta name="description" lang="ko" content="\'맛집\'의 네이버 블로그검색 결과입니다."> <title>맛집 : 네이버 블로그검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_32x32_240820.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><script> if (top.frames.length!=0 || window!=top) window.open(location, "_top"); </script><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_250109.css"> <link rel="stylesheet" type="text/css
# ...

# %%
# !pip install beautifulSoup4

# %%
import bs4

# %%
# !pip install lxml

# %%
soup = bs4.BeautifulSoup(res.text)

# %%
ul_elements = soup.select("ul")

# %%
type(ul_elements)
# Out:
# bs4.element.ResultSet

# %%
ul_elements[0]
# Out:
# <ul class="nav_list" role="tablist"> <li role="presentation"><a aria-selected="false" class="tab" href="?ssc=tab.nx.all&amp;where=nexearch&amp;sm=tab_jum&amp;query=%EB%A7%9B%EC%A7%91" onclick="return goOtherCR(this,'a=tmr*N.jmp&amp;r=1&amp;i=&amp;u='+urlencode(this.href));" role="tab"><i class="spnew2 ico_nav_all"></i>전체</a></li><li role="presentation"><a aria-selected="true" class="tab" href="?ssc=tab.blog.all&amp;sm=tab_jum&amp;query=%EB%A7%9B%EC%A7%91" onclick="return goOtherCR(this,'a=tmr*b.now&amp;r=2&amp;i=&amp;u='+urlencode(this.href));" role="tab"><i class="spnew2 ico_nav_blog"></i>블로그</a></li><li role="presentation"><a aria-selected="false" class="tab" href="https://map.naver.com/v5/search/%EB%A7%9B%EC%A7%91" onclick="return goOtherCR(this,'a=tmr*M.jmp&amp;r=3&amp;i=&amp;u='+urlencode(this.href));" role="tab" target="_blank"><i class="spnew2 ico_nav_map"></i>지도</a></li><li role="presentation"><a aria-selected="false" class="tab" href="?ssc=tab.cafe.all&amp;sm=tab_jum&amp;que
# ...

# %%
ul_elements = soup.select("ul.lst_view > li")
len(ul_elements)
# Out:
# 83

# %%
ul_element = ul_elements[0]

# %%
ul_element
# Out:
# <li class="bx"> <div class="view_wrap"> <div class="user_box"> <div class="api_save_group _keep_wrap"> <a aria-pressed="false" class="btn_save _keep_trigger" data-url="https://blog.naver.com/ahram1120/223749741926" href="#" onclick="tCR('a=blg*a.kep&amp;r=1&amp;i=90000003_000000000000003418861D66&amp;u=javascript'); return false;" role="button"><i class="spnew ico_save">문서 저장하기</i></a> <div class="api_ly_save _keep_save_layer"> <a class="spnew_af item item_save _keep_save" data-cr-off="a=blg*a.kepoff&amp;r=1&amp;i=90000003_000000000000003418861D66&amp;u=javascript" data-cr-on="a=blg*a.kepon&amp;r=1&amp;i=90000003_000000000000003418861D66&amp;u=javascript" href="#" role="button">Keep에 저장</a> <a class="spnew_af item item_quick" href="https://keep.naver.com/" onclick="return goOtherCR(this,'a=blg*a.kephome&amp;r=1&amp;i=90000003_000000000000003418861D66&amp;u='+urlencode(this.href));" target="_blank">Keep 바로가기</a> </div> </div> <div class="user_box_inner"> <a class="user_thumb" href="ht
# ...

# %%
type(ul_element)
# Out:
# bs4.element.Tag

# %%
li_element = ul_element
li_element
# Out:
# <li class="bx"> <div class="view_wrap"> <div class="user_box"> <div class="api_save_group _keep_wrap"> <a aria-pressed="false" class="btn_save _keep_trigger" data-url="https://blog.naver.com/ahram1120/223749741926" href="#" onclick="tCR('a=blg*a.kep&amp;r=1&amp;i=90000003_000000000000003418861D66&amp;u=javascript'); return false;" role="button"><i class="spnew ico_save">문서 저장하기</i></a> <div class="api_ly_save _keep_save_layer"> <a class="spnew_af item item_save _keep_save" data-cr-off="a=blg*a.kepoff&amp;r=1&amp;i=90000003_000000000000003418861D66&amp;u=javascript" data-cr-on="a=blg*a.kepon&amp;r=1&amp;i=90000003_000000000000003418861D66&amp;u=javascript" href="#" role="button">Keep에 저장</a> <a class="spnew_af item item_quick" href="https://keep.naver.com/" onclick="return goOtherCR(this,'a=blg*a.kephome&amp;r=1&amp;i=90000003_000000000000003418861D66&amp;u='+urlencode(this.href));" target="_blank">Keep 바로가기</a> </div> </div> <div class="user_box_inner"> <a class="user_thumb" href="ht
# ...

# %%
# Out:
# []

# %%
len(soup.find_all("ul"))
# Out:
# 9

# %%
len(soup.find_all("ul", class_="lst_view"))
# Out:
# 1

# %%
len(soup.find_all("ul", {"class" : "lst_view"}))
# Out:
# 1

# %%
a = soup.find("ul", {"class" : "lst_view"})

# %%
type(a)
# Out:
# bs4.element.Tag

# %%
len(a.find_all("li"))
# Out:
# 83

# %%
a.find_all("li", {"class" :"bx"}, recursive = False)[0]
# Out:
# <li class="bx"> <div class="view_wrap"> <div class="user_box"> <div class="api_save_group _keep_wrap"> <a aria-pressed="false" class="btn_save _keep_trigger" data-url="https://blog.naver.com/ahram1120/223749741926" href="#" onclick="tCR('a=blg*a.kep&amp;r=1&amp;i=90000003_000000000000003418861D66&amp;u=javascript'); return false;" role="button"><i class="spnew ico_save">문서 저장하기</i></a> <div class="api_ly_save _keep_save_layer"> <a class="spnew_af item item_save _keep_save" data-cr-off="a=blg*a.kepoff&amp;r=1&amp;i=90000003_000000000000003418861D66&amp;u=javascript" data-cr-on="a=blg*a.kepon&amp;r=1&amp;i=90000003_000000000000003418861D66&amp;u=javascript" href="#" role="button">Keep에 저장</a> <a class="spnew_af item item_quick" href="https://keep.naver.com/" onclick="return goOtherCR(this,'a=blg*a.kephome&amp;r=1&amp;i=90000003_000000000000003418861D66&amp;u='+urlencode(this.href));" target="_blank">Keep 바로가기</a> </div> </div> <div class="user_box_inner"> <a class="user_thumb" href="ht
# ...

# %%
soup.find_all("panel-list", {"data-index":"tag"})
# Out:
# []

# %%
soup.body['class']
# Out:
# ['wrap-new', 'api_animation', 'tabsch', 'tabsch_blog']

# %%
soup.body.div['id']
# Out:
# 'nxtt_div'

# %%
li_element
# Out:
# <li class="bx"> <div class="view_wrap"> <div class="user_box"> <div class="api_save_group _keep_wrap"> <a aria-pressed="false" class="btn_save _keep_trigger" data-url="https://blog.naver.com/ahram1120/223749741926" href="#" onclick="tCR('a=blg*a.kep&amp;r=1&amp;i=90000003_000000000000003418861D66&amp;u=javascript'); return false;" role="button"><i class="spnew ico_save">문서 저장하기</i></a> <div class="api_ly_save _keep_save_layer"> <a class="spnew_af item item_save _keep_save" data-cr-off="a=blg*a.kepoff&amp;r=1&amp;i=90000003_000000000000003418861D66&amp;u=javascript" data-cr-on="a=blg*a.kepon&amp;r=1&amp;i=90000003_000000000000003418861D66&amp;u=javascript" href="#" role="button">Keep에 저장</a> <a class="spnew_af item item_quick" href="https://keep.naver.com/" onclick="return goOtherCR(this,'a=blg*a.kephome&amp;r=1&amp;i=90000003_000000000000003418861D66&amp;u='+urlencode(this.href));" target="_blank">Keep 바로가기</a> </div> </div> <div class="user_box_inner"> <a class="user_thumb" href="ht
# ...

# %%
len(li_element.select("a"))
# Out:
# 14

# %%
a_element = li_element.select("div.title_area > a")[0]
a_element
# Out:
# <a class="title_link" data-cb-target="90000003_000000000000003418861D66" data-cb-trigger="" href="https://blog.naver.com/ahram1120/223749741926" onclick="return goOtherCR(this,'a=blg*a.nblg&amp;r=1&amp;i=90000003_000000000000003418861D66&amp;u='+urlencode(this.href));" target="_blank">기대이상 제주 갈치구이 <mark>맛집</mark></a>

# %%
a_element1 = li_element.select("div.title_area > a")[1]

# %%
a_element
# Out:
# <a class="title_link" data-cb-target="90000003_000000000000003418861D66" data-cb-trigger="" href="https://blog.naver.com/ahram1120/223749741926" onclick="return goOtherCR(this,'a=blg*a.nblg&amp;r=1&amp;i=90000003_000000000000003418861D66&amp;u='+urlencode(this.href));" target="_blank">기대이상 제주 갈치구이 <mark>맛집</mark></a>

# %%
a_element.text.strip()
# Out:
# '기대이상 제주 갈치구이 맛집'

# %%
a_element.get("href")
# Out:
# 'https://blog.naver.com/ahram1120/223749741926'

# %%
for li_element in ul_elements:
    a_elements = li_element.select("div.title_area > a.title_link")  # 리스트 반환
    
    if a_elements:  # 리스트가 비어있지 않다면 실행
        a_element = a_elements[0]
        title = a_element.text.strip()
        url = a_element.get("href")
        
        print(title, url)
# Out:
# 기대이상 제주 갈치구이 맛집 https://blog.naver.com/ahram1120/223749741926
# 신선함에 반한 제주 고등어회 맛집 https://blog.naver.com/viviana1122/223751960947
# 제주도 서쪽 맛집 취향저격한 훈도 https://blog.naver.com/haheehooheho_/223748410522
# 초벌부터 고퀄인 애월 카페거리 맛집 https://blog.naver.com/rrrod29/223704597120
# 가성비 좋은 협재해수욕장 근처 맛집 https://blog.naver.com/armso4224/223721953453
# 극찬의 연속 영덕대게맛집 https://blog.naver.com/luxuryyhj/223677201834
# 특출났던 제주도 갈치구이 맛집 https://blog.naver.com/kimproperty/223687958346
# 퀄리티에 매료된 부산서면맛집 https://blog.naver.com/ahappy82/223729522344
# 부족함 없던 에코랜드 맛집 https://blog.naver.com/cocovely40/223734540260
# 맛깔났던 제주 소고기 맛집 제주원우정 https://blog.naver.com/junbeom789/223740948277
# 꿀맛같은 제주시 흑돼지 맛집 https://blog.naver.com/bau_j2/223744531973
# 매력만점 제주 애월 삼겹살 맛집 https://blog.naver.com/mimohwang/223731498305
# 추천하는 서귀포 현지인 맛집 https://blog.naver.com/zz3371/223732738138
# 중독적인 대구 대명동 맛집 https://blog.naver.com/kcr28/223717471360
# 가락시장 방어회 초장집 맛집 바다나라 횟집 https://blog.naver.com/minpil0312/223689914619
# ...
