# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import pyperclip
import time
import requests

driver = webdriver.Chrome()
driver.get("https://nid.naver.com/nidlogin.login")
time.sleep(1)

id = driver.find_element(By.CSS_SELECTOR, '#id')
pyperclip.copy(your_id)
id.send_keys(Keys.CONTROL, 'v')
time.sleep(1)

pw = driver.find_element(By.CSS_SELECTOR, '#pw')
pyperclip.copy(your_pw)
pw.send_keys(Keys.CONTROL, 'v')
time.sleep(1)


driver.find_element(By.CSS_SELECTOR, ".btn_login").click()

# %%
cookies = driver.get_cookies()

# %%
session = requests.Session()
for cookie in cookies:
    session.cookies.set(cookie['name'], cookie['value'])

# %%
res = session.get("https://cafe.naver.com/startcodingofficial/1906")
res
# Out:
# <Response [200]>

# %% [markdown]
# # 댓글 작성 자동화

# %%
cafeId = '31023030'
articleId = '1906'

# %%
cookies = {
    'NAC': 'OeMTDAhVORoMB',
    'NNB': '6CHZ7GSTK2UWO',
    'ba.uuid': 'bc52ea4e-a89e-4927-b423-0d5a1591c141',
    '_ga_6Z6DP60WFK': 'GS1.2.1739769802.1.0.1739769802.60.0.0',
    '_ga_8P4PY65YZ2': 'GS1.1.1741755871.1.1.1741755872.59.0.0',
    'BNB_FINANCE_HOME_TOOLTIP_MYASSET': 'true',
    'ASID': 'de61ac4300000195b62765290000004f',
    '_fbp': 'fb.1.1742557457069.940885132313976443',
    '_ga': 'GA1.1.1667454962.1739769802',
    '_ga_EFBDNNF91G': 'GS1.1.1742557457.1.0.1742557466.0.0.0',
    'NACT': '1',
    'SRT30': '1743049994',
    'JSESSIONID': '261EE08B7E22692C6335B05744C2F2A7',
    'page_uid': 'i+gTysqptbNssQ6xlq4ssssst2o-469053',
    'nid_inf': '2016414717',
    'NID_AUT': 'nDI/A5xS1ReX85ZRbs48Jc96GRi+kJaISv7uEsEX/yTZ/nK7ikMALPbbHOfn8CxE',
    'NID_SES': '...',
    'NID_JKL': 'HY18dPmq1ip0K89NNlmcwJxfDnkbyUvDVscbfU1ZXuw=',
    'SRT5': '1743054337',
    'BUC': 'yRoEEbUHQxSdj0HMLPNnb9EqDbfed8Pa6HD0BoWNxEw=',
}

headers = {
    'accept': 'application/json, text/plain, */*',
    'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
    'content-type': 'application/x-www-form-urlencoded',
    'origin': 'https://cafe.naver.com',
    'priority': 'u=1, i',
    'referer': 'https://cafe.naver.com/ca-fe/cafes/31023030/articles/1906?oldPath=%2FArticleRead.nhn%3Farticleid%3D1906%26clubid%3D31023030',
    'sec-ch-ua': '"Chromium";v="134", "Not:A-Brand";v="24", "Google Chrome";v="134"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-site',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36',
    'x-cafe-product': 'pc',
    # 'cookie': 'NAC=OeMTDAhVORoMB; NNB=6CHZ7GSTK2UWO; ba.uuid=bc52ea4e-a89e-4927-b423-0d5a1591c141; _ga_6Z6DP60WFK=GS1.2.1739769802.1.0.1739769802.60.0.0; _ga_8P4PY65YZ2=GS1.1.1741755871.1.1.1741755872.59.0.0; BNB_FINANCE_HOME_TOOLTIP_MYASSET=true; ASID=de61ac4300000195b62765290000004f; _fbp=fb.1.1742557457069.940885132313976443; _ga=GA1.1.1667454962.1739769802; _ga_EFBDNNF91G=GS1.1.1742557457.1.0.1742557466.0.0.0; NACT=1; SRT30=1743049994; JSESSIONID=261EE08B7E22692C6335B05744C2F2A7; page_uid=i+gTysqptbNssQ6xlq4ssssst2o-469053; nid_inf=2016414717; NID_AUT=nDI/A5xS1ReX85ZRbs48Jc96GRi+kJaISv7uEsEX/yTZ/nK7ikMALPbbHOfn8CxE; NID_SES=...; NID_JKL=HY18dPmq1ip0K89NNlmcwJxfDnkbyUvDVscbfU1ZXuw=; SRT5=1743054337; BUC=yRoEEbUHQxSdj0HMLPNnb9EqDbfed8Pa6HD0BoWNxEw=',
}

data = {
    'content': '테스트1',
    'stickerId': '',
    'cafeId': cafeId,
    'articleId': articleId,
    'requestFrom': 'A',
}

session.headers.update(headers)

response = session.post(
    'https://apis.naver.com/cafe-web/cafe-mobile/CommentPost.json',
    cookies=cookies,
    data=data,
)

# %%
import requests

cookies = {
    'NAC': 'OeMTDAhVORoMB',
    'NNB': '6CHZ7GSTK2UWO',
    'ba.uuid': 'bc52ea4e-a89e-4927-b423-0d5a1591c141',
    '_ga_6Z6DP60WFK': 'GS1.2.1739769802.1.0.1739769802.60.0.0',
    '_ga_8P4PY65YZ2': 'GS1.1.1741755871.1.1.1741755872.59.0.0',
    'BNB_FINANCE_HOME_TOOLTIP_MYASSET': 'true',
    'ASID': 'de61ac4300000195b62765290000004f',
    '_fbp': 'fb.1.1742557457069.940885132313976443',
    '_ga': 'GA1.1.1667454962.1739769802',
    '_ga_EFBDNNF91G': 'GS1.1.1742557457.1.0.1742557466.0.0.0',
    'NACT': '1',
    'SRT30': '1743049994',
    'JSESSIONID': '261EE08B7E22692C6335B05744C2F2A7',
    'page_uid': 'i+gTysqptbNssQ6xlq4ssssst2o-469053',
    'nid_inf': '2016414717',
    'NID_AUT': 'nDI/A5xS1ReX85ZRbs48Jc96GRi+kJaISv7uEsEX/yTZ/nK7ikMALPbbHOfn8CxE',
    'NID_SES': '...',
    'NID_JKL': 'HY18dPmq1ip0K89NNlmcwJxfDnkbyUvDVscbfU1ZXuw=',
    'SRT5': '1743054337',
    'BUC': 'H-V2q9xN0di8eQ8h_msfB3kctrEkL37IkBNjmMoE1Fg=',
}

headers = {
    'accept': 'application/json, text/plain, */*',
    'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
    'content-type': 'application/x-www-form-urlencoded',
    'origin': 'https://cafe.naver.com',
    'priority': 'u=1, i',
    'referer': 'https://cafe.naver.com/ca-fe/cafes/31023030/articles/1906?oldPath=%2FArticleRead.nhn%3Farticleid%3D1906%26clubid%3D31023030',
    'sec-ch-ua': '"Chromium";v="134", "Not:A-Brand";v="24", "Google Chrome";v="134"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-site',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36',
    'x-cafe-product': 'pc',
    # 'cookie': 'NAC=OeMTDAhVORoMB; NNB=6CHZ7GSTK2UWO; ba.uuid=bc52ea4e-a89e-4927-b423-0d5a1591c141; _ga_6Z6DP60WFK=GS1.2.1739769802.1.0.1739769802.60.0.0; _ga_8P4PY65YZ2=GS1.1.1741755871.1.1.1741755872.59.0.0; BNB_FINANCE_HOME_TOOLTIP_MYASSET=true; ASID=de61ac4300000195b62765290000004f; _fbp=fb.1.1742557457069.940885132313976443; _ga=GA1.1.1667454962.1739769802; _ga_EFBDNNF91G=GS1.1.1742557457.1.0.1742557466.0.0.0; NACT=1; SRT30=1743049994; JSESSIONID=261EE08B7E22692C6335B05744C2F2A7; page_uid=i+gTysqptbNssQ6xlq4ssssst2o-469053; nid_inf=2016414717; NID_AUT=nDI/A5xS1ReX85ZRbs48Jc96GRi+kJaISv7uEsEX/yTZ/nK7ikMALPbbHOfn8CxE; NID_SES=...; NID_JKL=HY18dPmq1ip0K89NNlmcwJxfDnkbyUvDVscbfU1ZXuw=; SRT5=1743054337; BUC=H-V2q9xN0di8eQ8h_msfB3kctrEkL37IkBNjmMoE1Fg=',
}

data = {
    'cafeId': '31023030',
    'menuId': '12',
    'articleId': '1906',
    'commentId': '83104504',
    'requestFrom': 'A',
}

response = session.post(
    'https://apis.naver.com/cafe-web/cafe-mobile/CommentDelete.json',
    cookies=cookies,
    headers=headers,
    data=data,
)

# %% [markdown]
# # 댓글 리스트 크롤링

# %%
import requests

cookies = {
    'NAC': 'OeMTDAhVORoMB',
    'NNB': '6CHZ7GSTK2UWO',
    'ba.uuid': 'bc52ea4e-a89e-4927-b423-0d5a1591c141',
    '_ga_6Z6DP60WFK': 'GS1.2.1739769802.1.0.1739769802.60.0.0',
    '_ga_8P4PY65YZ2': 'GS1.1.1741755871.1.1.1741755872.59.0.0',
    'BNB_FINANCE_HOME_TOOLTIP_MYASSET': 'true',
    'ASID': 'de61ac4300000195b62765290000004f',
    '_fbp': 'fb.1.1742557457069.940885132313976443',
    '_ga': 'GA1.1.1667454962.1739769802',
    '_ga_EFBDNNF91G': 'GS1.1.1742557457.1.0.1742557466.0.0.0',
    'NACT': '1',
    'SRT30': '1743049994',
    'JSESSIONID': '261EE08B7E22692C6335B05744C2F2A7',
    'page_uid': 'i+gTysqptbNssQ6xlq4ssssst2o-469053',
    'nid_inf': '2016414717',
    'NID_AUT': 'nDI/A5xS1ReX85ZRbs48Jc96GRi+kJaISv7uEsEX/yTZ/nK7ikMALPbbHOfn8CxE',
    'NID_SES': '...',
    'NID_JKL': 'HY18dPmq1ip0K89NNlmcwJxfDnkbyUvDVscbfU1ZXuw=',
    'BUC': 'GNCqV3qgj0quK8_9cqhvdv-XzKKMaiugo5psnOtEu54=',
}

headers = {
    'accept': 'application/json, text/plain, */*',
    'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
    'origin': 'https://cafe.naver.com',
    'priority': 'u=1, i',
    'referer': 'https://cafe.naver.com/ca-fe/cafes/31023030/articles/1906?oldPath=%2FArticleRead.nhn%3Farticleid%3D1906%26clubid%3D31023030',
    'sec-ch-ua': '"Chromium";v="134", "Not:A-Brand";v="24", "Google Chrome";v="134"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-site',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36',
    'x-cafe-product': 'pc',
    # 'cookie': 'NAC=OeMTDAhVORoMB; NNB=6CHZ7GSTK2UWO; ba.uuid=bc52ea4e-a89e-4927-b423-0d5a1591c141; _ga_6Z6DP60WFK=GS1.2.1739769802.1.0.1739769802.60.0.0; _ga_8P4PY65YZ2=GS1.1.1741755871.1.1.1741755872.59.0.0; BNB_FINANCE_HOME_TOOLTIP_MYASSET=true; ASID=de61ac4300000195b62765290000004f; _fbp=fb.1.1742557457069.940885132313976443; _ga=GA1.1.1667454962.1739769802; _ga_EFBDNNF91G=GS1.1.1742557457.1.0.1742557466.0.0.0; NACT=1; SRT30=1743049994; JSESSIONID=261EE08B7E22692C6335B05744C2F2A7; page_uid=i+gTysqptbNssQ6xlq4ssssst2o-469053; nid_inf=2016414717; NID_AUT=nDI/A5xS1ReX85ZRbs48Jc96GRi+kJaISv7uEsEX/yTZ/nK7ikMALPbbHOfn8CxE; NID_SES=...; NID_JKL=HY18dPmq1ip0K89NNlmcwJxfDnkbyUvDVscbfU1ZXuw=; BUC=GNCqV3qgj0quK8_9cqhvdv-XzKKMaiugo5psnOtEu54=',
}

params = {
    'requestFrom': 'A',
    'orderBy': 'asc',
}

res = session.get(
    'https://apis.naver.com/cafe-web/cafe-articleapi/v2/cafes/31023030/articles/1906/comments/pages/1',
    params=params,
    cookies=cookies,
    headers=headers,
)

# %%
import re, json
comment_data = json.loads(res.text)

# %%
comment_datas = comment_data['result']['comments']['items']
# Out:
# {'result': {'cafeId': 31023030,
#   'articleId': 1906,
#   'menuId': 12,
#   'cafe': {'id': 31023030,
#    'name': '스타트코딩 교육 센터',
#    'pcCafeName': '스타트코딩 교육 센터',
#    'url': 'startcodingofficial',
#    'image': {'url': 'https://cafeptthumb-phinf.pstatic.net/MjAyNDAzMTFfMTYy/MDAxNzEwMTM2NDEyMjQ2.PKJJ2KBB80Wl9EwnN_tFLugZQIZD9Pfh0yosPVKpf2Ag.j3PNt70NQEZEhI136KOYaK7vNwDAXGCBRxyz1C5hNFEg.PNG/image.png',
#     'service': 'CAFE',
#     'type': 'f100_100'},
#    'introduction': '코딩으로 돈을 벌며, 최고 IT 강사의 삶을 쟁취하는 노하우를 드립니다.',
#    'memberCount': 2103,
#    'hasPopularArticle': True,
#    'usingMemberLevel': True,
#    'memberLevelIconId': 1,
#    'openType': 'O',
#    'isDormant': False},
#   'user': {'id': 'snsk656',
#    'memberKey': 'IgggBsChHUZI8welzN9cDw',
#    'nick': '완벽그자체',
#    'image': {'url': 'https://ssl.pstatic.net/static/cafe/cafe_pc/default/cafe_profile_77.png',
#     'service': 'CAFE',
#     'type': 'c77_77'},
#    'memberLevel': 120,
#    'memberLevelName': '미드레벨',
# ...

# %%
comment_data['result']['hasNext']
# Out:
# {'cafeId': 31023030,
#  'articleId': 1906,
#  'menuId': 12,
#  'cafe': {'id': 31023030,
#   'name': '스타트코딩 교육 센터',
#   'pcCafeName': '스타트코딩 교육 센터',
#   'url': 'startcodingofficial',
#   'image': {'url': 'https://cafeptthumb-phinf.pstatic.net/MjAyNDAzMTFfMTYy/MDAxNzEwMTM2NDEyMjQ2.PKJJ2KBB80Wl9EwnN_tFLugZQIZD9Pfh0yosPVKpf2Ag.j3PNt70NQEZEhI136KOYaK7vNwDAXGCBRxyz1C5hNFEg.PNG/image.png',
#    'service': 'CAFE',
#    'type': 'f100_100'},
#   'introduction': '코딩으로 돈을 벌며, 최고 IT 강사의 삶을 쟁취하는 노하우를 드립니다.',
#   'memberCount': 2103,
#   'hasPopularArticle': True,
#   'usingMemberLevel': True,
#   'memberLevelIconId': 1,
#   'openType': 'O',
#   'isDormant': False},
#  'user': {'id': 'snsk656',
#   'memberKey': 'IgggBsChHUZI8welzN9cDw',
#   'nick': '완벽그자체',
#   'image': {'url': 'https://ssl.pstatic.net/static/cafe/cafe_pc/default/cafe_profile_77.png',
#    'service': 'CAFE',
#    'type': 'c77_77'},
#   'memberLevel': 120,
#   'memberLevelName': '미드레벨',
# ...

# %% [markdown]
# # 자동 댓글 리스트

# %%
import requests

cookies = {
    'NAC': 'OeMTDAhVORoMB',
    'NNB': '6CHZ7GSTK2UWO',
    'ba.uuid': 'bc52ea4e-a89e-4927-b423-0d5a1591c141',
    '_ga_6Z6DP60WFK': 'GS1.2.1739769802.1.0.1739769802.60.0.0',
    '_ga_8P4PY65YZ2': 'GS1.1.1741755871.1.1.1741755872.59.0.0',
    'BNB_FINANCE_HOME_TOOLTIP_MYASSET': 'true',
    'ASID': 'de61ac4300000195b62765290000004f',
    '_fbp': 'fb.1.1742557457069.940885132313976443',
    '_ga': 'GA1.1.1667454962.1739769802',
    '_ga_EFBDNNF91G': 'GS1.1.1742557457.1.0.1742557466.0.0.0',
    'NACT': '1',
    'SRT30': '1743049994',
    'JSESSIONID': '261EE08B7E22692C6335B05744C2F2A7',
    'page_uid': 'i+gTysqptbNssQ6xlq4ssssst2o-469053',
    'nid_inf': '2016414717',
    'NID_AUT': 'nDI/A5xS1ReX85ZRbs48Jc96GRi+kJaISv7uEsEX/yTZ/nK7ikMALPbbHOfn8CxE',
    'NID_SES': '...',
    'NID_JKL': 'HY18dPmq1ip0K89NNlmcwJxfDnkbyUvDVscbfU1ZXuw=',
    'BUC': 'GNCqV3qgj0quK8_9cqhvdv-XzKKMaiugo5psnOtEu54=',
}

headers = {
    'accept': 'application/json, text/plain, */*',
    'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
    'origin': 'https://cafe.naver.com',
    'priority': 'u=1, i',
    'referer': 'https://cafe.naver.com/ca-fe/cafes/31023030/articles/1906?oldPath=%2FArticleRead.nhn%3Farticleid%3D1906%26clubid%3D31023030',
    'sec-ch-ua': '"Chromium";v="134", "Not:A-Brand";v="24", "Google Chrome";v="134"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-site',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36',
    'x-cafe-product': 'pc',
    # 'cookie': 'NAC=OeMTDAhVORoMB; NNB=6CHZ7GSTK2UWO; ba.uuid=bc52ea4e-a89e-4927-b423-0d5a1591c141; _ga_6Z6DP60WFK=GS1.2.1739769802.1.0.1739769802.60.0.0; _ga_8P4PY65YZ2=GS1.1.1741755871.1.1.1741755872.59.0.0; BNB_FINANCE_HOME_TOOLTIP_MYASSET=true; ASID=de61ac4300000195b62765290000004f; _fbp=fb.1.1742557457069.940885132313976443; _ga=GA1.1.1667454962.1739769802; _ga_EFBDNNF91G=GS1.1.1742557457.1.0.1742557466.0.0.0; NACT=1; SRT30=1743049994; JSESSIONID=261EE08B7E22692C6335B05744C2F2A7; page_uid=i+gTysqptbNssQ6xlq4ssssst2o-469053; nid_inf=2016414717; NID_AUT=nDI/A5xS1ReX85ZRbs48Jc96GRi+kJaISv7uEsEX/yTZ/nK7ikMALPbbHOfn8CxE; NID_SES=...; NID_JKL=HY18dPmq1ip0K89NNlmcwJxfDnkbyUvDVscbfU1ZXuw=; BUC=GNCqV3qgj0quK8_9cqhvdv-XzKKMaiugo5psnOtEu54=',
}

params = {
    'requestFrom': 'A',
    'orderBy': 'asc',
}


page = 1
while True:
    res = session.get(
        f"https://apis.naver.com/cafe-web/cafe-articleapi/v2/cafes/31023030/articles/1906/comments/pages/{page}",
        params=params,
        cookies=cookies,
        headers=headers,
    )


    for comment_d in comment_datas :
        comment_id = comment_d['id']
        writer = comment_d['writer']['nick']
        content = comment_d['content']
    
        print(comment_id,"\t",writer,"\t",content)

    if comment_data['result']['hasNext'] :
        page += 1
    else :
        break
# Out:
# 82640712 	 스타트코딩 	 테스트2
# 82640720 	 스타트코딩 	 테스트3
# 82641036 	 37song 	 테스트4
# 82641109 	 한파엑셀 	 테스트5
# 82644630 	 스타트코딩 	 이사람들이
# 82645122 	 조민석
# 82663471 	 스타트코딩 	 자동화된 댓글입니다
# 82671679 	 getit 	 수동으로 단 댓글입니다
# 82678191 	 37song 	 흐흐흐 카페가 활발해지는거 같아 보기 좋습니당 😆😆
# 82729292 	 스타트코딩 	 안녕하세요
# 82729502 	 스타트코딩 	 단기 목표를 적어보세요
# 82834092 	 한파엑셀 	 심화편 2차 공개 시 답글이 달릴 댓글입니다.
# 82941959 	 호푸 	 안녕하세요
# 82942016 	 호푸 	 단기 목표를 적어보세요
# 82943175 	 JLSC 	 안녕하세요.
# 82943238 	 JLSC 	 화이팅!!
# 83037414 	 레오 	 과제를 스스로 해내고 말겠습니다!
# 83039466 	 cyk 	 안녕하세요
# 83048669 	 cyk 	 단기 목표를 적어보세요
# 83054701 	 cyk 	 단기 목표를 적어보세요
# 83067186 	 투타12 	 단기목표를 적어보세요
# 83067652 	 투타12 	 단기목표를 적어보세요
# 83067667 	 투타12 	 ㅇㄹㅇㄹ
# 83068071 	 투타12 	 단기목표를 적어보세요

# %% [markdown]
# # 게시글 좋아요 자동화 (토큰 말고도 추가적으로 파라미터가 고정이 아닌 값 찾아보기)

# %%
import requests

cookies = {
    'NAC': 'OeMTDAhVORoMB',
    'NNB': '6CHZ7GSTK2UWO',
    'ba.uuid': 'bc52ea4e-a89e-4927-b423-0d5a1591c141',
    '_ga_6Z6DP60WFK': 'GS1.2.1739769802.1.0.1739769802.60.0.0',
    '_ga_8P4PY65YZ2': 'GS1.1.1741755871.1.1.1741755872.59.0.0',
    'BNB_FINANCE_HOME_TOOLTIP_MYASSET': 'true',
    'ASID': 'de61ac4300000195b62765290000004f',
    '_fbp': 'fb.1.1742557457069.940885132313976443',
    '_ga': 'GA1.1.1667454962.1739769802',
    '_ga_EFBDNNF91G': 'GS1.1.1742557457.1.0.1742557466.0.0.0',
    'NACT': '1',
    'SRT30': '1743049994',
    'page_uid': 'i+gTysqptbNssQ6xlq4ssssst2o-469053',
    'nid_inf': '2016414717',
    'NID_AUT': 'nDI/A5xS1ReX85ZRbs48Jc96GRi+kJaISv7uEsEX/yTZ/nK7ikMALPbbHOfn8CxE',
    'NID_JKL': 'HY18dPmq1ip0K89NNlmcwJxfDnkbyUvDVscbfU1ZXuw=',
    'SRT5': '1743059911',
    'NID_SES': '...',
    'BUC': 'RshBQsNl28d8IwrUgA7gXnU9I00cYRG2ko00JEZp-vk=',
}

headers = {
    'accept': '*/*',
    'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
    'referer': 'https://cafe.naver.com/ca-fe/cafes/31023030/articles/2?oldPath=%2FArticleRead.nhn%3Farticleid%3D2%26clubid%3D31023030',
    'sec-ch-ua': '"Chromium";v="134", "Not:A-Brand";v="24", "Google Chrome";v="134"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'script',
    'sec-fetch-mode': 'no-cors',
    'sec-fetch-site': 'same-site',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36',
    # 'cookie': 'NAC=OeMTDAhVORoMB; NNB=6CHZ7GSTK2UWO; ba.uuid=bc52ea4e-a89e-4927-b423-0d5a1591c141; _ga_6Z6DP60WFK=GS1.2.1739769802.1.0.1739769802.60.0.0; _ga_8P4PY65YZ2=GS1.1.1741755871.1.1.1741755872.59.0.0; BNB_FINANCE_HOME_TOOLTIP_MYASSET=true; ASID=de61ac4300000195b62765290000004f; _fbp=fb.1.1742557457069.940885132313976443; _ga=GA1.1.1667454962.1739769802; _ga_EFBDNNF91G=GS1.1.1742557457.1.0.1742557466.0.0.0; NACT=1; SRT30=1743049994; page_uid=i+gTysqptbNssQ6xlq4ssssst2o-469053; nid_inf=2016414717; NID_AUT=nDI/A5xS1ReX85ZRbs48Jc96GRi+kJaISv7uEsEX/yTZ/nK7ikMALPbbHOfn8CxE; NID_JKL=HY18dPmq1ip0K89NNlmcwJxfDnkbyUvDVscbfU1ZXuw=; SRT5=1743059911; NID_SES=...; BUC=RshBQsNl28d8IwrUgA7gXnU9I00cYRG2ko00JEZp-vk=',
}

params = {
    'suppress_response_codes': 'true',
    'q': 'CAFE[31023030_startcodingofficial_2]|CAFE-COMMENT[31023030-2-80426722,31023030-2-80938474,31023030-2-82435974,31023030-2-82717278,31023030-2-83089503]',
    'isDuplication': 'true',
    'cssIds': 'BASIC_PC,CAFE_PC',
    '_': '1743060873971',
}

response = session.get('https://cafe.like.naver.com/v1/search/contents', params=params, cookies=cookies, headers=headers)
guest_token = response.json()['guestToken']
timestamp = response.json()['timestamp']
print(guest_token, timestamp)
# Out:
# aacad64ccf7d9746367bb9ff65f55fa73714487de03e514a80a01cacb6de4700ae10c81f46ac58f803f7a7d7b49e0fb0436d49556c166c426a98ecc227c166a6 1743061532423

# %%
response
# Out:
# '{"contents":[{"serviceId":"CAFE","contentsId":"31023030_startcodingofficial_2","isDisplay":true,"categoryId":null,"countType":"DEFAULT","reactions":[{"reactionType":"like","count":12,"isReacted":true,"periodUser":null,"reactionTypeCode":{"name":"like","messageCode":"reaction.type.like","description":"좋아요"}}],"reactionMap":{"com.naver.react.core.nbasearc.common.ReactionType@43afe7a2":{"reactionType":"like","count":12,"isReacted":true,"periodUser":null,"reactionTypeCode":{"name":"like","messageCode":"reaction.type.like","description":"좋아요"}}},"reactionTextMap":{"ko":{"like":"좋아요"},"zh-hant":{"like":"讚"},"zh-tw":{"like":"like"},"zh-hans":{"like":"喜欢"},"ja":{"like":"いいね"},"en":{"like":"like"},"fr":{"like":"J\'aime"},"zh-cn":{"like":"like"},"es":{"like":"Me gusta"},"es-mx":{"like":"Me gusta"}},"isLogin":false,"customized":false,"differentPlatform":false},{"serviceId":"CAFE-COMMENT","contentsId":"31023030-2-80426722","isDisplay":true,"categoryId":null,"countType":"DEFAULT","reactions":[],
# ...

# %%
import requests

cookies = {
    'NAC': 'OeMTDAhVORoMB',
    'NNB': '6CHZ7GSTK2UWO',
    'ba.uuid': 'bc52ea4e-a89e-4927-b423-0d5a1591c141',
    '_ga_6Z6DP60WFK': 'GS1.2.1739769802.1.0.1739769802.60.0.0',
    '_ga_8P4PY65YZ2': 'GS1.1.1741755871.1.1.1741755872.59.0.0',
    'BNB_FINANCE_HOME_TOOLTIP_MYASSET': 'true',
    'ASID': 'de61ac4300000195b62765290000004f',
    '_fbp': 'fb.1.1742557457069.940885132313976443',
    '_ga': 'GA1.1.1667454962.1739769802',
    '_ga_EFBDNNF91G': 'GS1.1.1742557457.1.0.1742557466.0.0.0',
    'NACT': '1',
    'SRT30': '1743049994',
    'page_uid': 'i+gTysqptbNssQ6xlq4ssssst2o-469053',
    'nid_inf': '2016414717',
    'NID_AUT': 'nDI/A5xS1ReX85ZRbs48Jc96GRi+kJaISv7uEsEX/yTZ/nK7ikMALPbbHOfn8CxE',
    'NID_JKL': 'HY18dPmq1ip0K89NNlmcwJxfDnkbyUvDVscbfU1ZXuw=',
    'NID_SES': '...',
    'SRT5': '1743059087',
    'BUC': 'h-3YeG11cZha7YZQmJKTN-wDw7d9wEzkrsFw-mtA6jw=',
}

params = {
    'suppress_response_codes': 'true',
    '_method': 'POST',
    'callback': 'jQuery3310036667290351312554_1743059102009',
    'displayId': 'CAFE',
    'reactionType': 'like',
    'categoryId': '31023030',
    'guestToken': guest_token,
    'timestamp': timestamp,
    '_ch': 'pcw',
    'isDuplication': 'true',
    'lang': 'ko',
    'countType': 'default',
    'count': '1',
    'history': '',
    'runtimeStatus': '',
    'isPostTimeline': 'false',
    '_': '1743059102011',
}

session.headers.update(headers)

response = session.get(
    'https://cafe.like.naver.com/v1/services/CAFE/contents/31023030_startcodingofficial_2',
    params=params,
    cookies=cookies,
)

# %%
response.text
# Out:
# '/**/jQuery3310036667290351312554_1743059102009({"serviceId":"CAFE","displayId":"CAFE","contentsId":"31023030_startcodingofficial_2","message":"좋아요가 되었습니다.","categoryId":"31023030","reactionType":"like","count":12,"isReacted":true,"countType":"DEFAULT","nolimitUserCount":0});'
