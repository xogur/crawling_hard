# %% [markdown]
# ## requests 방식

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import pyperclip
import time
import requests
import json,re

# %%
import requests

cookies = {
    'session': '.eJwtT8tOwzAQ_BXjU5Ha1M_ECSfEAaRSLlTqAVDk2GtqGpIqTnlV_Xc2iMvOand2ZvZE69DatINEq6cTJSMCjV3o6Zw-HxvDDFZnDVGIolTk-WgdFAguFzjz-o-hRDnt3dQLUBf05fwyR-kB0o5WwbYJ5tQNYEfwtUUTKpjQCyYXotiwsmKmkjyTuRGFRmeXhlCP_R46ZJaOBW-tkJozBaBCbmRpbDCccVdaI1nBvCpKvIuH2nqPpvgN5Sxjmcp4wXDzluoPGGKI4Gk1DkeMk5AW-67ewzeyNQo6JQzPC106za32kjNpGt8YL51EjWOCobav0E351_1PbFu71Bkjs23sfP-ZyMOGTK5XBAe5uiJfubok14dDC1toVnFcalngl2S2utus7-ekjXsgt-D2_SW52Q39Oyy5VNkUnJFHG-wQ_0_o-ReFPXzH.Z-UVjw.Lc9p9S469BTnAmVigakzibs94Sw',
}

headers = {
    'Accept': 'application/json',
    'Accept-Language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
    'Connection': 'keep-alive',
    'Referer': 'https://begincoding.pythonanywhere.com/level3',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36',
    'sec-ch-ua': '"Chromium";v="134", "Not:A-Brand";v="24", "Google Chrome";v="134"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    # 'Cookie': 'session=.eJwtT8tOwzAQ_BXjU5Ha1M_ECSfEAaRSLlTqAVDk2GtqGpIqTnlV_Xc2iMvOand2ZvZE69DatINEq6cTJSMCjV3o6Zw-HxvDDFZnDVGIolTk-WgdFAguFzjz-o-hRDnt3dQLUBf05fwyR-kB0o5WwbYJ5tQNYEfwtUUTKpjQCyYXotiwsmKmkjyTuRGFRmeXhlCP_R46ZJaOBW-tkJozBaBCbmRpbDCccVdaI1nBvCpKvIuH2nqPpvgN5Sxjmcp4wXDzluoPGGKI4Gk1DkeMk5AW-67ewzeyNQo6JQzPC106za32kjNpGt8YL51EjWOCobav0E351_1PbFu71Bkjs23sfP-ZyMOGTK5XBAe5uiJfubok14dDC1toVnFcalngl2S2utus7-ekjXsgt-D2_SW52Q39Oyy5VNkUnJFHG-wQ_0_o-ReFPXzH.Z-UVjw.Lc9p9S469BTnAmVigakzibs94Sw',
}

params = {
    'page': '1',
    'pageSize': '20',
}

response = requests.get(
    'https://begincoding.pythonanywhere.com/protected_api/articles',
    params=params,
    cookies=cookies,
    headers=headers,
)

# %%
datas = json.loads(response.text)
datas
# Out:
# [{'article_no': '2456802095',
#   'article_name': 'K타워(도시형)',
#   'article_deal_or_warrant_price': '2억 2,000',
#   'article_type_name': '아파트',
#   'article_area_name': '26B',
#   'article_area_size': 16,
#   'article_floor': '4/14',
#   'article_direction': '남동향',
#   'article_desc': '역세권 즉시입주가능 물건',
#   'article_expandable': True,
# ...

# %%
for data in datas :
    num = data.get("article_no","")
    print("매물번호 : ",num)
# Out:
# 매물번호 :  2456802095
# 매물번호 :  2456645976
# 매물번호 :  2460477200
# 매물번호 :  2461781941
# 매물번호 :  2460813114
# 매물번호 :  2460519930
# 매물번호 :  2460211781
# 매물번호 :  2461115789
# 매물번호 :  2459776757
# 매물번호 :  2461933668
# 매물번호 :  2461968304
# 매물번호 :  2462143478
# 매물번호 :  2462079959
# 매물번호 :  2461710895
# 매물번호 :  2456968913
# 매물번호 :  2462092179
# 매물번호 :  2461677544
# 매물번호 :  2461406767
# 매물번호 :  2461414115
# 매물번호 :  2461969152

# %% [markdown]
# ## 세션 방식

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time

driver = webdriver.Chrome()
driver.get("https://begincoding.pythonanywhere.com/login")
time.sleep(1)

username = driver.find_element(By.CSS_SELECTOR, "#username")
username.send_keys('test4')
time.sleep(1)

password = driver.find_element(By.CSS_SELECTOR, "#password")
password.send_keys('4444')
time.sleep(1)

login_btn = driver.find_element(By.CSS_SELECTOR, "#submit")
login_btn.click()

# %%
cookies = driver.get_cookies()
print(cookies)
# Out:
# [{'domain': 'begincoding.pythonanywhere.com', 'httpOnly': True, 'name': 'session', 'path': '/', 'sameSite': 'Lax', 'secure': False, 'value': '.eJwlT0FuAzEI_Erkc1UZbK9xvtKNIrBBqVq10jo-Rfl7iXoZGAYxwyNc7ZvnTWc4fzzC6e4lzNW7zhnewr6ESt8XD6N99VpfWEY8eYEELnQr-xqFXgKK94KdXqj5PVyelzc3OHTewvl-LHX2OcI5SKlgHXGLfrIOwgGUCZTzJo1bHi6R1SZKvUHMgzcrjZiKIQljkeR7fTRhxbK1KNQhAototRy3WgTB4wiTdB6aimmsRIkBjGvy165r6vGfBsB5n4dd779f-uMTbCi9EG7YGEkZDXMeMkyyG6VUPabW1sLzD5xkXwA.Z-UXjw._makjalJTgGPWlBognZGuggw7u4'}]

# %%
session = requests.Session()

for cookie in cookies:
    session.cookies.set(cookie['name'], cookie['value'])

# %%
import requests


headers = {
    'Accept': 'application/json',
    'Accept-Language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
    'Connection': 'keep-alive',
    'Referer': 'https://begincoding.pythonanywhere.com/level3',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36',
    'sec-ch-ua': '"Chromium";v="134", "Not:A-Brand";v="24", "Google Chrome";v="134"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    # 'Cookie': 'session=.eJwtT8tOwzAQ_BXjU5Ha1M_ECSfEAaRSLlTqAVDk2GtqGpIqTnlV_Xc2iMvOand2ZvZE69DatINEq6cTJSMCjV3o6Zw-HxvDDFZnDVGIolTk-WgdFAguFzjz-o-hRDnt3dQLUBf05fwyR-kB0o5WwbYJ5tQNYEfwtUUTKpjQCyYXotiwsmKmkjyTuRGFRmeXhlCP_R46ZJaOBW-tkJozBaBCbmRpbDCccVdaI1nBvCpKvIuH2nqPpvgN5Sxjmcp4wXDzluoPGGKI4Gk1DkeMk5AW-67ewzeyNQo6JQzPC106za32kjNpGt8YL51EjWOCobav0E351_1PbFu71Bkjs23sfP-ZyMOGTK5XBAe5uiJfubok14dDC1toVnFcalngl2S2utus7-ekjXsgt-D2_SW52Q39Oyy5VNkUnJFHG-wQ_0_o-ReFPXzH.Z-UVjw.Lc9p9S469BTnAmVigakzibs94Sw',
}

params = {
    'page': '1',
    'pageSize': '20',
}

response = session.get(
    'https://begincoding.pythonanywhere.com/protected_api/articles',
    params=params,
    headers=headers,
)

# %%
datas = json.loads(response.text)
datas
# Out:
# [{'article_no': '2456802095',
#   'article_name': 'K타워(도시형)',
#   'article_deal_or_warrant_price': '2억 2,000',
#   'article_type_name': '아파트',
#   'article_area_name': '26B',
#   'article_area_size': 16,
#   'article_floor': '4/14',
#   'article_direction': '남동향',
#   'article_desc': '역세권 즉시입주가능 물건',
#   'article_expandable': True,
# ...

# %%
for data in datas :
    num = data.get("article_no","")
    print("매물번호 : ",num)
# Out:
# 매물번호 :  2456802095
# 매물번호 :  2456645976
# 매물번호 :  2460477200
# 매물번호 :  2461781941
# 매물번호 :  2460813114
# 매물번호 :  2460519930
# 매물번호 :  2460211781
# 매물번호 :  2461115789
# 매물번호 :  2459776757
# 매물번호 :  2461933668
# 매물번호 :  2461968304
# 매물번호 :  2462143478
# 매물번호 :  2462079959
# 매물번호 :  2461710895
# 매물번호 :  2456968913
# 매물번호 :  2462092179
# 매물번호 :  2461677544
# 매물번호 :  2461406767
# 매물번호 :  2461414115
# 매물번호 :  2461969152
